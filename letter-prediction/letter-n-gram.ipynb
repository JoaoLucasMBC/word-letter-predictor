# %% [markdown]
# # **Calculating N-Gram Letter Prediction**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **First Dataset: 5k most frequent worrds**
#
# Font: [wordfrequency.info](wordfrequency.info)

# %%
# get a specific page from the xlsx
df_words = pd.read_excel('../data/wordFrequency.xlsx', sheet_name='4 forms (219k)')

# %%
df_words.head()
# Out:
#    rank word      freq  #texts  %caps     blog      web      TVM     spok  \
# 0     1  the  50074257  483041   0.11  6272412  7101104  3784652  5769026
# 1     2   to  25557793  478977   0.02  3579158  3590504  2911924  3427348
# 2     3  and  24821791  478727   0.09  3211226  3458960  1828166  3325442
# 3     4   of  23605964  478144   0.01  2952017  3462140  1486604  2678416
# 4     5    a  21889251  477421   0.05  2783458  2827106  2519099  2716641
#
#        fic  ...     news     acad    blogPM     webPM     TVMPM    spokPM  \
# 0  6311500  ...  6582642  7447070  50480.69  55212.83  29550.39  45736.71
# 1  2871517  ...  3013501  2978222  28805.25  27917.05  22736.17  27171.94
# 2  3064047  ...  2995111  3633119  25844.11  26894.26  14274.24  26364.03
# 3  2330823  ...  2893200  4517563  23757.98  26918.99  11607.33  21234.42
# 4  2749208  ...  2959649  2229222  22401.41  21981.44  19669.01  21537.47
#
#       ficPM     magPM    newsPM    acadPM
# 0  53341.69  53975.61  54070.43  62167.47
# 1  24268.65  25264.13  24753.18  24861.93
# 2  25895.82  26215.95  24602.12  30328.95
# 3  19698.97  26054.07  23765.01  37712.21
# 4  23234.95  24619.48  24310.83  18609.35
#
# [5 rows x 21 columns]

# %% [markdown]
# Filtering the words only.

# %%
words = df_words['word'].values
print(words[:10])
# Out:
# ['the' 'to' 'and' 'of' 'a' 'in' 'i' 'that' 'you' 'it']

# %% [markdown]
# Let's create an n-gram model that calculates the probabilities of the next letter for every n-size preffix:

# %%
N = 4 #4-gram on the way!

def generate_probs(n, words):
    num_transitions = {}

    for word in words: 
        word = str(word)
        for idx in range(1, len(word)):
            if idx < n:
                prev = "%"*(n - idx) + word[:idx] # if there aren't enough letters to form an n-gram, adds % to complete it
            else:
                prev = word[idx - n:idx] # get the n-gram behind
            
            nxt = word[idx] # get the curr letter

            # if the n-gram isn't already in the table, adds it as an empty dict
            num_transitions.setdefault(prev, {})

            # then updates the count of that n-gram with the following letter by 1
            num_transitions[prev][nxt] = num_transitions[prev].setdefault(nxt, 0) + 1
        
        # for eacah one of the n-grams, count the sum of the occurences of that prefix
        # we will use this to compute the probability of each following letter
        prev_counts = {prev: sum(num_transitions[prev].values()) for prev in num_transitions}

    probs = {}
    for prev, nxt_dict in num_transitions.items():
        # for each n-gram prefix, compute the prob that the next one is the following letter
        for nxt in nxt_dict:
            probs.setdefault(prev, {})
            probs[prev][nxt] = num_transitions[prev][nxt] / prev_counts[prev]
    
    # returns relative frequency (prob) and absolute frequency for each n-gram and following word on the corpus
    return probs, prev_counts

# %% [markdown]
# Let's test!

# %%
# %%time
generate_probs(N, words)
# Out:
# CPU times: total: 1.41 s
# Wall time: 5.16 s
# ({'%%%t': {'h': 0.20973782771535582,
#    'o': 0.1348314606741573,
#    'i': 0.06741573033707865,
#    'w': 0.02247191011235955,
#    'a': 0.11235955056179775,
#    'e': 0.19101123595505617,
#    'r': 0.20973782771535582,
#    'u': 0.033707865168539325,
#    'y': 0.0149812734082397,
#    'v': 0.003745318352059925},
#   '%%th': {'e': 0.30357142857142855,
#    'a': 0.10714285714285714,
#    'i': 0.17857142857142858,
#    'o': 0.14285714285714285,
#    'r': 0.23214285714285715,
#    'u': 0.03571428571428571},
#   '%%%a': {'n': 0.11977715877437325,
#    's': 0.07799442896935933,
#    'r': 0.08913649025069638,
#    't': 0.07242339832869081,
#    'l': 0.09192200557103064,
#    'b': 0.03899721448467967,
#    'f': 0.036211699164345405,
#    'g': 0.04735376044568245,
#    'm': 0.036211699164345405,
#    'w': 0.022284122562674095,
#    'c': 0.11420612813370473,
#    'i': 0.022284122562674095,
#    'v': 0.011142061281337047,
#    'd': 0.08913649025069638,
#    'h': 0.005571030640668524,
#    'p': 0.08635097493036212,
#    'u': 0.036211699164345405,
#    'a': 0.002785515320334262},
#   '%%an': {'d': 0.11904761904761904,
#    'y': 0.16666666666666666,
#    'o': 0.047619047619047616,
#    's': 0.07142857142857142,
#    'a': 0.09523809523809523,
#    'i': 0.047619047619047616,
#    'n': 0.19047619047619047,
#    'g': 0.14285714285714285,
#    'c': 0.047619047619047616,
#    'x': 0.023809523809523808,
#    't': 0.047619047619047616},
#   '%%%o': {'f': 0.12598425196850394,
#    'n': 0.06299212598425197,
#    'r': 0.13385826771653545,
#    'u': 0.07086614173228346,
#    't': 0.023622047244094488,
#    'v': 0.05511811023622047,
#    'h': 0.015748031496062992,
#    'w': 0.06299212598425197,
#    'k': 0.023622047244094488,
#    'l': 0.047244094488188976,
#    'p': 0.15748031496062992,
#    'b': 0.09448818897637795,
#    'i': 0.007874015748031496,
#    'c': 0.07086614173228346,
#    'd': 0.015748031496062992,
#    'o': 0.007874015748031496,
#    'x': 0.007874015748031496,
#    's': 0.007874015748031496,
#    "'": 0.007874015748031496},
#   '%%%i': {'n': 0.6210526315789474,
#    't': 0.03684210526315789,
#    's': 0.05789473684210526,
#    'f': 0.005263157894736842,
#    'm': 0.14210526315789473,
#    'd': 0.04736842105263158,
#    'r': 0.02631578947368421,
#    'c': 0.005263157894736842,
#    'i': 0.010526315789473684,
#    'l': 0.021052631578947368,
#    'g': 0.010526315789473684,
#    'o': 0.005263157894736842,
#    'p': 0.005263157894736842,
#    '-': 0.005263157894736842},
#   '%tha': {'t': 0.3333333333333333, 'n': 0.6666666666666666},
#   '%%%y': {'o': 0.42857142857142855,
#    'e': 0.38095238095238093,
#    'a': 0.14285714285714285,
#    'i': 0.047619047619047616},
#   '%%yo': {'u': 0.875, 'r': 0.125},
#   '%%%f': {'o': 0.2,
#    'r': 0.11666666666666667,
#    'i': 0.20416666666666666,
#    'e': 0.11666666666666667,
#    'a': 0.2125,
#    'u': 0.08333333333333333,
#    'l': 0.0625,
#    'b': 0.004166666666666667},
#   '%%fo': {'r': 0.5416666666666666,
#    'u': 0.14583333333333334,
#    'o': 0.10416666666666667,
#    'l': 0.10416666666666667,
#    'c': 0.0625,
#    'x': 0.020833333333333332,
#    's': 0.020833333333333332},
#   '%%%w': {'a': 0.2413793103448276,
#    'i': 0.20114942528735633,
#    'e': 0.16091954022988506,
#    'h': 0.12643678160919541,
#    'o': 0.20689655172413793,
#    'r': 0.06321839080459771},
#   '%%wa': {'s': 0.09523809523809523,
#    'y': 0.07142857142857142,
#    'n': 0.11904761904761904,
#    't': 0.11904761904761904,
#    'r': 0.19047619047619047,
#    'i': 0.07142857142857142,
#    'l': 0.21428571428571427,
#    'k': 0.023809523809523808,
#    'v': 0.047619047619047616,
#    'g': 0.047619047619047616},
#   '%%%h': {'e': 0.23214285714285715,
#    'a': 0.23214285714285715,
#    'i': 0.16666666666666666,
#    'o': 0.25,
#    'u': 0.10714285714285714,
#    't': 0.005952380952380952,
#    'm': 0.005952380952380952},
#   '%%wi': {'t': 0.14285714285714285,
#    'l': 0.2,
#    'f': 0.02857142857142857,
#    'n': 0.34285714285714286,
#    's': 0.14285714285714285,
#    'd': 0.11428571428571428,
#    'r': 0.02857142857142857},
#   '%wit': {'h': 0.6, 'n': 0.4},
#   '%thi': {'s': 0.1, 'n': 0.6, 'r': 0.2, 'c': 0.1},
#   '%%%n': {"'": 0.010416666666666666,
#    'o': 0.28125,
#    'e': 0.3020833333333333,
#    'a': 0.20833333333333334,
#    'i': 0.0625,
#    'u': 0.08333333333333333,
#    'f': 0.010416666666666666,
#    't': 0.010416666666666666,
#    'p': 0.010416666666666666,
#    'b': 0.020833333333333332},
#   "%%n'": {'t': 1.0},
#   '%%%b': {'e': 0.22267206477732793,
#    'u': 0.12550607287449392,
#    'y': 0.008097165991902834,
#    'a': 0.18218623481781376,
#    'o': 0.14979757085020243,
#    'i': 0.10121457489878542,
#    'l': 0.05263157894736842,
#    'r': 0.15789473684210525},
#   '%%ha': {'v': 0.05263157894736842,
#    'd': 0.02631578947368421,
#    's': 0.02631578947368421,
#    'r': 0.23684210526315788,
#    'n': 0.2631578947368421,
#    'p': 0.15789473684210525,
#    'l': 0.05263157894736842,
#    'i': 0.02631578947368421,
#    't': 0.07894736842105263,
#    'b': 0.05263157894736842,
#    'm': 0.02631578947368421},
#   '%hav': {'e': 0.5, 'i': 0.5},
#   '%%ar': {'e': 0.125,
#    'o': 0.03125,
#    't': 0.25,
#    'm': 0.125,
#    'g': 0.1875,
#    'r': 0.15625,
#    'a': 0.0625,
#    'i': 0.03125,
#    'c': 0.03125},
#   '%%no': {'t': 0.3076923076923077,
#    'w': 0.07692307692307693,
#    'r': 0.19230769230769232,
#    'b': 0.038461538461538464,
#    'n': 0.07692307692307693,
#    'v': 0.11538461538461539,
#    's': 0.038461538461538464,
#    'i': 0.038461538461538464,
#    'd': 0.038461538461538464,
#    'o': 0.038461538461538464,
#    'm': 0.038461538461538464},
#   '%%bu': {'t': 0.12903225806451613,
#    's': 0.16129032258064516,
#    'i': 0.12903225806451613,
#    'y': 0.06451612903225806,
#    'd': 0.06451612903225806,
#    'n': 0.03225806451612903,
#    'r': 0.25806451612903225,
#    'c': 0.06451612903225806,
#    'l': 0.0967741935483871},
#   '%the': {'y': 0.0625,
#    'r': 0.1875,
#    'i': 0.0625,
#    'm': 0.25,
#    'n': 0.0625,
#    's': 0.0625,
#    'o': 0.1875,
#    'a': 0.125},
#   '%%%d': {'o': 0.10954063604240283,
#    'i': 0.24734982332155478,
#    'a': 0.10954063604240283,
#    'u': 0.028268551236749116,
#    'e': 0.3745583038869258,
#    'r': 0.1166077738515901,
#    'y': 0.007067137809187279,
#    'n': 0.0035335689045936395,
#    'c': 0.0035335689045936395},
#   '%%wh': {'a': 0.09090909090909091,
#    'o': 0.2727272727272727,
#    'e': 0.36363636363636365,
#    'i': 0.22727272727272727,
#    'y': 0.045454545454545456},
#   '%wha': {'t': 1.0},
#   '%%hi': {'s': 0.2222222222222222,
#    'm': 0.07407407407407407,
#    'g': 0.18518518518518517,
#    't': 0.1111111111111111,
#    'l': 0.1111111111111111,
#    'd': 0.1111111111111111,
#    'r': 0.1111111111111111,
#    'p': 0.037037037037037035,
#    'v': 0.037037037037037035},
#   '%%fr': {'o': 0.10714285714285714,
#    'e': 0.2857142857142857,
#    'i': 0.17857142857142858,
#    'a': 0.32142857142857145,
#    'u': 0.10714285714285714},
#   '%fro': {'m': 0.3333333333333333,
#    'n': 0.3333333333333333,
#    'z': 0.3333333333333333},
#   '%%%s': {'h': 0.08872458410351201,
#    'o': 0.08687615526802218,
#    'a': 0.07208872458410351,
#    'e': 0.14972273567467653,
#    't': 0.19963031423290203,
#    'u': 0.12199630314232902,
#    'c': 0.051756007393715345,
#    'i': 0.08687615526802218,
#    'y': 0.009242144177449169,
#    'm': 0.022181146025878003,
#    'p': 0.06284658040665435,
#    'l': 0.022181146025878003,
#    'k': 0.009242144177449169,
#    'w': 0.012939001848428836,
#    'q': 0.0018484288354898336,
#    'n': 0.0018484288354898336},
#   '%%sh': {'e': 0.14583333333333334,
#    'o': 0.4791666666666667,
#    'a': 0.25,
#    'i': 0.10416666666666667,
#    'u': 0.020833333333333332},
#   '%%%m': {'y': 0.016194331983805668,
#    'e': 0.18218623481781376,
#    'o': 0.20242914979757085,
#    'a': 0.340080971659919,
#    'u': 0.05668016194331984,
#    'i': 0.17408906882591094,
#    'r': 0.008097165991902834,
#    's': 0.004048582995951417,
#    'm': 0.008097165991902834,
#    'c': 0.004048582995951417,
#    'g': 0.004048582995951417},
#   '%%al': {'l': 0.3125,
#    's': 0.03125,
#    'w': 0.03125,
#    'r': 0.0625,
#    'm': 0.03125,
#    'o': 0.09375,
#    't': 0.0625,
#    'i': 0.09375,
#    'b': 0.03125,
#    'c': 0.03125,
#    'e': 0.09375,
#    'a': 0.125},
#   'ther': {'e': 0.23076923076923078,
#    's': 0.3076923076923077,
#    'w': 0.07692307692307693,
#    'n': 0.15384615384615385,
#    'a': 0.07692307692307693,
#    'm': 0.07692307692307693,
#    'i': 0.07692307692307693},
#   '%%he': {'r': 0.18421052631578946,
#    'l': 0.23684210526315788,
#    'a': 0.47368421052631576,
#    'y': 0.02631578947368421,
#    'n': 0.05263157894736842,
#    'i': 0.02631578947368421},
#   '%%ab': {'o': 0.21428571428571427,
#    'l': 0.07142857142857142,
#    'i': 0.14285714285714285,
#    's': 0.2857142857142857,
#    'u': 0.07142857142857142,
#    'c': 0.07142857142857142,
#    'a': 0.07142857142857142,
#    'r': 0.07142857142857142},
#   '%abo': {'u': 0.3333333333333333,
#    'v': 0.3333333333333333,
#    'r': 0.3333333333333333},
#   'abou': {'t': 1.0},
#   '%%on': {'e': 0.2857142857142857,
#    'l': 0.2857142857142857,
#    'c': 0.14285714285714285,
#    't': 0.14285714285714285,
#    'g': 0.14285714285714285},
#   '%you': {'r': 0.5, 'n': 0.3333333333333333, 't': 0.16666666666666666},
#   '%%%c': {'a': 0.1442687747035573,
#    'o': 0.45652173913043476,
#    'h': 0.14031620553359683,
#    'i': 0.02766798418972332,
#    'e': 0.03162055335968379,
#    'l': 0.08300395256916997,
#    'u': 0.037549407114624504,
#    'r': 0.07312252964426877,
#    'n': 0.001976284584980237,
#    'y': 0.001976284584980237,
#    'b': 0.001976284584980237},
#   '%%ca': {'n': 0.09722222222222222,
#    'm': 0.1111111111111111,
#    'l': 0.1388888888888889,
#    's': 0.05555555555555555,
#    'r': 0.2777777777777778,
#    'u': 0.06944444444444445,
#    'p': 0.1111111111111111,
#    't': 0.08333333333333333,
#    'b': 0.041666666666666664,
#    'k': 0.013888888888888888},
#   '%%ou': {'t': 0.5555555555555556,
#    'r': 0.3333333333333333,
#    'g': 0.1111111111111111},
#   'thei': {'r': 1.0},
#   '%%we': {'r': 0.037037037037037035,
#    'l': 0.14814814814814814,
#    'n': 0.037037037037037035,
#    'e': 0.14814814814814814,
#    's': 0.07407407407407407,
#    'i': 0.07407407407407407,
#    'b': 0.07407407407407407,
#    'a': 0.2962962962962963,
#    'd': 0.07407407407407407,
#    't': 0.037037037037037035},
#   '%wer': {'e': 1.0},
#   '%%%l': {'i': 0.25773195876288657,
#    'o': 0.23195876288659795,
#    'e': 0.22164948453608246,
#    'a': 0.24742268041237114,
#    'u': 0.030927835051546393,
#    'y': 0.005154639175257732,
#    't': 0.005154639175257732},
#   '%%li': {'k': 0.08,
#    't': 0.12,
#    'f': 0.1,
#    'v': 0.08,
#    'n': 0.14,
#    'g': 0.04,
#    's': 0.14,
#    'm': 0.08,
#    'e': 0.08,
#    'b': 0.08,
#    'p': 0.02,
#    'c': 0.02,
#    'q': 0.02},
#   '%lik': {'e': 1.0},
#   '%%%j': {'u': 0.22666666666666666,
#    'o': 0.3466666666666667,
#    'a': 0.21333333333333335,
#    'e': 0.17333333333333334,
#    'i': 0.02666666666666667,
#    'r': 0.013333333333333334},
#   '%%ju': {'s': 0.23529411764705882,
#    'd': 0.29411764705882354,
#    'n': 0.11764705882352941,
#    'l': 0.11764705882352941,
#    'r': 0.058823529411764705,
#    'm': 0.11764705882352941,
#    'i': 0.058823529411764705},
#   '%jus': {'t': 1.0},
#   '%%wo': {'u': 0.08571428571428572,
#    'r': 0.5428571428571428,
#    'm': 0.05714285714285714,
#    'n': 0.14285714285714285,
#    'w': 0.02857142857142857,
#    'o': 0.08571428571428572,
#    'l': 0.02857142857142857,
#    'k': 0.02857142857142857},
#   '%wou': {'l': 0.3333333333333333, 'n': 0.6666666666666666},
#   'woul': {'d': 1.0},
#   '%%%u': {'p': 0.1016949152542373,
#    's': 0.1864406779661017,
#    'n': 0.5254237288135594,
#    'h': 0.03389830508474576,
#    'm': 0.01694915254237288,
#    'l': 0.03389830508474576,
#    'r': 0.03389830508474576,
#    'g': 0.01694915254237288,
#    'k': 0.01694915254237288,
#    't': 0.03389830508474576},
#   '%whe': {'n': 0.25, 'r': 0.375, 't': 0.125, 'e': 0.25},
#   '%%mo': {'r': 0.14,
#    's': 0.06,
#    'n': 0.16,
#    't': 0.1,
#    'v': 0.16,
#    'm': 0.08,
#    'd': 0.12,
#    'u': 0.1,
#    'o': 0.06,
#    'b': 0.02},
#   '%mor': {'e': 0.2857142857142857,
#    'n': 0.14285714285714285,
#    'a': 0.14285714285714285,
#    'g': 0.14285714285714285,
#    't': 0.14285714285714285,
#    'r': 0.14285714285714285},
#   '%wil': {'l': 0.5714285714285714,
#    'd': 0.2857142857142857,
#    's': 0.14285714285714285},
#   '%%%k': {'n': 0.24444444444444444,
#    'i': 0.35555555555555557,
#    'e': 0.26666666666666666,
#    'o': 0.06666666666666667,
#    'a': 0.06666666666666667},
#   '%%kn': {'o': 0.6363636363636364,
#    'e': 0.2727272727272727,
#    'i': 0.09090909090909091},
#   '%kno': {'w': 0.7142857142857143, 'c': 0.2857142857142857},
#   '%%sa': {'i': 0.05128205128205128,
#    'y': 0.07692307692307693,
#    'm': 0.10256410256410256,
#    'w': 0.02564102564102564,
#    'n': 0.1282051282051282,
#    'v': 0.10256410256410256,
#    'f': 0.05128205128205128,
#    't': 0.1282051282051282,
#    'l': 0.1282051282051282,
#    'd': 0.05128205128205128,
#    'r': 0.02564102564102564,
#    'k': 0.02564102564102564,
#    'u': 0.05128205128205128,
#    'c': 0.05128205128205128},
#   '%sai': {'d': 0.5, 'n': 0.5},
#   '%%di': {'d': 0.014285714285714285,
#    'f': 0.1,
#    'r': 0.12857142857142856,
#    'e': 0.05714285714285714,
#    's': 0.4714285714285714,
#    'n': 0.02857142857142857,
#    'v': 0.1,
#    'g': 0.02857142857142857,
#    'c': 0.014285714285714285,
#    'a': 0.05714285714285714},
#   '%%be': {'e': 0.05555555555555555,
#    'c': 0.09259259259259259,
#    'f': 0.018518518518518517,
#    'i': 0.037037037037037035,
#    't': 0.05555555555555555,
#    's': 0.05555555555555555,
#    'l': 0.16666666666666666,
#    'h': 0.09259259259259259,
#    'g': 0.09259259259259259,
#    'y': 0.018518518518518517,
#    'a': 0.16666666666666666,
#    'd': 0.037037037037037035,
#    'n': 0.1111111111111111},
#   '%bee': {'n': 0.3333333333333333,
#    'r': 0.3333333333333333,
#    'f': 0.3333333333333333},
#   '%%%p': {'e': 0.10852713178294573,
#    'r': 0.3281653746770026,
#    'u': 0.06201550387596899,
#    'a': 0.18604651162790697,
#    'l': 0.07751937984496124,
#    'o': 0.13178294573643412,
#    'h': 0.05167958656330749,
#    'i': 0.041343669250646,
#    'm': 0.002583979328165375,
#    's': 0.00516795865633075,
#    'p': 0.002583979328165375,
#    'c': 0.002583979328165375},
#   '%%pe': {'o': 0.047619047619047616,
#    'r': 0.6428571428571429,
#    'a': 0.07142857142857142,
#    't': 0.07142857142857142,
#    'p': 0.023809523809523808,
#    'n': 0.09523809523809523,
#    'e': 0.047619047619047616},
#   '%peo': {'p': 1.0},
#   'peop': {'l': 1.0},
#   'eopl': {'e': 1.0},
#   '%%%g': {'e': 0.16,
#    'o': 0.18666666666666668,
#    'r': 0.24,
#    'i': 0.07333333333333333,
#    'a': 0.16,
#    'u': 0.11333333333333333,
#    'l': 0.04666666666666667,
#    'h': 0.006666666666666667,
#    'y': 0.006666666666666667,
#    'm': 0.006666666666666667},
#   '%%ge': {'t': 0.125,
#    'n': 0.6666666666666666,
#    'o': 0.08333333333333333,
#    'r': 0.08333333333333333,
#    'a': 0.041666666666666664},
#   '%%ti': {'m': 0.2222222222222222,
#    't': 0.1111111111111111,
#    'n': 0.05555555555555555,
#    'r': 0.05555555555555555,
#    'g': 0.05555555555555555,
#    'l': 0.05555555555555555,
#    'e': 0.16666666666666666,
#    'p': 0.1111111111111111,
#    'c': 0.1111111111111111,
#    's': 0.05555555555555555},
#   '%tim': {'e': 0.6666666666666666, 'i': 0.3333333333333333},
#   '%%so': {'m': 0.17391304347826086,
#    'c': 0.08695652173913043,
#    'r': 0.06521739130434782,
#    'n': 0.08695652173913043,
#    'u': 0.21739130434782608,
#    'o': 0.043478260869565216,
#    'l': 0.1956521739130435,
#    'f': 0.043478260869565216,
#    'v': 0.021739130434782608,
#    'i': 0.021739130434782608,
#    '-': 0.021739130434782608,
#    'p': 0.021739130434782608},
#   '%som': {'e': 1.0},
#   '%%ho': {'w': 0.07142857142857142,
#    'm': 0.07142857142857142,
#    'u': 0.16666666666666666,
#    'p': 0.11904761904761904,
#    'l': 0.19047619047619047,
#    't': 0.047619047619047616,
#    's': 0.07142857142857142,
#    'n': 0.11904761904761904,
#    'r': 0.11904761904761904,
#    'o': 0.023809523809523808},
#   '%whi': {'c': 0.2, 'l': 0.2, 't': 0.4, 's': 0.2},
#   'whic': {'h': 1.0},
#   '%%co': {'u': 0.09130434782608696,
#    'm': 0.24782608695652175,
#    'n': 0.4043478260869565,
#    'l': 0.07391304347826087,
#    's': 0.008695652173913044,
#    'v': 0.021739130434782608,
#    'o': 0.02608695652173913,
#    'a': 0.030434782608695653,
#    'f': 0.004347826086956522,
#    'r': 0.05217391304347826,
#    'd': 0.004347826086956522,
#    'p': 0.021739130434782608,
#    'g': 0.004347826086956522,
#    't': 0.004347826086956522,
#    'h': 0.004347826086956522},
#   '%cou': {'l': 0.047619047619047616,
#    'n': 0.5238095238095238,
#    'r': 0.23809523809523808,
#    'p': 0.09523809523809523,
#    's': 0.047619047619047616,
#    'c': 0.047619047619047616},
#   'coul': {'d': 1.0},
#   'thin': {'k': 0.2727272727272727, 'g': 0.7272727272727273},
#   '%%in': {'t': 0.26495726495726496,
#    'f': 0.05982905982905983,
#    'c': 0.13675213675213677,
#    's': 0.1623931623931624,
#    'd': 0.13675213675213677,
#    'v': 0.13675213675213677,
#    'i': 0.02564102564102564,
#    'j': 0.02564102564102564,
#    'n': 0.02564102564102564,
#    'g': 0.008547008547008548,
#    'e': 0.008547008547008548,
#    'p': 0.008547008547008548},
#   '%int': {'o': 0.03333333333333333, 'e': 0.8666666666666667, 'r': 0.1},
#   '%%ot': {'h': 1.0},
#   '%oth': {'e': 1.0},
#   'othe': {'r': 0.9090909090909091, 's': 0.09090909090909091},
#   '%%%r': {'i': 0.05901639344262295,
#    'e': 0.6524590163934426,
#    'o': 0.12131147540983607,
#    'u': 0.03934426229508197,
#    'a': 0.12131147540983607,
#    'y': 0.003278688524590164,
#    'h': 0.003278688524590164},
#   '%%ri': {'g': 0.1111111111111111,
#    's': 0.2222222222222222,
#    'v': 0.1111111111111111,
#    'c': 0.2222222222222222,
#    'd': 0.2222222222222222,
#    'n': 0.1111111111111111},
#   '%rig': {'h': 1.0},
#   'righ': {'t': 1.0},
#   '%her': {'e': 0.16666666666666666,
#    's': 0.3333333333333333,
#    'o': 0.3333333333333333,
#    'i': 0.16666666666666666},
#   '%wel': {'l': 0.5, 'c': 0.25, 'f': 0.25},
#   '%%ne': {'w': 0.1724137931034483,
#    'e': 0.10344827586206896,
#    'v': 0.06896551724137931,
#    'x': 0.034482758620689655,
#    'a': 0.10344827586206896,
#    'c': 0.10344827586206896,
#    't': 0.10344827586206896,
#    'i': 0.1724137931034483,
#    'g': 0.06896551724137931,
#    'r': 0.034482758620689655,
#    'l': 0.034482758620689655},
#   '%bec': {'a': 0.4, 'o': 0.6},
#   'beca': {'u': 0.5, 'm': 0.5},
#   'ecau': {'s': 1.0},
#   'caus': {'e': 0.8, 'i': 0.2},
#   '%%se': {'e': 0.14814814814814814,
#    'c': 0.14814814814814814,
#    't': 0.08641975308641975,
#    'v': 0.037037037037037035,
#    'n': 0.13580246913580246,
#    'r': 0.12345679012345678,
#    'a': 0.1111111111111111,
#    'x': 0.037037037037037035,
#    'l': 0.07407407407407407,
#    'p': 0.04938271604938271,
#    's': 0.024691358024691357,
#    'q': 0.012345679012345678,
#    'g': 0.012345679012345678},
#   '%%ba': {'c': 0.1111111111111111,
#    'd': 0.044444444444444446,
#    's': 0.17777777777777778,
#    'b': 0.044444444444444446,
#    'n': 0.13333333333333333,
#    'l': 0.13333333333333333,
#    'r': 0.15555555555555556,
#    't': 0.06666666666666667,
#    'g': 0.06666666666666667,
#    'y': 0.022222222222222223,
#    'k': 0.044444444444444446},
#   '%bac': {'k': 0.8, 't': 0.2},
#   '%onl': {'y': 0.5, 'i': 0.5},
#   'thes': {'e': 1.0},
#   '%%ov': {'e': 1.0},
#   '%ove': {'r': 0.8571428571428571, 'n': 0.14285714285714285},
#   '%%go': {'i': 0.037037037037037035,
#    'o': 0.18518518518518517,
#    't': 0.07407407407407407,
#    'd': 0.1111111111111111,
#    'v': 0.14814814814814814,
#    'n': 0.07407407407407407,
#    'e': 0.037037037037037035,
#    'a': 0.07407407407407407,
#    'l': 0.1111111111111111,
#    'p': 0.037037037037037035,
#    'r': 0.07407407407407407,
#    's': 0.037037037037037035},
#   '%goi': {'n': 1.0},
#   'goin': {'g': 1.0},
#   '%als': {'o': 1.0},
#   '%%tw': {'o': 0.16666666666666666, 'i': 0.5, 'e': 0.3333333333333333},
#   '%%fi': {'r': 0.14285714285714285,
#    'n': 0.2653061224489796,
#    'v': 0.02040816326530612,
#    'g': 0.12244897959183673,
#    'e': 0.04081632653061224,
#    'l': 0.16326530612244897,
#    's': 0.061224489795918366,
#    't': 0.04081632653061224,
#    'x': 0.04081632653061224,
#    'f': 0.061224489795918366,
#    'c': 0.02040816326530612,
#    'b': 0.02040816326530612},
#   '%fir': {'s': 0.14285714285714285,
#    'e': 0.42857142857142855,
#    'm': 0.2857142857142857,
#    'i': 0.14285714285714285},
#   'firs': {'t': 1.0},
#   '%%it': {'s': 0.3333333333333333,
#    'e': 0.3333333333333333,
#    'a': 0.3333333333333333},
#   '%%%e': {'v': 0.07509881422924901,
#    'a': 0.07114624505928854,
#    'n': 0.17391304347826086,
#    'l': 0.06719367588932806,
#    'y': 0.007905138339920948,
#    'x': 0.28063241106719367,
#    'd': 0.04743083003952569,
#    'i': 0.007905138339920948,
#    's': 0.05138339920948617,
#    'c': 0.011857707509881422,
#    'f': 0.03557312252964427,
#    't': 0.023715415019762844,
#    'u': 0.007905138339920948,
#    'm': 0.07905138339920949,
#    'q': 0.019762845849802372,
#    'r': 0.015810276679841896,
#    '-': 0.003952569169960474,
#    'p': 0.007905138339920948,
#    'g': 0.011857707509881422},
#   '%%ev': {'e': 0.6842105263157895,
#    'i': 0.15789473684210525,
#    'o': 0.05263157894736842,
#    'a': 0.10526315789473684},
#   '%eve': {'n': 0.4166666666666667, 'r': 0.5833333333333334},
#   '%goo': {'d': 0.8, 'g': 0.2},
#   'wher': {'e': 1.0},
#   '%%af': {'t': 0.15384615384615385,
#    'r': 0.3076923076923077,
#    'f': 0.46153846153846156,
#    'g': 0.07692307692307693},
#   '%aft': {'e': 1.0},
#   'afte': {'r': 1.0},
#   '%wan': {'t': 1.0},
#   '%%%v': {'e': 0.1527777777777778,
#    'i': 0.4305555555555556,
#    'o': 0.19444444444444445,
#    'a': 0.19444444444444445,
#    's': 0.013888888888888888,
#    'u': 0.013888888888888888},
#   '%%ve': {'r': 0.36363636363636365,
#    'h': 0.18181818181818182,
#    't': 0.18181818181818182,
#    'g': 0.18181818181818182,
#    'n': 0.09090909090909091},
#   '%ver': {'y': 0.25, 's': 0.75},
#   '%%ye': {'a': 0.375, 's': 0.25, 't': 0.125, 'l': 0.125, 'p': 0.125},
#   '%yea': {'r': 0.6666666666666666, 'h': 0.3333333333333333},
#   'year': {'s': 1.0},
#   '%%ma': {'k': 0.04819277108433735,
#    'n': 0.1566265060240964,
#    'y': 0.03614457831325301,
#    'd': 0.024096385542168676,
#    't': 0.12048192771084337,
#    'j': 0.024096385542168676,
#    'r': 0.24096385542168675,
#    'i': 0.10843373493975904,
#    'l': 0.03614457831325301,
#    's': 0.060240963855421686,
#    'c': 0.03614457831325301,
#    'g': 0.03614457831325301,
#    'p': 0.024096385542168676,
#    'x': 0.024096385542168676,
#    'm': 0.012048192771084338,
#    "'": 0.012048192771084338},
#   '%mak': {'e': 0.75, 'i': 0.25},
#   '%mos': {'t': 0.6666666666666666, 'c': 0.3333333333333333},
#   '%%mu': {'c': 0.07142857142857142,
#    's': 0.5714285714285714,
#    'r': 0.21428571428571427,
#    'l': 0.07142857142857142,
#    't': 0.07142857142857142},
#   '%muc': {'h': 1.0},
#   '%%do': {'e': 0.03333333333333333,
#    'w': 0.06666666666666667,
#    'i': 0.03333333333333333,
#    'n': 0.13333333333333333,
#    'o': 0.06666666666666667,
#    'c': 0.23333333333333334,
#    'g': 0.06666666666666667,
#    'l': 0.06666666666666667,
#    'u': 0.13333333333333333,
#    'm': 0.1,
#    'z': 0.06666666666666667},
#   '%doe': {'s': 1.0},
#   '%tho': {'s': 0.125, 'u': 0.625, 'm': 0.25},
#   'thos': {'e': 1.0},
#   '%dow': {'n': 1.0},
#   '%sho': {'u': 0.13043478260869565,
#    'w': 0.2608695652173913,
#    'r': 0.13043478260869565,
#    't': 0.08695652173913043,
#    'o': 0.13043478260869565,
#    'p': 0.13043478260869565,
#    'e': 0.043478260869565216,
#    'c': 0.08695652173913043},
#   'shou': {'l': 1.0},
#   'houl': {'d': 1.0},
#   '%com': {'e': 0.05263157894736842,
#    'i': 0.03508771929824561,
#    'p': 0.45614035087719296,
#    'm': 0.3508771929824561,
#    'f': 0.03508771929824561,
#    'b': 0.07017543859649122},
#   '%man': {'y': 0.08333333333333333,
#    'a': 0.5,
#    'n': 0.08333333333333333,
#    'h': 0.08333333333333333,
#    'u': 0.25},
#   '%%re': {'a': 0.1111111111111111,
#    's': 0.16161616161616163,
#    'm': 0.0707070707070707,
#    'p': 0.13636363636363635,
#    'd': 0.025252525252525252,
#    'c': 0.10606060606060606,
#    'l': 0.09090909090909091,
#    't': 0.03535353535353535,
#    'v': 0.050505050505050504,
#    'q': 0.04040404040404041,
#    'g': 0.08080808080808081,
#    'f': 0.07575757575757576,
#    'n': 0.005050505050505051,
#    'j': 0.005050505050505051,
#    'w': 0.005050505050505051},
#   '%rea': {'l': 0.2727272727272727,
#    'd': 0.2727272727272727,
#    's': 0.13636363636363635,
#    'c': 0.22727272727272727,
#    'g': 0.045454545454545456,
#    'r': 0.045454545454545456},
#   'real': {'l': 0.2, 'i': 0.8},
#   'eall': {'y': 1.0},
#   '%%ta': {'k': 0.13793103448275862,
#    'l': 0.27586206896551724,
#    'b': 0.06896551724137931,
#    'x': 0.06896551724137931,
#    'r': 0.10344827586206896,
#    's': 0.10344827586206896,
#    'u': 0.034482758620689655,
#    'p': 0.06896551724137931,
#    'y': 0.034482758620689655,
#    'n': 0.034482758620689655,
#    'i': 0.034482758620689655,
#    'g': 0.034482758620689655},
#   '%tak': {'e': 0.75, 'i': 0.25},
#   '%thr': {'o': 0.46153846153846156, 'e': 0.5384615384615384},
#   'thro': {'u': 0.2857142857142857,
#    'w': 0.42857142857142855,
#    'o': 0.14285714285714285,
#    'a': 0.14285714285714285},
#   'hrou': {'g': 1.0},
#   'roug': {'h': 1.0},
#   '%say': {'s': 0.5, 'i': 0.5},
#   '%bef': {'o': 1.0},
#   'befo': {'r': 1.0},
#   'efor': {'e': 0.4, 'm': 0.6},
#   '%wor': {'k': 0.3157894736842105,
#    'l': 0.15789473684210525,
#    'd': 0.10526315789473684,
#    't': 0.10526315789473684,
#    's': 0.10526315789473684,
#    'r': 0.10526315789473684,
#    'e': 0.05263157894736842,
#    'n': 0.05263157894736842},
#   '%%st': {'i': 0.028037383177570093,
#    'a': 0.32710280373831774,
#    'u': 0.09345794392523364,
#    'o': 0.16822429906542055,
#    'r': 0.2616822429906542,
#    'e': 0.102803738317757,
#    'y': 0.018691588785046728},
#   '%sti': {'l': 0.3333333333333333,
#    'c': 0.3333333333333333,
#    'r': 0.3333333333333333},
#   'stil': {'l': 1.0},
#   '%%lo': {'o': 0.1111111111111111,
#    'n': 0.1111111111111111,
#    't': 0.044444444444444446,
#    'v': 0.1111111111111111,
#    's': 0.13333333333333333,
#    'c': 0.13333333333333333,
#    'w': 0.06666666666666667,
#    'r': 0.022222222222222223,
#    'u': 0.06666666666666667,
#    'a': 0.1111111111111111,
#    'g': 0.06666666666666667,
#    'b': 0.022222222222222223},
#   '%loo': {'k': 0.8, 's': 0.2},
#   'some': {'t': 0.2857142857142857,
#    'o': 0.14285714285714285,
#    'b': 0.14285714285714285,
#    'w': 0.2857142857142857,
#    'h': 0.14285714285714285},
#   'omet': {'h': 0.5, 'i': 0.5},
#   'meth': {'i': 0.3333333333333333, 'o': 0.6666666666666666},
#   'ethi': {'n': 0.3333333333333333, 'c': 0.6666666666666666},
#   '%%to': {'o': 0.11428571428571428,
#    'd': 0.05714285714285714,
#    'l': 0.02857142857142857,
#    'g': 0.02857142857142857,
#    'p': 0.08571428571428572,
#    'w': 0.14285714285714285,
#    'n': 0.14285714285714285,
#    't': 0.05714285714285714,
#    'm': 0.08571428571428572,
#    'u': 0.17142857142857143,
#    'b': 0.02857142857142857,
#    'y': 0.02857142857142857,
#    'i': 0.02857142857142857},
#   '%nee': {'d': 1.0},
#   '%%le': {'t': 0.11904761904761904,
#    'f': 0.023809523809523808,
#    's': 0.07142857142857142,
#    'a': 0.40476190476190477,
#    'v': 0.047619047619047616,
#    'd': 0.023809523809523808,
#    'g': 0.21428571428571427,
#    'e': 0.023809523809523808,
#    'n': 0.023809523809523808,
#    'w': 0.023809523809523808,
#    'm': 0.023809523809523808},
#   '%lit': {'t': 0.2, 'e': 0.8},
#   'litt': {'l': 1.0},
#   'ittl': {'e': 1.0},
#   '%bei': {'n': 1.0},
#   'bein': {'g': 1.0},
#   '%%of': {'f': 0.9333333333333333, 't': 0.06666666666666667},
#   '%%da': {'y': 0.06666666666666667,
#    't': 0.16666666666666666,
#    'v': 0.1,
#    'd': 0.06666666666666667,
#    'r': 0.1,
#    'u': 0.06666666666666667,
#    'i': 0.03333333333333333,
#    'm': 0.1,
#    'n': 0.23333333333333334,
#    'l': 0.03333333333333333,
#    'w': 0.03333333333333333},
#   '%nev': {'e': 1.0},
#   'neve': {'r': 1.0},
#   '%%la': {'s': 0.0425531914893617,
#    't': 0.1276595744680851,
#    'w': 0.14893617021276595,
#    'r': 0.10638297872340426,
#    'n': 0.1702127659574468,
#    'c': 0.02127659574468085,
#    'd': 0.0425531914893617,
#    'b': 0.0851063829787234,
#    'k': 0.02127659574468085,
#    'y': 0.0425531914893617,
#    'u': 0.1702127659574468,
#    'i': 0.02127659574468085},
#   '%las': {'t': 1.0},
#   '%lif': {'e': 0.6, 't': 0.4},
#   '%%su': {'c': 0.07575757575757576,
#    'r': 0.22727272727272727,
#    'p': 0.19696969696969696,
#    'm': 0.06060606060606061,
#    'b': 0.09090909090909091,
#    'n': 0.030303030303030304,
#    'd': 0.030303030303030304,
#    'g': 0.10606060606060606,
#    'i': 0.045454545454545456,
#    's': 0.06060606060606061,
#    'f': 0.06060606060606061,
#    'e': 0.015151515151515152},
#   '%suc': {'h': 0.2, 'c': 0.8},
#   'worl': {'d': 1.0},
#   '%mad': {'e': 1.0},
#   'whil': {'e': 1.0},
#   '%aro': {'u': 1.0},
#   'arou': {'n': 1.0},
#   'roun': {'d': 1.0},
#   'hing': {'s': 0.5, 't': 0.5},
#   '%%ow': {'n': 0.8571428571428571, 'e': 0.14285714285714285},
#   '%sam': {'e': 0.3333333333333333, 'p': 0.6666666666666666},
#   '%ano': {'t': 0.5, 'n': 0.5},
#   'anot': {'h': 1.0},
#   'noth': {'e': 0.5, 'i': 0.5},
#   '%lon': {'g': 0.6, 'd': 0.2, 'e': 0.2},
#   '%%bo': {'t': 0.10810810810810811,
#    'o': 0.13513513513513514,
#    'd': 0.05405405405405406,
#    'y': 0.08108108108108109,
#    'a': 0.08108108108108109,
#    'x': 0.05405405405405406,
#    'r': 0.10810810810810811,
#    'b': 0.05405405405405406,
#    'u': 0.08108108108108109,
#    'w': 0.05405405405405406,
#    's': 0.05405405405405406,
#    'n': 0.10810810810810811,
#    'm': 0.02702702702702703},
#   '%bot': {'h': 0.5, 't': 0.5},
#   '%%us': {'e': 0.6, 'i': 0.1, 'u': 0.2, 'a': 0.1},
#   '%sta': {'t': 0.2857142857142857,
#    'r': 0.22857142857142856,
#    'y': 0.08571428571428572,
#    'n': 0.17142857142857143,
#    'f': 0.02857142857142857,
#    'g': 0.05714285714285714,
#    'b': 0.05714285714285714,
#    'd': 0.02857142857142857,
#    'i': 0.02857142857142857,
#    'k': 0.02857142857142857},
#   'stat': {'e': 0.5454545454545454,
#    'u': 0.09090909090909091,
#    'i': 0.36363636363636365},
#   'thre': {'e': 0.14285714285714285,
#    'a': 0.7142857142857143,
#    'w': 0.14285714285714285},
#   '%bet': {'w': 0.5, 't': 0.5},
#   'betw': {'e': 1.0},
#   'etwe': {'e': 1.0},
#   'twee': {'n': 1.0},
#   'ever': {'y': 0.6, 'a': 0.1, 'e': 0.1, 't': 0.1, 's': 0.1},
#   '%%gr': {'e': 0.2222222222222222, 'o': 0.2777777777777778, 'a': 0.5},
#   '%gre': {'a': 0.5, 'e': 0.25, 'w': 0.125, 'g': 0.125},
#   'grea': {'t': 1.0},
#   '%hom': {'e': 1.0},
#   '%%ea': {'c': 0.05555555555555555,
#    'r': 0.4444444444444444,
#    's': 0.3333333333333333,
#    't': 0.1111111111111111,
#    'g': 0.05555555555555555},
#   '%eac': {'h': 1.0},
#   '%%ag': {'a': 0.11764705882352941,
#    'o': 0.058823529411764705,
#    'e': 0.4117647058823529,
#    'r': 0.29411764705882354,
#    'g': 0.058823529411764705,
#    'i': 0.058823529411764705},
#   '%aga': {'i': 1.0},
#   'agai': {'n': 1.0},
#   '%%te': {'l': 0.09803921568627451,
#    'a': 0.19607843137254902,
#    's': 0.09803921568627451,
#    'r': 0.17647058823529413,
#    'c': 0.13725490196078433,
#    'x': 0.058823529411764705,
#    'n': 0.09803921568627451,
#    'm': 0.0784313725490196,
#    'e': 0.0392156862745098,
#    'd': 0.0196078431372549},
#   '%tel': {'l': 0.6, 'e': 0.4},
#   '%hel': {'p': 0.5555555555555556,
#    'd': 0.1111111111111111,
#    'l': 0.2222222222222222,
#    'e': 0.1111111111111111},
#   '%%pr': {'e': 0.25196850393700787,
#    'o': 0.5196850393700787,
#    'i': 0.1732283464566929,
#    'a': 0.05511811023622047},
#   '%pre': {'s': 0.40625,
#    't': 0.0625,
#    'v': 0.125,
#    'p': 0.125,
#    'g': 0.0625,
#    'f': 0.09375,
#    'c': 0.0625,
#    'd': 0.0625},
#   'pres': {'i': 0.14814814814814814,
#    's': 0.37037037037037035,
#    'e': 0.48148148148148145},
#   'resi': {'d': 0.75, 's': 0.25},
#   'esid': {'e': 1.0},
#   'side': {'n': 0.42857142857142855,
#    'r': 0.35714285714285715,
#    's': 0.14285714285714285,
#    'b': 0.07142857142857142},
#   'iden': {'t': 0.8235294117647058, 'c': 0.17647058823529413},
#   '%%sc': {'h': 0.25,
#    'i': 0.17857142857142858,
#    'e': 0.10714285714285714,
#    'r': 0.14285714285714285,
#    'a': 0.14285714285714285,
#    'o': 0.17857142857142858},
#   '%sch': {'o': 0.5714285714285714, 'e': 0.42857142857142855},
#   'scho': {'o': 0.5, 'l': 0.5},
#   'choo': {'l': 0.5, 's': 0.5},
#   '%%mi': {'g': 0.023255813953488372,
#    'l': 0.16279069767441862,
#    'n': 0.27906976744186046,
#    'd': 0.046511627906976744,
#    'c': 0.09302325581395349,
#    's': 0.18604651162790697,
#    'k': 0.023255813953488372,
#    'x': 0.06976744186046512,
#    'r': 0.046511627906976744,
#    'a': 0.023255813953488372,
#    't': 0.046511627906976744},
#   '%mig': {'h': 1.0},
#   'migh': {'t': 1.0},
#   '%%me': {'a': 0.2727272727272727,
#    'n': 0.11363636363636363,
#    'm': 0.13636363636363635,
#    'd': 0.11363636363636363,
#    'e': 0.09090909090909091,
#    't': 0.09090909090909091,
#    's': 0.06818181818181818,
#    'x': 0.045454545454545456,
#    'r': 0.045454545454545456,
#    'c': 0.022727272727272728},
#   '%mea': {'n': 0.5,
#    's': 0.25,
#    't': 0.08333333333333333,
#    'l': 0.16666666666666666},
#   '%fin': {'d': 0.3076923076923077,
#    'a': 0.3076923076923077,
#    'e': 0.07692307692307693,
#    'i': 0.15384615384615385,
#    'g': 0.15384615384615385},
#   '%hou': {'s': 0.7142857142857143, 'r': 0.2857142857142857},
#   'hous': {'e': 0.42857142857142855,
#    'a': 0.2857142857142857,
#    't': 0.14285714285714285,
#    'i': 0.14285714285714285},
#   '%%pu': {'t': 0.125,
#    'b': 0.20833333333333334,
#    'l': 0.16666666666666666,
#    'r': 0.2916666666666667,
#    's': 0.125,
#    'n': 0.08333333333333333},
#   '%lov': {'e': 0.8, 'i': 0.2},
#   'bett': {'e': 1.0},
#   'ette': {'r': 1.0},
#   '%%si': {'n': 0.14893617021276595,
#    'd': 0.06382978723404255,
#    'x': 0.0425531914893617,
#    'm': 0.14893617021276595,
#    't': 0.14893617021276595,
#    'r': 0.02127659574468085,
#    'g': 0.2553191489361702,
#    'z': 0.02127659574468085,
#    's': 0.0425531914893617,
#    'c': 0.02127659574468085,
#    'l': 0.0851063829787234},
#   '%sin': {'c': 0.16666666666666666,
#    'g': 0.6666666666666666,
#    'k': 0.16666666666666666},
#   'sinc': {'e': 1.0},
#   '%alw': {'a': 1.0},
#   'alwa': {'y': 1.0},
#   'lway': {'s': 1.0},
#   '%nex': {'t': 1.0},
#   '%use': {'d': 0.2, 's': 0.2, 'r': 0.4, 'f': 0.2},
#   '%%aw': {'a': 0.75, 'e': 0.125, 'f': 0.125},
#   '%awa': {'y': 0.16666666666666666,
#    'r': 0.6666666666666666,
#    'k': 0.16666666666666666},
#   '%%pa': {'r': 0.323943661971831,
#    's': 0.11267605633802817,
#    'y': 0.07042253521126761,
#    'p': 0.028169014084507043,
#    'u': 0.028169014084507043,
#    't': 0.09859154929577464,
#    'g': 0.028169014084507043,
#    'i': 0.11267605633802817,
#    'n': 0.056338028169014086,
#    'c': 0.07042253521126761,
#    'l': 0.056338028169014086,
#    'k': 0.014084507042253521},
#   '%par': {'t': 0.6086956521739131,
#    'e': 0.08695652173913043,
#    'k': 0.17391304347826086,
#    'i': 0.043478260869565216,
#    'a': 0.043478260869565216,
#    'l': 0.043478260869565216},
#   '%%pl': {'a': 0.7666666666666667,
#    'e': 0.16666666666666666,
#    'u': 0.03333333333333333,
#    'o': 0.03333333333333333},
#   '%pla': {'c': 0.13043478260869565,
#    'y': 0.2608695652173913,
#    'n': 0.391304347826087,
#    's': 0.043478260869565216,
#    't': 0.13043478260869565,
#    'i': 0.043478260869565216},
#   'plac': {'e': 1.0},
#   '%%fe': {'w': 0.07142857142857142,
#    'e': 0.35714285714285715,
#    'l': 0.10714285714285714,
#    'd': 0.07142857142857142,
#    'a': 0.17857142857142858,
#    'm': 0.07142857142857142,
#    'b': 0.07142857142857142,
#    's': 0.03571428571428571,
#    'n': 0.03571428571428571},
#   'thou': {'g': 0.5714285714285714,
#    't': 0.14285714285714285,
#    's': 0.2857142857142857},
#   'houg': {'h': 1.0},
#   'ough': {'t': 0.7777777777777778,
#    'o': 0.1111111111111111,
#    'l': 0.1111111111111111},
#   '%%bi': {'g': 0.12,
#    't': 0.2,
#    'l': 0.2,
#    'r': 0.16,
#    'b': 0.04,
#    'k': 0.04,
#    'o': 0.08,
#    'n': 0.04,
#    's': 0.04,
#    'a': 0.04,
#    'd': 0.04},
#   'gain': {'s': 0.6666666666666666, 'e': 0.3333333333333333},
#   'ains': {'t': 1.0},
#   '%%gi': {'v': 0.36363636363636365,
#    'r': 0.2727272727272727,
#    'f': 0.18181818181818182,
#    'a': 0.18181818181818182},
#   '%giv': {'e': 0.75, 'i': 0.25},
#   '%doi': {'n': 1.0},
#   'doin': {'g': 1.0},
#   '%sur': {'e': 0.13333333333333333,
#    'f': 0.06666666666666667,
#    'p': 0.26666666666666666,
#    'v': 0.3333333333333333,
#    'g': 0.06666666666666667,
#    'r': 0.13333333333333333},
#   '%bes': {'t': 0.3333333333333333, 'i': 0.6666666666666666},
#   'with': {'o': 0.5, 'i': 0.5},
#   'itho': {'u': 1.0},
#   '%wom': {'e': 0.5, 'a': 0.5},
#   'wome': {'n': 1.0},
#   '%%ch': {'i': 0.14084507042253522,
#    'a': 0.4507042253521127,
#    'u': 0.056338028169014086,
#    'e': 0.1267605633802817,
#    'o': 0.11267605633802817,
#    'r': 0.11267605633802817},
#   '%chi': {'l': 0.3, 'n': 0.2, 'e': 0.1, 'c': 0.2, 'p': 0.2},
#   'chil': {'d': 1.0},
#   'hild': {'r': 0.5, 'h': 0.5},
#   'ildr': {'e': 1.0},
#   'ldre': {'n': 1.0},
#   '%fou': {'n': 0.5714285714285714,
#    'r': 0.2857142857142857,
#    'g': 0.14285714285714285},
#   'foun': {'d': 1.0},
#   '%%fa': {'m': 0.09803921568627451,
#    'c': 0.2549019607843137,
#    'r': 0.0784313725490196,
#    't': 0.0784313725490196,
#    'l': 0.0784313725490196,
#    's': 0.0784313725490196,
#    'i': 0.13725490196078433,
#    'v': 0.0392156862745098,
#    'n': 0.09803921568627451,
#    'u': 0.0196078431372549,
#    'k': 0.0196078431372549,
#    'b': 0.0196078431372549},
#   '%fam': {'i': 0.6, 'o': 0.2, 'e': 0.2},
#   'fami': {'l': 1.0},
#   'amil': {'y': 0.3333333333333333, 'i': 0.6666666666666666},
#   '%mon': {'e': 0.125, 't': 0.375, 'd': 0.125, 'i': 0.25, 's': 0.125},
#   'mone': {'y': 1.0},
#   '%tod': {'a': 0.5, 'd': 0.5},
#   'toda': {'y': 1.0},
#   '%mus': {'t': 0.125, 'i': 0.25, 'e': 0.125, 'l': 0.25, 'c': 0.25},
#   '%tol': {'d': 1.0},
#   '%%ok': {'a': 0.5, 'l': 0.5},
#   '%oka': {'y': 1.0},
#   '%%ol': {'d': 0.5, 'y': 0.3333333333333333, 'i': 0.16666666666666666},
#   '%%am': {'e': 0.3333333333333333,
#    'o': 0.25,
#    'a': 0.16666666666666666,
#    'y': 0.08333333333333333,
#    'b': 0.16666666666666666},
#   '%ame': {'r': 0.75, 'n': 0.25},
#   'amer': {'i': 0.6666666666666666, 'a': 0.3333333333333333},
#   'meri': {'c': 1.0},
#   'eric': {'a': 1.0},
#   'rica': {'n': 0.75, 'l': 0.25},
#   '%%du': {'r': 0.125,
#    'e': 0.125,
#    't': 0.25,
#    'd': 0.125,
#    's': 0.125,
#    'k': 0.125,
#    'm': 0.125},
#   '%dur': {'i': 1.0},
#   'duri': {'n': 1.0},
#   'urin': {'g': 1.0},
#   '%%ni': {'g': 0.3333333333333333,
#    'c': 0.3333333333333333,
#    'n': 0.16666666666666666,
#    'x': 0.16666666666666666},
#   '%nig': {'h': 1.0},
#   'nigh': {'t': 1.0},
#   '%%un': {'d': 0.2,
#    't': 0.03333333333333333,
#    'i': 0.4,
#    'l': 0.1,
#    'f': 0.03333333333333333,
#    'c': 0.06666666666666667,
#    'a': 0.03333333333333333,
#    'u': 0.03333333333333333,
#    'k': 0.03333333333333333,
#    'e': 0.06666666666666667},
#   '%und': {'e': 1.0},
#   'unde': {'r': 0.6363636363636364, 'd': 0.36363636363636365},
#   '%lef': {'t': 1.0},
#   '%%po': {'i': 0.0784313725490196,
#    'w': 0.09803921568627451,
#    'l': 0.19607843137254902,
#    's': 0.23529411764705882,
#    'o': 0.0392156862745098,
#    't': 0.0784313725490196,
#    'p': 0.09803921568627451,
#    'u': 0.0392156862745098,
#    'v': 0.0196078431372549,
#    'c': 0.0196078431372549,
#    'r': 0.058823529411764705,
#    'e': 0.0392156862745098},
#   '%poi': {'n': 1.0},
#   'poin': {'t': 1.0},
#   '%%ki': {'n': 0.25,
#    'd': 0.1875,
#    'l': 0.25,
#    't': 0.0625,
#    's': 0.0625,
#    'c': 0.125,
#    'm': 0.0625},
#   '%kin': {'d': 0.5, 'g': 0.5},
#   '%dif': {'f': 1.0},
#   'diff': {'e': 0.5714285714285714, 'i': 0.42857142857142855},
#   'iffe': {'r': 1.0},
#   'ffer': {'e': 0.6, 's': 0.2, 'i': 0.2},
#   'fere': {'n': 0.7777777777777778, 'd': 0.2222222222222222},
#   'eren': {'t': 0.2857142857142857, 'c': 0.7142857142857143},
#   '%%en': {'d': 0.11627906976744186,
#    'o': 0.046511627906976744,
#    'e': 0.06976744186046512,
#    't': 0.23255813953488372,
#    'g': 0.23255813953488372,
#    'v': 0.046511627906976744,
#    'j': 0.06976744186046512,
#    's': 0.023255813953488372,
#    'f': 0.023255813953488372,
#    'c': 0.09302325581395349,
#    'h': 0.023255813953488372,
#    'a': 0.023255813953488372},
#   '%cam': {'e': 0.375, 'p': 0.625},
#   '%fee': {'l': 0.4444444444444444,
#    't': 0.1111111111111111,
#    'd': 0.3333333333333333,
#    's': 0.1111111111111111},
#   '%%ke': {'e': 0.25,
#    'y': 0.16666666666666666,
#    'p': 0.08333333333333333,
#    'v': 0.08333333333333333,
#    'n': 0.25,
#    'l': 0.08333333333333333,
#    'r': 0.08333333333333333},
#   '%kee': {'p': 1.0},
#   '%hig': {'h': 1.0},
#   'tate': {'s': 0.25, 'm': 0.5, 'd': 0.25},
#   '%eno': {'u': 0.5, 'r': 0.5},
#   'enou': {'g': 1.0},
#   'noug': {'h': 1.0},
#   '%gov': {'e': 1.0},
#   'gove': {'r': 1.0},
#   'over': {'n': 0.2222222222222222,
#    'a': 0.1111111111111111,
#    'e': 0.1111111111111111,
#    't': 0.05555555555555555,
#    'y': 0.1111111111111111,
#    'i': 0.05555555555555555,
#    's': 0.2222222222222222,
#    'c': 0.05555555555555555,
#    'w': 0.05555555555555555},
#   'vern': {'m': 0.5, 'o': 0.25, 'i': 0.25},
#   'ernm': {'e': 1.0},
#   'rnme': {'n': 1.0},
#   'nmen': {'t': 1.0},
#   '%any': {'t': 0.16666666666666666,
#    'o': 0.16666666666666666,
#    'w': 0.3333333333333333,
#    'b': 0.16666666666666666,
#    'm': 0.16666666666666666},
#   'anyt': {'h': 1.0},
#   'nyth': {'i': 1.0},
#   'ythi': {'n': 1.0},
#   '%not': {'h': 0.14285714285714285,
#    'e': 0.42857142857142855,
#    'i': 0.42857142857142855},
#   'othi': {'n': 1.0},
#   '%stu': {'d': 0.7, 'f': 0.1, 'p': 0.1, 'c': 0.1},
#   'stud': {'e': 0.2857142857142857,
#    'y': 0.2857142857142857,
#    'i': 0.42857142857142855},
#   'tude': {'n': 0.6666666666666666, 's': 0.3333333333333333},
#   'uden': {'t': 1.0},
#   'dent': {'s': 0.4, 'i': 0.6},
#   '%unt': {'i': 1.0},
#   'unti': {'l': 0.2, 'n': 0.6, 'e': 0.2},
#   'coun': {'t': 0.8, 'c': 0.06666666666666667, 's': 0.13333333333333333},
#   'ount': {'r': 0.15384615384615385,
#    'y': 0.07692307692307693,
#    'a': 0.15384615384615385,
#    's': 0.23076923076923078,
#    'e': 0.15384615384615385,
#    'i': 0.23076923076923078},
#   'untr': {'y': 0.5, 'i': 0.5},
#   '%wen': {'t': 1.0},
#   '%%ci': {'t': 0.35714285714285715,
#    'v': 0.21428571428571427,
#    'r': 0.2857142857142857,
#    'a': 0.07142857142857142,
#    'g': 0.07142857142857142},
#   '%cit': {'y': 0.2, 'i': 0.6, 'e': 0.2},
#   '%bel': {'i': 0.5555555555555556,
#    'o': 0.2222222222222222,
#    'l': 0.1111111111111111,
#    't': 0.1111111111111111},
#   'beli': {'e': 1.0},
#   'elie': {'v': 0.5, 'f': 0.5},
#   'liev': {'e': 1.0},
#   '%onc': {'e': 1.0},
#   '%may': {'b': 0.5, 'o': 0.5},
#   'mayb': {'e': 1.0},
#   '%pub': {'l': 1.0},
#   'publ': {'i': 1.0},
#   'ubli': {'c': 0.75, 's': 0.25},
#   '%cal': {'l': 0.4444444444444444,
#    'i': 0.2222222222222222,
#    'm': 0.1111111111111111,
#    'o': 0.1111111111111111,
#    'c': 0.1111111111111111},
#   'call': {'e': 0.2,
#    's': 0.13333333333333333,
#    'i': 0.06666666666666667,
#    'y': 0.6},
#   'alle': {'d': 0.25,
#    'n': 0.375,
#    'r': 0.125,
#    'y': 0.0625,
#    'g': 0.125,
#    'l': 0.0625},
#   'whit': {'e': 1.0},
#   '%cas': {'e': 0.5, 'h': 0.25, 't': 0.25},
#   '%tal': {'k': 0.5, 'l': 0.125, 'e': 0.375},
#   'cour': {'s': 0.3333333333333333,
#    't': 0.2222222222222222,
#    'a': 0.4444444444444444},
#   'ours': {'e': 1.0},
#   '%per': {'c': 0.19230769230769232,
#    's': 0.2692307692307692,
#    'h': 0.038461538461538464,
#    'i': 0.07692307692307693,
#    'f': 0.2692307692307692,
#    'm': 0.11538461538461539,
#    'r': 0.038461538461538464},
#   'perc': {'e': 1.0},
#   'erce': {'n': 0.4, 'i': 0.2, 'p': 0.4},
#   'rcen': {'t': 1.0},
#   '%don': {'e': 0.3333333333333333, 'a': 0.6666666666666666},
#   'time': {'s': 1.0},
#   '%%ac': {'t': 0.36585365853658536,
#    'r': 0.04878048780487805,
#    'c': 0.36585365853658536,
#    'a': 0.04878048780487805,
#    'h': 0.07317073170731707,
#    'k': 0.04878048780487805,
#    'q': 0.024390243902439025,
#    'i': 0.024390243902439025},
#   '%act': {'u': 0.14285714285714285,
#    'i': 0.5714285714285714,
#    's': 0.07142857142857142,
#    'o': 0.14285714285714285,
#    'r': 0.07142857142857142},
#   'actu': {'a': 0.5, 'r': 0.5},
#   'ctua': {'l': 1.0},
#   'tual': {'l': 1.0},
#   'uall': {'y': 1.0},
#   '%day': {'s': 1.0},
#   '%fac': {'t': 0.38461538461538464,
#    'e': 0.3076923076923077,
#    'i': 0.23076923076923078,
#    'u': 0.07692307692307693},
#   '%too': {'k': 0.3333333333333333, 'l': 0.6666666666666666},
#   '%car': {'e': 0.2631578947368421,
#    'd': 0.10526315789473684,
#    's': 0.05263157894736842,
#    'r': 0.21052631578947367,
#    'o': 0.10526315789473684,
#    't': 0.05263157894736842,
#    'b': 0.05263157894736842,
#    'l': 0.10526315789473684,
#    'i': 0.05263157894736842},
#   '%%nu': {'m': 0.375, 'c': 0.125, 'r': 0.375, 't': 0.125},
#   '%num': {'b': 0.6666666666666666, 'e': 0.3333333333333333},
#   'numb': {'e': 1.0},
#   'umbe': {'r': 1.0},
#   '%hea': {'d': 0.2777777777777778,
#    'l': 0.2222222222222222,
#    'r': 0.2777777777777778,
#    't': 0.05555555555555555,
#    'v': 0.16666666666666666},
#   '%les': {'s': 1.0},
#   '%sec': {'o': 0.2727272727272727,
#    'u': 0.18181818181818182,
#    't': 0.2727272727272727,
#    'r': 0.2727272727272727},
#   'seco': {'n': 1.0},
#   'econ': {'d': 0.5, 'o': 0.5},
#   '%%sy': {'s': 0.4, 'm': 0.4, 'r': 0.2},
#   '%sys': {'t': 1.0},
#   'syst': {'e': 1.0},
#   'yste': {'m': 0.6666666666666666, 'r': 0.3333333333333333},
#   '%%im': {'p': 0.6538461538461539,
#    'a': 0.19230769230769232,
#    'm': 0.15384615384615385},
#   '%imp': {'o': 0.23529411764705882,
#    'a': 0.058823529411764705,
#    'r': 0.47058823529411764,
#    'l': 0.23529411764705882},
#   'impo': {'r': 0.75, 's': 0.25},
#   'mpor': {'t': 0.6, 'a': 0.4},
#   'port': {'a': 0.2222222222222222,
#    'e': 0.2777777777777778,
#    'u': 0.1111111111111111,
#    's': 0.16666666666666666,
#    'i': 0.2222222222222222},
#   'orta': {'n': 0.5, 'b': 0.3333333333333333, 't': 0.16666666666666666},
#   'rtan': {'t': 0.6666666666666666, 'c': 0.3333333333333333},
#   'omeo': {'n': 1.0},
#   'meon': {'e': 1.0},
#   '%%tr': {'y': 0.03571428571428571,
#    'i': 0.16071428571428573,
#    'u': 0.10714285714285714,
#    'a': 0.48214285714285715,
#    'e': 0.17857142857142858,
#    'o': 0.03571428571428571},
#   '%try': {'i': 1.0},
#   'tryi': {'n': 1.0},
#   'ryin': {'g': 1.0},
#   '%get': {'t': 0.5, 's': 0.5},
#   'gett': {'i': 1.0},
#   'etti': {'n': 1.0},
#   'ttin': {'g': 1.0},
#   '%cha': {'n': 0.21875,
#    'r': 0.34375,
#    'l': 0.125,
#    'i': 0.125,
#    'p': 0.03125,
#    'm': 0.09375,
#    's': 0.03125,
#    'o': 0.03125},
#   'chan': {'g': 0.5555555555555556,
#    'c': 0.2222222222222222,
#    'n': 0.1111111111111111,
#    'i': 0.1111111111111111},
#   'hang': {'e': 0.6666666666666666, 'i': 0.3333333333333333},
#   '%wee': {'k': 1.0},
#   '%how': {'e': 0.5, 'a': 0.5},
#   'howe': {'v': 0.3333333333333333,
#    'd': 0.3333333333333333,
#    'r': 0.3333333333333333},
#   'owev': {'e': 1.0},
#   'weve': {'r': 1.0},
#   '%wat': {'e': 0.4, 'c': 0.6},
#   'wate': {'r': 1.0},
#   '%bus': {'i': 0.5, 'h': 0.25, 'y': 0.25},
#   'busi': {'n': 1.0},
#   'usin': {'e': 0.3333333333333333, 'g': 0.6666666666666666},
#   'sine': {'s': 1.0},
#   'ines': {'s': 0.75, 'e': 0.25},
#   'very': {'t': 0.2, 'o': 0.2, 'b': 0.2, 'w': 0.2, 'd': 0.2},
#   'eryt': {'h': 1.0},
#   'ryth': {'i': 1.0},
#   '%%sm': {'a': 0.25,
#    'i': 0.4166666666666667,
#    'o': 0.25,
#    'e': 0.08333333333333333},
#   '%sma': {'l': 0.6666666666666666, 'r': 0.3333333333333333},
#   'smal': {'l': 1.0},
#   '%%ro': {'o': 0.13513513513513514,
#    'l': 0.13513513513513514,
#    'a': 0.05405405405405406,
#    'm': 0.10810810810810811,
#    'b': 0.13513513513513514,
#    'c': 0.05405405405405406,
#    's': 0.05405405405405406,
#    'u': 0.13513513513513514,
#    'w': 0.02702702702702703,
#    'g': 0.02702702702702703,
#    'n': 0.05405405405405406,
#    'y': 0.05405405405405406,
#    'k': 0.02702702702702703},
#   '%roo': {'m': 0.4, 'f': 0.2, 't': 0.4},
#   'want': {'e': 0.3333333333333333,
#    's': 0.3333333333333333,
#    'i': 0.3333333333333333},
#   'ante': {'d': 0.6666666666666666, 'e': 0.3333333333333333},
#   '%lea': {'s': 0.058823529411764705,
#    'v': 0.17647058823529413,
#    'd': 0.35294117647058826,
#    'r': 0.17647058823529413,
#    'g': 0.058823529411764705,
#    't': 0.058823529411764705,
#    'n': 0.11764705882352941},
#   'leas': {'t': 0.14285714285714285,
#    'e': 0.5714285714285714,
#    'u': 0.14285714285714285,
#    'a': 0.14285714285714285},
#   '%%na': {'t': 0.47368421052631576,
#    'm': 0.15789473684210525,
#    'r': 0.15789473684210525,
#    'v': 0.05263157894736842,
#    'n': 0.05263157894736842,
#    'k': 0.05263157894736842,
#    's': 0.05263157894736842},
#   '%nat': {'i': 0.5555555555555556,
#    'u': 0.3333333333333333,
#    'o': 0.1111111111111111},
#   'nati': {'o': 0.7857142857142857,
#    'v': 0.14285714285714285,
#    'n': 0.07142857142857142},
#   'atio': {'n': 1.0},
#   'tion': {'a': 0.1896551724137931,
#    's': 0.7758620689655172,
#    'e': 0.017241379310344827,
#    'w': 0.017241379310344827},
#   'iona': {'l': 1.0},
#   'than': {'k': 1.0},
#   '%sto': {'r': 0.3333333333333333,
#    'p': 0.2222222222222222,
#    'o': 0.05555555555555555,
#    'c': 0.1111111111111111,
#    'n': 0.1111111111111111,
#    'm': 0.05555555555555555,
#    'l': 0.1111111111111111},
#   'stor': {'y': 0.18181818181818182,
#    'i': 0.36363636363636365,
#    'e': 0.18181818181818182,
#    'm': 0.09090909090909091,
#    's': 0.09090909090909091,
#    'a': 0.09090909090909091},
#   '%pow': {'e': 0.8, 'd': 0.2},
# ...
#    'i': 0.38461538461538464},
#   'lita': {'r': 1.0},
#   'itar': {'y': 1.0},
#   '%rep': {'o': 0.23076923076923078,
#    'u': 0.15384615384615385,
#    'r': 0.2692307692307692,
#    'l': 0.19230769230769232,
#    'e': 0.11538461538461539,
#    'a': 0.038461538461538464},
#   'repo': {'r': 1.0},
#   'epor': {'t': 1.0},
#   '%hol': {'d': 0.375, 'e': 0.25, 'y': 0.125, 'l': 0.125, 'i': 0.125},
#   '%%sp': {'e': 0.4411764705882353,
#    'a': 0.14705882352941177,
#    'o': 0.20588235294117646,
#    'r': 0.08823529411764706,
#    'i': 0.08823529411764706,
#    'l': 0.029411764705882353},
#   '%spe': {'c': 0.3333333333333333,
#    'n': 0.2,
#    'a': 0.26666666666666666,
#    'e': 0.13333333333333333,
#    'l': 0.06666666666666667},
#   '%bab': {'y': 0.5, 'i': 0.5},
#   '%cau': {'s': 0.8, 'g': 0.2},
#   '%sou': {'t': 0.2, 'n': 0.3, 'r': 0.2, 'l': 0.1, 'g': 0.1, 'p': 0.1},
#   'sout': {'h': 1.0},
#   'ssue': {'s': 0.5, 'd': 0.5},
#   '%%ph': {'o': 0.42105263157894735,
#    'y': 0.2631578947368421,
#    'i': 0.15789473684210525,
#    'a': 0.05263157894736842,
#    'r': 0.05263157894736842,
#    'e': 0.05263157894736842},
#   '%pho': {'n': 0.25, 't': 0.75},
#   'phon': {'e': 1.0},
#   '%soo': {'n': 1.0},
#   '%nor': {'t': 0.5, 'm': 0.5},
#   'nort': {'h': 1.0},
#   '%%ec': {'o': 1.0},
#   '%eco': {'n': 1.0},
#   'cono': {'m': 1.0},
#   'onom': {'i': 0.6666666666666666, 'y': 0.3333333333333333},
#   'nomi': {'c': 0.6666666666666666, 'n': 0.3333333333333333},
#   'live': {'s': 0.2, 'd': 0.2, 'r': 0.6},
#   'coup': {'l': 1.0},
#   'oupl': {'e': 1.0},
#   '%chu': {'r': 0.5, 'c': 0.5},
#   'chur': {'c': 1.0},
#   'hurc': {'h': 1.0},
#   '%goe': {'s': 1.0},
#   '%cla': {'s': 0.45454545454545453,
#    'i': 0.36363636363636365,
#    'r': 0.09090909090909091,
#    'y': 0.09090909090909091},
#   'clas': {'s': 1.0},
#   '%dev': {'e': 0.6, 'i': 0.3, 'o': 0.1},
#   'deve': {'l': 1.0},
#   'evel': {'o': 0.75, 's': 0.125, 'a': 0.125},
#   'velo': {'p': 1.0},
#   'elop': {'m': 0.4, 'e': 0.4, 'i': 0.2},
#   'lopm': {'e': 1.0},
#   'opme': {'n': 1.0},
#   'pmen': {'t': 1.0},
#   'abov': {'e': 1.0},
#   '%fig': {'u': 0.6, 'h': 0.4},
#   'figu': {'r': 1.0},
#   'igur': {'e': 1.0},
#   'watc': {'h': 1.0},
#   '%mid': {'d': 0.5, 'n': 0.5},
#   'midd': {'l': 1.0},
#   'iddl': {'e': 1.0},
#   '%sim': {'p': 0.42857142857142855,
#    'i': 0.2857142857142857,
#    'o': 0.14285714285714285,
#    'u': 0.14285714285714285},
#   'simp': {'l': 0.6666666666666666, 's': 0.3333333333333333},
#   'impl': {'y': 0.16666666666666666,
#    'e': 0.6666666666666666,
#    'i': 0.16666666666666666},
#   'rson': {'a': 0.6, 's': 0.2, 'n': 0.2},
#   'sona': {'l': 0.75, 'b': 0.25},
#   '%run': {'n': 0.5, 's': 0.5},
#   'runn': {'i': 1.0},
#   'unni': {'n': 1.0},
#   'nnin': {'g': 1.0},
#   'eede': {'d': 1.0},
#   '%spa': {'c': 0.4, 'n': 0.2, 'i': 0.2, 'r': 0.2},
#   'spac': {'e': 1.0},
#   ...},
#  {'%%%t': 267,
#   '%%th': 56,
#   '%%%a': 359,
#   '%%an': 42,
#   '%%%o': 127,
#   '%%%i': 190,
#   '%tha': 6,
#   '%%%y': 21,
#   '%%yo': 8,
#   '%%%f': 240,
#   '%%fo': 48,
#   '%%%w': 174,
#   '%%wa': 42,
#   '%%%h': 168,
#   '%%wi': 35,
#   '%wit': 5,
#   '%thi': 10,
#   '%%%n': 96,
#   "%%n'": 1,
#   '%%%b': 247,
#   '%%ha': 38,
#   '%hav': 2,
#   '%%ar': 32,
#   '%%no': 26,
#   '%%bu': 31,
#   '%the': 16,
#   '%%%d': 283,
#   '%%wh': 22,
#   '%wha': 2,
#   '%%hi': 27,
#   '%%fr': 28,
#   '%fro': 3,
#   '%%%s': 541,
#   '%%sh': 48,
#   '%%%m': 247,
#   '%%al': 32,
#   'ther': 13,
#   '%%he': 38,
#   '%%ab': 14,
#   '%abo': 3,
#   'abou': 1,
#   '%%on': 7,
#   '%you': 6,
#   '%%%c': 506,
#   '%%ca': 72,
#   '%%ou': 9,
#   'thei': 1,
#   '%%we': 27,
#   '%wer': 1,
#   '%%%l': 194,
#   '%%li': 50,
#   '%lik': 4,
#   '%%%j': 75,
#   '%%ju': 17,
#   '%jus': 4,
#   '%%wo': 35,
#   '%wou': 3,
#   'woul': 1,
#   '%%%u': 59,
#   '%whe': 8,
#   '%%mo': 50,
#   '%mor': 7,
#   '%wil': 7,
#   '%%%k': 45,
#   '%%kn': 11,
#   '%kno': 7,
#   '%%sa': 39,
#   '%sai': 2,
#   '%%di': 70,
#   '%%be': 54,
#   '%bee': 3,
#   '%%%p': 387,
#   '%%pe': 42,
#   '%peo': 2,
#   'peop': 2,
#   'eopl': 2,
#   '%%%g': 150,
#   '%%ge': 24,
#   '%%ti': 18,
#   '%tim': 3,
#   '%%so': 46,
#   '%som': 8,
#   '%%ho': 42,
#   '%whi': 5,
#   'whic': 1,
#   '%%co': 230,
#   '%cou': 21,
#   'coul': 1,
#   'thin': 11,
#   '%%in': 117,
#   '%int': 30,
#   '%%ot': 3,
#   '%oth': 3,
#   'othe': 11,
#   '%%%r': 305,
#   '%%ri': 18,
#   '%rig': 2,
#   'righ': 6,
#   '%her': 6,
#   '%wel': 4,
#   '%%ne': 29,
#   '%bec': 5,
#   'beca': 2,
#   'ecau': 1,
#   'caus': 5,
#   '%%se': 81,
#   '%%ba': 45,
#   '%bac': 5,
#   '%onl': 2,
#   'thes': 1,
#   '%%ov': 7,
#   '%ove': 7,
#   '%%go': 27,
#   '%goi': 1,
#   'goin': 2,
#   '%als': 1,
#   '%%tw': 6,
#   '%%fi': 49,
#   '%fir': 7,
#   'firs': 1,
#   '%%it': 6,
#   '%%%e': 253,
#   '%%ev': 19,
#   '%eve': 12,
#   '%goo': 5,
#   'wher': 8,
#   '%%af': 13,
#   '%aft': 2,
#   'afte': 2,
#   '%wan': 4,
#   '%%%v': 72,
#   '%%ve': 11,
#   '%ver': 4,
#   '%%ye': 8,
#   '%yea': 3,
#   'year': 1,
#   '%%ma': 83,
#   '%mak': 4,
#   '%mos': 3,
#   '%%mu': 14,
#   '%muc': 1,
#   '%%do': 30,
#   '%doe': 1,
#   '%tho': 8,
#   'thos': 1,
#   '%dow': 2,
#   '%sho': 23,
#   'shou': 3,
#   'houl': 3,
#   '%com': 57,
#   '%man': 12,
#   '%%re': 198,
#   '%rea': 22,
#   'real': 5,
#   'eall': 1,
#   '%%ta': 29,
#   '%tak': 4,
#   '%thr': 13,
#   'thro': 7,
#   'hrou': 2,
#   'roug': 5,
#   '%say': 2,
#   '%bef': 1,
#   'befo': 1,
#   'efor': 5,
#   '%wor': 19,
#   '%%st': 107,
#   '%sti': 3,
#   'stil': 1,
#   '%%lo': 45,
#   '%loo': 5,
#   'some': 7,
#   'omet': 2,
#   'meth': 3,
#   'ethi': 3,
#   '%%to': 35,
#   '%nee': 3,
#   '%%le': 42,
#   '%lit': 5,
#   'litt': 1,
#   'ittl': 1,
#   '%bei': 2,
#   'bein': 2,
#   '%%of': 15,
#   '%%da': 30,
#   '%nev': 2,
#   'neve': 3,
#   '%%la': 47,
#   '%las': 1,
#   '%lif': 5,
#   '%%su': 66,
#   '%suc': 5,
#   'worl': 3,
#   '%mad': 1,
#   'whil': 2,
#   '%aro': 1,
#   'arou': 1,
#   'roun': 8,
#   'hing': 2,
#   '%%ow': 7,
#   '%sam': 3,
#   '%ano': 2,
#   'anot': 1,
#   'noth': 2,
#   '%lon': 5,
#   '%%bo': 37,
#   '%bot': 4,
#   '%%us': 10,
#   '%sta': 35,
#   'stat': 11,
#   'thre': 7,
#   '%bet': 2,
#   'betw': 1,
#   'etwe': 1,
#   'twee': 1,
#   'ever': 10,
#   '%%gr': 36,
#   '%gre': 8,
#   'grea': 4,
#   '%hom': 3,
#   '%%ea': 18,
#   '%eac': 1,
#   '%%ag': 17,
#   '%aga': 2,
#   'agai': 2,
#   '%%te': 51,
#   '%tel': 5,
#   '%hel': 9,
#   '%%pr': 127,
#   '%pre': 32,
#   'pres': 27,
#   'resi': 8,
#   'esid': 8,
#   'side': 14,
#   'iden': 17,
#   '%%sc': 28,
#   '%sch': 7,
#   'scho': 4,
#   'choo': 4,
#   '%%mi': 43,
#   '%mig': 1,
#   'migh': 1,
#   '%%me': 44,
#   '%mea': 12,
#   '%fin': 13,
#   '%hou': 7,
#   'hous': 7,
#   '%%pu': 24,
#   '%lov': 5,
#   'bett': 1,
#   'ette': 3,
#   '%%si': 47,
#   '%sin': 6,
#   'sinc': 1,
#   '%alw': 1,
#   'alwa': 1,
#   'lway': 1,
#   '%nex': 1,
#   '%use': 5,
#   '%%aw': 8,
#   '%awa': 6,
#   '%%pa': 71,
#   '%par': 23,
#   '%%pl': 30,
#   '%pla': 23,
#   'plac': 6,
#   '%%fe': 28,
#   'thou': 7,
#   'houg': 4,
#   'ough': 9,
#   '%%bi': 25,
#   'gain': 3,
#   'ains': 2,
#   '%%gi': 11,
#   '%giv': 4,
#   '%doi': 1,
#   'doin': 1,
#   '%sur': 15,
#   '%bes': 3,
#   'with': 2,
#   'itho': 1,
#   '%wom': 2,
#   'wome': 1,
#   '%%ch': 71,
#   '%chi': 10,
#   'chil': 3,
#   'hild': 2,
#   'ildr': 1,
#   'ldre': 1,
#   '%fou': 7,
#   'foun': 4,
#   '%%fa': 51,
#   '%fam': 5,
#   'fami': 3,
#   'amil': 3,
#   '%mon': 8,
#   'mone': 1,
#   '%tod': 2,
#   'toda': 1,
#   '%mus': 8,
#   '%tol': 1,
#   '%%ok': 2,
#   '%oka': 1,
#   '%%ol': 6,
#   '%%am': 12,
#   '%ame': 4,
#   'amer': 6,
#   'meri': 4,
#   'eric': 4,
#   'rica': 8,
#   '%%du': 8,
#   '%dur': 1,
#   'duri': 1,
#   'urin': 2,
#   '%%ni': 6,
#   '%nig': 2,
#   'nigh': 5,
#   '%%un': 30,
#   '%und': 6,
#   'unde': 11,
#   '%lef': 1,
#   '%%po': 51,
#   '%poi': 4,
#   'poin': 7,
#   '%%ki': 16,
#   '%kin': 4,
#   '%dif': 7,
#   'diff': 7,
#   'iffe': 4,
#   'ffer': 10,
#   'fere': 9,
#   'eren': 7,
#   '%%en': 43,
#   '%cam': 8,
#   '%fee': 9,
#   '%%ke': 12,
#   '%kee': 3,
#   '%hig': 5,
#   'tate': 4,
#   '%eno': 2,
#   'enou': 1,
#   'noug': 1,
#   '%gov': 3,
#   'gove': 3,
#   'over': 18,
#   'vern': 4,
#   'ernm': 2,
#   'rnme': 2,
#   'nmen': 5,
#   '%any': 6,
#   'anyt': 1,
#   'nyth': 1,
#   'ythi': 2,
#   '%not': 7,
#   'othi': 2,
#   '%stu': 10,
#   'stud': 7,
#   'tude': 3,
#   'uden': 2,
#   'dent': 10,
#   '%unt': 1,
#   'unti': 5,
#   'coun': 15,
#   'ount': 13,
#   'untr': 2,
#   '%wen': 1,
#   '%%ci': 14,
#   '%cit': 5,
#   '%bel': 9,
#   'beli': 5,
#   'elie': 6,
#   'liev': 3,
#   '%onc': 1,
#   '%may': 2,
#   'mayb': 1,
#   '%pub': 5,
#   'publ': 8,
#   'ubli': 8,
#   '%cal': 9,
#   'call': 15,
#   'alle': 16,
#   'whit': 2,
#   '%cas': 4,
#   '%tal': 8,
#   'cour': 9,
#   'ours': 5,
#   '%per': 26,
#   'perc': 5,
#   'erce': 5,
#   'rcen': 2,
#   '%don': 3,
#   'time': 2,
#   '%%ac': 41,
#   '%act': 14,
#   'actu': 4,
#   'ctua': 3,
#   'tual': 3,
#   'uall': 6,
#   '%day': 1,
#   '%fac': 13,
#   '%too': 3,
#   '%car': 19,
#   '%%nu': 8,
#   '%num': 3,
#   'numb': 2,
#   'umbe': 2,
#   '%hea': 18,
#   '%les': 3,
#   '%sec': 11,
#   'seco': 3,
#   'econ': 6,
#   '%%sy': 5,
#   '%sys': 2,
#   'syst': 2,
#   'yste': 3,
#   '%%im': 26,
#   '%imp': 17,
#   'impo': 4,
#   'mpor': 5,
#   'port': 18,
#   'orta': 6,
#   'rtan': 3,
#   'omeo': 1,
#   'meon': 1,
#   '%%tr': 56,
#   '%try': 1,
#   'tryi': 1,
#   'ryin': 3,
#   '%get': 2,
#   'gett': 1,
#   'etti': 4,
#   'ttin': 8,
#   '%cha': 32,
#   'chan': 9,
#   'hang': 6,
#   '%wee': 4,
#   '%how': 2,
#   'howe': 3,
#   'owev': 1,
#   'weve': 1,
#   '%wat': 5,
#   'wate': 2,
#   '%bus': 4,
#   'busi': 2,
#   'usin': 6,
#   'sine': 2,
#   'ines': 4,
#   'very': 5,
#   'eryt': 1,
#   'ryth': 1,
#   '%%sm': 12,
#   '%sma': 3,
#   'smal': 2,
#   '%%ro': 37,
#   '%roo': 5,
#   'want': 3,
#   'ante': 3,
#   '%lea': 17,
#   'leas': 7,
#   '%%na': 19,
#   '%nat': 9,
#   'nati': 14,
#   'atio': 90,
#   'tion': 58,
#   'iona': 17,
#   'than': 3,
#   '%sto': 18,
#   'stor': 11,
#   '%pow': 5,
#   'powe': 4,
#   '%gro': 10,
#   'grou': 6,
#   '%mot': 5,
#   'moth': 3,
#   'havi': 4,
#   'avin': 4,
#   '%nam': 3,
#   'woma': 1,
#   '%inf': 7,
#   'info': 2,
#   'nfor': 5,
#   'form': 16,
#   'orma': 10,
#   'rmat': 4,
#   'mati': 7,
#   '%pro': 65,
#   'prob': 3,
#   'robl': 2,
#   'oble': 2,
#   '%%jo': 26,
#   '%lat': 6,
#   'late': 7,
#   '%alr': 2,
#   'alre': 1,
#   'lrea': 1,
#   'read': 6,
#   '%%ga': 24,
#   '%gam': 2,
#   '%%bl': 13,
#   '%bla': 3,
#   'blac': 2,
#   '%har': 9,
#   'maki': 1,
#   'akin': 6,
#   'look': 3,
#   'ooki': 3,
#   'okin': 3,
#   '%%as': 27,
#   '%ask': 3,
#   'aske': 2,
#   '%mil': 7,
#   'mill': 3,
#   'illi': 12,
#   'llio': 5,
#   '%boo': 5,
#   '%tog': 1,
#   'toge': 1,
#   'oget': 1,
#   'geth': 1,
#   'ethe': 3,
#   'heal': 4,
#   'ealt': 5,
#   '%uni': 12,
#   'unit': 6,
#   'nite': 2,
#   '%%%q': 15,
#   '%%qu': 14,
#   '%que': 3,
#   'ques': 4,
#   'uest': 4,
#   'esti': 18,
#   'stio': 4,
#   '%han': 10,
#   '%fat': 3,
#   'fath': 3,
#   'athe': 10,
#   'pers': 7,
#   'erso': 8,
#   'youn': 2,
#   '%oft': 1,
#   'ofte': 1,
#   '%see': 11,
#   '%pas': 8,
#   '%soc': 4,
#   'soci': 6,
#   'ocia': 4,
#   '%new': 4,
#   'comi': 3,
#   'omin': 5,
#   'comp': 27,
#   'ompa': 5,
#   'mpan': 2,
#   '%sid': 3,
#   '%tea': 9,
#   'whet': 1,
#   'heth': 1,
#   '%abl': 1,
#   '%alm': 1,
#   'almo': 1,
#   'lmos': 1,
#   '%pol': 10,
#   'poli': 7,
#   'olit': 4,
#   'liti': 10,
#   'itic': 7,
#   'tica': 10,
#   '%liv': 4,
#   '%kne': 3,
#   'beco': 3,
#   'ecom': 6,
#   'star': 7,
#   'sayi': 1,
#   'ayin': 4,
#   '%%op': 20,
#   '%ope': 9,
#   'work': 6,
#   'orki': 1,
#   'rkin': 2,
#   '%who': 5,
#   'whol': 1,
#   '%sup': 13,
#   'supp': 9,
#   'uppo': 7,
#   'ppor': 7,
#   '%yor': 1,
#   '%fiv': 1,
#   'roba': 1,
#   'obab': 1,
#   'babl': 1,
#   '%amo': 3,
#   'amon': 1,
#   '%usi': 1,
#   '%res': 32,
#   'rese': 16,
#   'esea': 2,
#   'sear': 4,
#   'earc': 4,
#   '%%gu': 17,
#   '%%id': 8,
#   '%ide': 7,
#   '%%ru': 12,
#   'make': 2,
#   '%ear': 7,
#   'earl': 4,
#   '%%el': 16,
#   '%els': 2,
#   '%inc': 15,
#   'incl': 4,
#   'nclu': 7,
#   'clud': 5,
#   'ludi': 1,
#   'udin': 1,
#   '%joh': 3,
#   'nder': 9,
#   'ders': 5,
#   'erst': 3,
#   'rsta': 2,
#   'stan': 20,
#   '%%hu': 18,
#   '%hum': 4,
#   'huma': 3,
#   'univ': 4,
#   'nive': 5,
#   'iver': 11,
#   'vers': 16,
#   'ersi': 6,
#   'rsit': 3,
#   'talk': 3,
#   'alki': 2,
#   'lkin': 2,
#   '%fre': 8,
#   '%alo': 3,
#   'alon': 3,
#   'ithi': 1,
#   '%his': 5,
#   'hist': 5,
#   'isto': 5,
#   'morn': 1,
#   'orni': 2,
#   'rnin': 8,
#   '%%ey': 2,
#   '%eye': 1,
#   '%sev': 3,
#   'seve': 3,
#   'vera': 4,
#   '%lin': 7,
#   '%min': 11,
#   '%ple': 5,
#   'plea': 4,
#   'prog': 5,
#   'rogr': 5,
#   'ogra': 7,
#   '%acr': 2,
#   'acro': 1,
#   'cros': 5,
#   '%kid': 2,
#   '%beh': 5,
#   'behi': 1,
#   'ehin': 1,
#   'part': 15,
#   'eryo': 1,
#   'ryon': 1,
#   '%bod': 2,
#   '%rem': 14,
#   'reme': 7,
#   'emem': 2,
#   'memb': 5,
#   'embe': 8,
#   '%%ex': 71,
#   '%exa': 7,
#   'exam': 5,
#   'xamp': 2,
#   'ampl': 4,
#   '%sor': 3,
#   'sorr': 1,
#   '%con': 93,
#   'cont': 27,
#   'ontr': 13,
#   'ntro': 8,
#   'give': 2,
#   '%%ra': 37,
#   '%rat': 7,
#   'rath': 1,
#   'mean': 5,
#   '%dat': 5,
#   '%%ob': 12,
#   '%oba': 1,
#   'obam': 1,
#   'tart': 3,
#   'arte': 5,
#   '%off': 13,
#   'offi': 7,
#   'ffic': 13,
#   '%%%T': 1,
#   '%%Tr': 1,
#   '%Tru': 1,
#   'comm': 23,
#   'ommu': 6,
#   'mmun': 6,
#   'muni': 6,
#   '%%wr': 11,
#   '%wro': 2,
#   'wron': 1,
#   'mont': 3,
#   'onth': 2,
#   '%fri': 5,
#   'frie': 6,
#   'rien': 10,
#   'iend': 3,
#   '%gen': 16,
#   'gene': 9,
#   'ener': 8,
#   'nera': 8,
#   '%mat': 10,
#   'matt': 4,
#   'atte': 15,
#   '%mov': 8,
#   '%%ed': 11,
#   '%edu': 4,
#   'educ': 8,
#   'duca': 4,
#   'ucat': 4,
#   'cati': 12,
#   '%foo': 5,
#   'hear': 4,
#   'ooke': 1,
#   '%%ei': 2,
#   '%eit': 1,
#   'eith': 2,
#   'ithe': 2,
#   '%him': 1,
#   'hims': 1,
#   'imse': 1,
#   'msel': 2,
#   '%hap': 6,
#   'happ': 6,
#   'appe': 14,
#   'ppen': 3,
#   'pene': 2,
#   '%lar': 5,
#   'larg': 4,
#   '%guy': 1,
#   '%sen': 10,
#   'sens': 3,
#   '%%ce': 16,
#   '%cen': 6,
#   'cent': 9,
#   'ente': 12,
#   'leav': 3,
#   '%%or': 16,
#   '%ord': 4,
#   'orde': 7,
#   'musi': 2,
#   'pret': 3,
#   'rett': 2,
#   'taki': 1,
#   'olic': 3,
#   'proc': 5,
#   'roce': 6,
#   'oces': 3,
#   '%%tu': 9,
#   '%tur': 6,
#   'come': 4,
#   '%los': 5,
#   '%%fu': 20,
#   '%fut': 1,
#   'futu': 1,
#   'utur': 1,
#   '%tab': 2,
#   'tabl': 11,
#   '%hal': 2,
#   '%%cl': 42,
#   '%clo': 12,
#   'clos': 7,
#   '%hop': 5,
#   '%lig': 2,
#   'ligh': 5,
#   'minu': 2,
#   'inut': 2,
#   'nute': 1,
#   'seem': 3,
#   'pare': 6,
#   'aren': 6,
#   'rent': 4,
#   '%pos': 12,
#   'poss': 6,
#   'ossi': 6,
#   'ssib': 6,
#   'sibl': 7,
#   'reas': 10,
#   'easo': 5,
#   '%exp': 32,
#   'expe': 17,
#   'xper': 9,
#   'peri': 9,
#   'erie': 4,
#   'ienc': 7,
#   '%are': 3,
#   'word': 1,
#   '%alt': 2,
#   'alth': 4,
#   'ltho': 1,
#   '%wai': 3,
#   '%doo': 2,
#   '%fel': 3,
#   '%acc': 15,
#   'acco': 5,
#   'ccor': 1,
#   'cord': 4,
#   'ordi': 4,
#   'rdin': 5,
#   '%%ai': 7,
#   '%ful': 2,
#   '%%de': 105,
#   '%dea': 9,
#   'anyo': 1,
#   'nyon': 1,
#   'deat': 2,
#   '%loc': 6,
#   'loca': 4,
#   'hour': 1,
#   'hank': 2,
#   '%%is': 10,
#   '%iss': 3,
#   'issu': 4,
#   'fron': 1,
#   'meti': 1,
#   'etim': 2,
#   '%ins': 19,
#   'inst': 13,
#   'nste': 2,
#   'stea': 3,
#   '%mom': 3,
#   'mome': 2,
#   'omen': 3,
#   'livi': 1,
#   'ivin': 6,
#   '%col': 17,
#   'coll': 10,
#   'olle': 9,
#   'lleg': 5,
#   '%gir': 3,
#   'need': 2,
#   'turn': 7,
#   'urne': 5,
#   '%%br': 39,
#   '%bri': 11,
#   'brin': 3,
#   '%lev': 2,
#   'leve': 3,
#   '%maj': 2,
#   'majo': 2,
#   '%was': 3,
#   'wash': 1,
#   'ashi': 2,
#   'shin': 4,
#   'ingt': 1,
#   'ngto': 1,
#   '%cle': 6,
#   'clea': 6,
#   '%bil': 5,
#   '%out': 4,
#   'outs': 1,
#   'utsi': 1,
#   'tsid': 1,
#   '%ser': 10,
#   'serv': 17,
#   'ervi': 6,
#   'rvic': 2,
#   'take': 3,
#   'hand': 7,
#   'perh': 1,
#   'erha': 1,
#   'rhap': 1,
#   '%sea': 8,
#   'seas': 4,
#   '%mem': 6,
#   'mber': 4,
#   'know': 7,
#   'blem': 1,
#   '%%cu': 19,
#   'hink': 2,
#   'inki': 2,
#   'nkin': 3,
#   '%bas': 8,
#   'base': 3,
#   'like': 4,
#   'ikel': 2,
#   '%str': 28,
#   'stre': 7,
#   'tree': 3,
#   'secu': 4,
#   'ecur': 2,
#   'curi': 2,
#   'urit': 1,
#   '%gav': 1,
#   'them': 4,
#   'hems': 1,
#   'emse': 1,
#   'selv': 2,
#   'elve': 2,
#   'insi': 3,
#   'nsid': 6,
#   '%%es': 13,
#   '%esp': 1,
#   'espe': 4,
#   'spec': 14,
#   'peci': 5,
#   'ecia': 3,
#   'cial': 3,
#   'iall': 5,
#   '%for': 25,
#   'orme': 4,
#   '%fed': 1,
#   'fede': 1,
#   'eder': 1,
#   'dera': 4,
#   '%mar': 20,
#   'mark': 7,
#   'arke': 5,
#   '%beg': 5,
#   'bega': 1,
#   '%%my': 3,
#   '%mys': 2,
#   'myse': 1,
#   'ysel': 1,
#   '%nic': 2,
#   '%wif': 1,
#   '%qui': 6,
#   'quit': 1,
#   '%gon': 1,
#   'fina': 4,
#   'inal': 2,
#   'nall': 4,
#   '%tow': 5,
#   'towa': 2,
#   'owar': 3,
#   'mili': 4,
#   'ilit': 13,
#   'lita': 1,
#   'itar': 1,
#   '%rep': 26,
#   'repo': 6,
#   'epor': 6,
#   '%hol': 8,
#   '%%sp': 34,
#   '%spe': 15,
#   '%bab': 2,
#   '%cau': 5,
#   '%sou': 10,
#   'sout': 2,
#   'ssue': 2,
#   '%%ph': 19,
#   '%pho': 8,
#   'phon': 4,
#   '%soo': 2,
#   '%nor': 4,
#   'nort': 2,
#   '%%ec': 3,
#   '%eco': 3,
#   'cono': 3,
#   'onom': 3,
#   'nomi': 3,
#   'live': 5,
#   'coup': 2,
#   'oupl': 2,
#   '%chu': 4,
#   'chur': 2,
#   'hurc': 2,
#   '%goe': 1,
#   '%cla': 11,
#   'clas': 5,
#   '%dev': 10,
#   'deve': 6,
#   'evel': 8,
#   'velo': 6,
#   'elop': 5,
#   'lopm': 2,
#   'opme': 2,
#   'pmen': 3,
#   'abov': 1,
#   '%fig': 5,
#   'figu': 3,
#   'igur': 3,
#   'watc': 3,
#   '%mid': 2,
#   'midd': 1,
#   'iddl': 1,
#   '%sim': 7,
#   'simp': 3,
#   'impl': 6,
#   'rson': 5,
#   'sona': 4,
#   '%run': 2,
#   'runn': 1,
#   'unni': 1,
#   'nnin': 4,
#   'eede': 1,
#   '%spa': 5,
#   'spac': 2,
#   ...})

# %%
def get_top3_weights(txt, probs, n):
    # get the n-gram prefix of the text
    # if that n-gram isn't in the table, returns an empty dict
    weights = probs.get(txt[len(txt)-n:], {})
    if not weights:
        return {}

    # get the 3 most probable following letters
    # if there are less than 3, gets all of them
    words = np.array(list(weights.keys()))
    freq = np.array(list(weights.values()))

    top = np.argpartition(freq, -3)[-3:] if len(freq) >= 3 else np.argpartition(freq, -len(freq))

    return dict(zip(words[top], freq[top]))

# %%
word_counts = {'apple': 10, 'banana': 5, 'orange': 8, 'grape': 3, 'kiwi': 12}
print(get_top3_weights('oi', {'oi': word_counts}, 2))
# Out:
# {'orange': 8, 'apple': 10, 'kiwi': 12}

# %%
def predicter(n, words):

    # initializes variables
    probs, prev_counts = generate_probs(n, words)

    txt = r'%%%'
    while (curr := input("Next Letter: ")) != '':
        if curr == ' ':
            txt = r'%%%'
            continue

        txt += curr
        top3 = get_top3_weights(txt, probs, n)
        print(f'\n{txt} \nBest 3 letters are: {list(reversed(top3.keys()))}')

# %%
predicter(N, words)
# Out:
# %%%hell
# Best 3 letters are: ['e', 'o']

# %% [markdown]
# If we save this data, we can use them later on any other project!

# %%
# Save the probs dict as a json
import json

probs, prev_counts = generate_probs(N, words)

with open('../data/out/word-frequency/word-frequency_probs.json', 'w') as f:
    json.dump(probs, f)

with open('../data/out/word-frequency/word-frequency_prefix-count.json', 'w') as f:
    json.dump(prev_counts, f)

# %% [markdown]
# ## **Second Dataset: 100k most common words**
#
# It seems a bit outdated and it's from a gist, so... let's test!
#
# Font: [https://gist.github.com/h3xx/1976236](https://gist.github.com/h3xx/1976236)

# %%
words100k = []
with open('../data/wiki-100k.txt', 'r', encoding='utf-8') as f:
    curr = f.read().splitlines()

    for line in curr: # reading all lines and ignoring comments
        if line and line[0] != '#':
            words100k.extend(line.split())
    
    words100k = np.array(words100k)

# %%
words100k[:10], len(words100k)
# Out:
# (array(['the', 'of', 'and', 'to', 'a', 'in', 'that', 'I', 'was', 'he'],
#        dtype='<U23'),
#  98916)

# %% [markdown]
# Just from quickly analyzing the file, we can see that there is a big problem of repetition, where the same word appears capitalized and not capitalized. Also, some proper nouns can also be a problem. Therefore, let's test by eliminating any letter that is capitalized:

# %%
def preprocess_text(text):
    # filter all capitalized words and words that contain special characters
    words = [word for word in text if word.islower() and word.isalpha()]

    # this function can be improved in the future!

    return words

# %%
words100k = preprocess_text(words100k)

# %% [markdown]
# 30k less words!

# %%
len(words100k), words100k[:10]
# Out:
# (63139, ['the', 'of', 'and', 'to', 'a', 'in', 'that', 'was', 'he', 'his'])

# %%
# %%time
second_probs, second_prefix_count = generate_probs(N, words100k)
# Out:
# CPU times: total: 2min 50s
# Wall time: 7min 57s

# %%
second_probs
# Out:
# {'%%%t': {'h': 0.1371794871794872,
#   'o': 0.13173076923076923,
#   'i': 0.07916666666666666,
#   'w': 0.022435897435897436,
#   'a': 0.1233974358974359,
#   'e': 0.14967948717948718,
#   'u': 0.0625,
#   't': 0.000641025641025641,
#   'r': 0.2586538461538462,
#   'y': 0.017948717948717947,
#   'ê': 0.0009615384615384616,
#   'ä': 0.008012820512820512,
#   'm': 0.0003205128205128205,
#   'ô': 0.000641025641025641,
#   'ú': 0.0003205128205128205,
#   'v': 0.000641025641025641,
#   's': 0.0003205128205128205,
#   'é': 0.0019230769230769232,
#   'â': 0.000641025641025641,
#   'l': 0.0003205128205128205,
#   'j': 0.000641025641025641,
#   'ã': 0.0003205128205128205,
#   'í': 0.0009615384615384616,
#   'z': 0.0003205128205128205,
#   'æ': 0.0003205128205128205},
#  '%%th': {'e': 0.2505854800936768,
#   'a': 0.07962529274004684,
#   'i': 0.1990632318501171,
#   'o': 0.10772833723653395,
#   'r': 0.24824355971896955,
#   'y': 0.01873536299765808,
#   'u': 0.07259953161592506,
#   'w': 0.00936768149882904,
#   'é': 0.01405152224824356},
#  '%%%o': {'f': 0.06787963610916725,
#   'n': 0.05458362491252624,
#   'r': 0.13086074177746676,
#   'u': 0.12036389083275018,
#   't': 0.01609517144856543,
#   'v': 0.11616515045486354,
#   'l': 0.03848845346396081,
#   'w': 0.01819454163750875,
#   'p': 0.08467459762071379,
#   'b': 0.13086074177746676,
#   'c': 0.05318404478656403,
#   'g': 0.00489853044086774,
#   'm': 0.03918824352694192,
#   'ù': 0.0006997900629811056,
#   'd': 0.021693491952414275,
#   'h': 0.0034989503149055285,
#   'i': 0.018894331700489854,
#   'a': 0.016794961511546535,
#   'o': 0.01609517144856543,
#   's': 0.01959412176347096,
#   'x': 0.007697690692792162,
#   'y': 0.00489853044086774,
#   'z': 0.002099370188943317,
#   'j': 0.0027991602519244225,
#   'e': 0.008397480755773267,
#   'k': 0.0006997900629811056,
#   'í': 0.0006997900629811056},
#  '%%%a': {'n': 0.10921153355447819,
#   's': 0.07808114314876244,
#   't': 0.04720591987751978,
#   'l': 0.09619800969635112,
#   'r': 0.09237050267925491,
#   'b': 0.06506761929063537,
#   'f': 0.033937228884919624,
#   'm': 0.0469507527430467,
#   'g': 0.03215105894360806,
#   'w': 0.013523858127073234,
#   'u': 0.052054095432508295,
#   'i': 0.025516713447307986,
#   'c': 0.08343965297269712,
#   'p': 0.08369482010717019,
#   'v': 0.031130390405715743,
#   'd': 0.07808114314876244,
#   'h': 0.001786169941311559,
#   'a': 0.0048481755549885175,
#   'y': 0.0022965042102577188,
#   'k': 0.0012758356723653994,
#   'x': 0.003317172748150038,
#   'e': 0.0061240112273539165,
#   'q': 0.003827507017096198,
#   'z': 0.0007655014034192396,
#   'j': 0.004337841286042358,
#   'o': 0.0012758356723653994,
#   'ñ': 0.0005103342689461597,
#   'ú': 0.00025516713447307985,
#   'ð': 0.00025516713447307985,
#   'î': 0.00025516713447307985,
#   'ë': 0.00025516713447307985},
#  '%%an': {'d': 0.07042253521126761,
#   'y': 0.03755868544600939,
#   'o': 0.03755868544600939,
#   's': 0.03990610328638498,
#   'c': 0.08685446009389672,
#   'x': 0.018779342723004695,
#   'i': 0.07511737089201878,
#   'g': 0.11502347417840375,
#   'n': 0.16901408450704225,
#   't': 0.19953051643192488,
#   'a': 0.08450704225352113,
#   'e': 0.02112676056338028,
#   'k': 0.02112676056338028,
#   'v': 0.007042253521126761,
#   'f': 0.007042253521126761,
#   'z': 0.007042253521126761,
#   'u': 0.002347417840375587},
#  '%%%i': {'n': 0.6296006264682851,
#   's': 0.022317932654659357,
#   't': 0.01644479248238058,
#   'f': 0.0011746280344557558,
#   'l': 0.034064212999216914,
#   'd': 0.031323414252153486,
#   'c': 0.00822239624119029,
#   'm': 0.16718872357086922,
#   'r': 0.04111198120595145,
#   'h': 0.00822239624119029,
#   'k': 0.003523884103367267,
#   'i': 0.0015661707126076742,
#   'g': 0.012529365700861394,
#   'v': 0.003915426781519186,
#   'o': 0.0031323414252153485,
#   'x': 0.0007830853563038371,
#   'e': 0.00274079874706343,
#   'a': 0.0011746280344557558,
#   'b': 0.004306969459671104,
#   'p': 0.00274079874706343,
#   'z': 0.0011746280344557558,
#   'u': 0.0011746280344557558,
#   'y': 0.0007830853563038371,
#   'j': 0.0007830853563038371},
#  '%tha': {'t': 0.15151515151515152,
#   'n': 0.6060606060606061,
#   'r': 0.06060606060606061,
#   'w': 0.09090909090909091,
#   'e': 0.030303030303030304,
#   'l': 0.030303030303030304,
#   'y': 0.030303030303030304},
#  '%%%w': {'a': 0.2541766109785203,
#   'i': 0.2016706443914081,
#   'h': 0.13007159904534607,
#   'e': 0.16288782816229117,
#   'o': 0.15513126491646778,
#   'r': 0.06682577565632458,
#   'u': 0.015513126491646777,
#   'f': 0.0005966587112171838,
#   'ü': 0.00477326968973747,
#   'ä': 0.004176610978520286,
#   'y': 0.003579952267303103,
#   't': 0.0005966587112171838},
#  '%%wa': {'s': 0.0611764705882353,
#   'y': 0.03294117647058824,
#   'n': 0.0988235294117647,
#   't': 0.11529411764705882,
#   'r': 0.22823529411764706,
#   'l': 0.08,
#   'i': 0.08941176470588236,
#   'v': 0.03529411764705882,
#   'g': 0.06352941176470588,
#   'k': 0.03058823529411765,
#   'x': 0.018823529411764704,
#   'a': 0.04941176470588235,
#   'd': 0.021176470588235293,
#   'e': 0.011764705882352941,
#   'h': 0.023529411764705882,
#   'f': 0.01647058823529412,
#   'c': 0.011764705882352941,
#   'm': 0.002352941176470588,
#   'u': 0.004705882352941176,
#   'p': 0.004705882352941176},
#  '%%%h': {'e': 0.2365734576120728,
#   'i': 0.09942299156679982,
#   'a': 0.27518863737239235,
#   'o': 0.20861074123391035,
#   'w': 0.0004438526409232135,
#   'u': 0.11273857079449623,
#   't': 0.0004438526409232135,
#   'ä': 0.010652463382157125,
#   'y': 0.032401242787394584,
#   'v': 0.005326231691078562,
#   'ö': 0.007101642254771416,
#   'é': 0.0031069684864624943,
#   'r': 0.0022192632046160675,
#   'â': 0.0013315579227696406,
#   'ø': 0.0013315579227696406,
#   'ô': 0.0013315579227696406,
#   'j': 0.000887705281846427,
#   'å': 0.0004438526409232135,
#   'á': 0.0004438526409232135},
#  '%%hi': {'s': 0.15246636771300448,
#   'm': 0.03139013452914798,
#   'g': 0.08968609865470852,
#   'l': 0.08968609865470852,
#   'j': 0.026905829596412557,
#   'd': 0.07623318385650224,
#   't': 0.05829596412556054,
#   'e': 0.12556053811659193,
#   'n': 0.21973094170403587,
#   'r': 0.04484304932735426,
#   'p': 0.026905829596412557,
#   'z': 0.004484304932735426,
#   'v': 0.017937219730941704,
#   'c': 0.017937219730941704,
#   'u': 0.004484304932735426,
#   'k': 0.008968609865470852,
#   'a': 0.004484304932735426},
#  '%%wi': {'t': 0.19584569732937684,
#   'l': 0.14540059347181009,
#   'f': 0.011869436201780416,
#   's': 0.10089020771513353,
#   'n': 0.20771513353115728,
#   'd': 0.0830860534124629,
#   'e': 0.06528189910979229,
#   'r': 0.05341246290801187,
#   'c': 0.05637982195845697,
#   'v': 0.008902077151335312,
#   'j': 0.020771513353115726,
#   'p': 0.008902077151335312,
#   'g': 0.02373887240356083,
#   'z': 0.011869436201780416,
#   'm': 0.002967359050445104,
#   'ß': 0.002967359050445104},
#  '%wit': {'h': 0.5625,
#   'n': 0.125,
#   's': 0.03125,
#   'c': 0.125,
#   't': 0.140625,
#   'l': 0.015625},
#  '%%%f': {'o': 0.21223643276875215,
#   'r': 0.1396474248185275,
#   'i': 0.13273418596612513,
#   'a': 0.1914967162115451,
#   'e': 0.11095748358105773,
#   'u': 0.07569996543380574,
#   'l': 0.11787072243346007,
#   'ü': 0.00414794331144141,
#   'ö': 0.0031109574835810577,
#   't': 0.0010369858278603526,
#   'û': 0.000691323885240235,
#   'f': 0.000691323885240235,
#   'ê': 0.0010369858278603526,
#   'å': 0.0010369858278603526,
#   'y': 0.000691323885240235,
#   'ä': 0.0010369858278603526,
#   'é': 0.002073971655720705,
#   'î': 0.000691323885240235,
#   'ø': 0.00138264777048047,
#   'â': 0.000691323885240235,
#   'ò': 0.0003456619426201175,
#   'á': 0.0003456619426201175,
#   'j': 0.0003456619426201175},
#  '%%fo': {'r': 0.5497553017944535,
#   'u': 0.10114192495921696,
#   'l': 0.08809135399673736,
#   'o': 0.0929853181076672,
#   'n': 0.03915171288743882,
#   'i': 0.022838499184339316,
#   'e': 0.013050570962479609,
#   'g': 0.0065252854812398045,
#   'x': 0.008156606851549755,
#   'a': 0.013050570962479609,
#   'w': 0.011419249592169658,
#   's': 0.021207177814029365,
#   'c': 0.009787928221859706,
#   'y': 0.0032626427406199023,
#   'd': 0.004893964110929853,
#   'p': 0.0065252854812398045,
#   'm': 0.004893964110929853,
#   'b': 0.0016313213703099511,
#   'h': 0.0016313213703099511},
#  '%%ha': {'d': 0.01615508885298869,
#   'v': 0.030694668820678513,
#   's': 0.0420032310177706,
#   'n': 0.1308562197092084,
#   'l': 0.1050080775444265,
#   'r': 0.2197092084006462,
#   'p': 0.03877221324717286,
#   'i': 0.04038772213247173,
#   't': 0.05977382875605816,
#   'b': 0.10016155088852989,
#   'a': 0.011308562197092083,
#   'u': 0.05492730210016155,
#   'y': 0.008077544426494346,
#   'm': 0.03231017770597738,
#   'e': 0.0210016155088853,
#   'z': 0.01938610662358643,
#   'g': 0.012924071082390954,
#   'w': 0.01615508885298869,
#   'c': 0.03231017770597738,
#   'f': 0.004846526655896607,
#   'k': 0.0016155088852988692,
#   'h': 0.0016155088852988692},
#  '%%%y': {'o': 0.25280898876404495,
#   'e': 0.34831460674157305,
#   'a': 0.1348314606741573,
#   'i': 0.05056179775280899,
#   'n': 0.011235955056179775,
#   'h': 0.03932584269662921,
#   'u': 0.011235955056179775,
#   'l': 0.02247191011235955,
#   'k': 0.011235955056179775,
#   'r': 0.016853932584269662,
#   't': 0.0056179775280898875,
#   'm': 0.03932584269662921,
#   'ö': 0.02247191011235955,
#   's': 0.011235955056179775,
#   'c': 0.0056179775280898875,
#   'b': 0.0056179775280898875,
#   'f': 0.0056179775280898875,
#   'd': 0.0056179775280898875},
#  '%%yo': {'u': 0.6744186046511628,
#   'n': 0.11627906976744186,
#   'k': 0.09302325581395349,
#   'r': 0.046511627906976744,
#   'l': 0.046511627906976744,
#   'w': 0.023255813953488372},
#  '%%%n': {'o': 0.26919967663702504,
#   'e': 0.2514147130153597,
#   'i': 0.10913500404203719,
#   'a': 0.20776071139854488,
#   'u': 0.10024252223120453,
#   'y': 0.00889248181083266,
#   'm': 0.0008084074373484236,
#   'ä': 0.024252223120452707,
#   'ã': 0.0008084074373484236,
#   'é': 0.00889248181083266,
#   'å': 0.004042037186742118,
#   'g': 0.0032336297493936943,
#   'ö': 0.0008084074373484236,
#   'è': 0.002425222312045271,
#   't': 0.0008084074373484236,
#   'ú': 0.0008084074373484236,
#   'd': 0.0016168148746968471,
#   'ô': 0.0016168148746968471,
#   'æ': 0.0008084074373484236,
#   'k': 0.0008084074373484236,
#   'n': 0.0008084074373484236,
#   's': 0.0008084074373484236},
#  '%%no': {'t': 0.21450151057401812,
#   'w': 0.027190332326283987,
#   'r': 0.06646525679758308,
#   'u': 0.09063444108761329,
#   'n': 0.04833836858006042,
#   'b': 0.05740181268882175,
#   'c': 0.03625377643504532,
#   'i': 0.07250755287009064,
#   's': 0.0755287009063444,
#   'o': 0.0513595166163142,
#   'd': 0.030211480362537766,
#   'v': 0.05740181268882175,
#   'm': 0.10574018126888217,
#   'g': 0.015105740181268883,
#   'x': 0.0030211480362537764,
#   'k': 0.0030211480362537764,
#   'l': 0.0030211480362537764,
#   'e': 0.021148036253776436,
#   'z': 0.0030211480362537764,
#   'p': 0.0030211480362537764,
#   'h': 0.00906344410876133,
#   'y': 0.006042296072507553},
#  '%%%b': {'e': 0.24196066187948798,
#   'y': 0.004370902279113331,
#   'u': 0.10177958164221043,
#   'a': 0.17858257883234468,
#   'o': 0.13674679987511706,
#   'r': 0.15797689665938183,
#   'l': 0.1130190446456447,
#   'i': 0.06056821729628473,
#   'ê': 0.0006244146113019045,
#   'â': 0.001248829222603809,
#   'å': 0.0006244146113019045,
#   'ö': 0.0009366219169528567,
#   'k': 0.00031220730565095225,
#   'ä': 0.0006244146113019045,
#   'ü': 0.00031220730565095225,
#   'j': 0.00031220730565095225},
#  '%%he': {'r': 0.2391713747645951,
#   'a': 0.2806026365348399,
#   'l': 0.1016949152542373,
#   't': 0.02824858757062147,
#   'i': 0.08097928436911488,
#   'n': 0.03766478342749529,
#   'm': 0.030131826741996232,
#   's': 0.02824858757062147,
#   'u': 0.02824858757062147,
#   'e': 0.0583804143126177,
#   'b': 0.013182674199623353,
#   'd': 0.02071563088512241,
#   'c': 0.011299435028248588,
#   'v': 0.007532956685499058,
#   'w': 0.007532956685499058,
#   'y': 0.003766478342749529,
#   'f': 0.011299435028248588,
#   'x': 0.005649717514124294,
#   'z': 0.0018832391713747645,
#   'g': 0.0018832391713747645,
#   'h': 0.0018832391713747645},
#  '%%wh': {'i': 0.5,
#   'o': 0.12385321100917432,
#   'e': 0.25229357798165136,
#   'a': 0.10550458715596331,
#   'y': 0.013761467889908258,
#   'u': 0.0045871559633027525},
#  '%whi': {'c': 0.03669724770642202,
#   'l': 0.06422018348623854,
#   't': 0.21100917431192662,
#   's': 0.26605504587155965,
#   'p': 0.07339449541284404,
#   'r': 0.12844036697247707,
#   'm': 0.09174311926605505,
#   'n': 0.06422018348623854,
#   'f': 0.01834862385321101,
#   'z': 0.027522935779816515,
#   'g': 0.01834862385321101},
#  'whic': {'h': 1.0},
#  '%hav': {'e': 0.5555555555555556,
#   'i': 0.2222222222222222,
#   'd': 0.05555555555555555,
#   'o': 0.05555555555555555,
#   'a': 0.1111111111111111},
#  '%%fr': {'o': 0.18,
#   'i': 0.1725,
#   'e': 0.27,
#   'u': 0.07,
#   'a': 0.27,
#   'è': 0.0075,
#   'å': 0.0075,
#   'y': 0.005,
#   'n': 0.0025,
#   'ü': 0.0075,
#   'é': 0.005,
#   'ö': 0.0025},
#  '%fro': {'m': 0.08571428571428572,
#   'n': 0.2857142857142857,
#   'z': 0.04285714285714286,
#   's': 0.08571428571428572,
#   'w': 0.12857142857142856,
#   'i': 0.1,
#   'g': 0.05714285714285714,
#   'l': 0.08571428571428572,
#   't': 0.07142857142857142,
#   'c': 0.02857142857142857,
#   'h': 0.014285714285714285,
#   'e': 0.014285714285714285},
#  '%thi': {'s': 0.047619047619047616,
#   'n': 0.3333333333333333,
#   'r': 0.21428571428571427,
#   'c': 0.21428571428571427,
#   't': 0.03571428571428571,
#   'e': 0.07142857142857142,
#   'g': 0.047619047619047616,
#   'm': 0.023809523809523808,
#   'l': 0.011904761904761904},
#  '%%bu': {'t': 0.13230769230769232,
#   's': 0.11692307692307692,
#   'i': 0.055384615384615386,
#   'r': 0.2153846153846154,
#   'y': 0.021538461538461538,
#   'l': 0.10461538461538461,
#   'n': 0.07384615384615385,
#   'f': 0.04,
#   'd': 0.033846153846153845,
#   'c': 0.06769230769230769,
#   'g': 0.03076923076923077,
#   'z': 0.015384615384615385,
#   'b': 0.015384615384615385,
#   'o': 0.027692307692307693,
#   'e': 0.015384615384615385,
#   'm': 0.024615384615384615,
#   'x': 0.003076923076923077,
#   'v': 0.006153846153846154},
#  '%%al': {'l': 0.36,
#   's': 0.016,
#   'w': 0.016,
#   'm': 0.04533333333333334,
#   'r': 0.008,
#   'o': 0.042666666666666665,
#   't': 0.168,
#   'i': 0.09066666666666667,
#   'a': 0.050666666666666665,
#   'e': 0.029333333333333333,
#   'c': 0.037333333333333336,
#   'b': 0.021333333333333333,
#   'p': 0.018666666666666668,
#   'k': 0.021333333333333333,
#   'g': 0.032,
#   'd': 0.018666666666666668,
#   'u': 0.016,
#   'f': 0.0026666666666666666,
#   'z': 0.0026666666666666666,
#   'n': 0.0026666666666666666},
#  '%%%s': {'h': 0.07413435927789287,
#   'o': 0.09411068363421131,
#   'a': 0.09129920094702575,
#   'u': 0.12133767386800828,
#   'e': 0.11852619118082273,
#   't': 0.14693696359869785,
#   'm': 0.014501331754957087,
#   'i': 0.0735424681858538,
#   'p': 0.06939923054158034,
#   'n': 0.014945250073986387,
#   'w': 0.022935779816513763,
#   'l': 0.036401302160402486,
#   'y': 0.015093222846996152,
#   'c': 0.0722107132287659,
#   'k': 0.013317549570878958,
#   'q': 0.010062148564664102,
#   'd': 0.0001479727730097662,
#   'å': 0.0010358094110683633,
#   'b': 0.0002959455460195324,
#   'g': 0.0004439183190292986,
#   'û': 0.000739863865048831,
#   'ì': 0.0001479727730097662,
#   'v': 0.0008878366380585972,
#   'é': 0.003699319325244155,
#   'í': 0.0001479727730097662,
#   's': 0.0001479727730097662,
#   'ä': 0.0008878366380585972,
#   'ó': 0.0002959455460195324,
#   'j': 0.0010358094110683633,
#   'x': 0.0001479727730097662,
#   'ö': 0.0002959455460195324,
#   'è': 0.0002959455460195324,
#   'ù': 0.0001479727730097662,
#   'ã': 0.0001479727730097662,
#   'r': 0.0001479727730097662,
#   'ü': 0.0001479727730097662},
#  '%%sh': {'e': 0.158,
#   'o': 0.252,
#   'a': 0.246,
#   'i': 0.152,
#   'u': 0.054,
#   'y': 0.014,
#   'r': 0.122,
#   't': 0.002},
#  '%%we': {'r': 0.06642066420664207,
#   'l': 0.12915129151291513,
#   'n': 0.08856088560885608,
#   'e': 0.1033210332103321,
#   'a': 0.25461254612546125,
#   'i': 0.15867158671586715,
#   's': 0.05166051660516605,
#   't': 0.033210332103321034,
#   'b': 0.014760147601476014,
#   'd': 0.055350553505535055,
#   'p': 0.007380073800738007,
#   'g': 0.007380073800738007,
#   'z': 0.007380073800738007,
#   'h': 0.007380073800738007,
#   'm': 0.0036900369003690036,
#   'ê': 0.0036900369003690036,
#   'k': 0.0036900369003690036,
#   'f': 0.0036900369003690036},
#  '%wer': {'e': 0.23529411764705882,
#   'd': 0.29411764705882354,
#   'k': 0.23529411764705882,
#   'r': 0.058823529411764705,
#   'y': 0.058823529411764705,
#   'f': 0.058823529411764705,
#   'p': 0.058823529411764705},
#  '%the': {'y': 0.02857142857142857,
#   'i': 0.06666666666666667,
#   'm': 0.08571428571428572,
#   'r': 0.37142857142857144,
#   'n': 0.05714285714285714,
#   's': 0.047619047619047616,
#   'e': 0.02857142857142857,
#   'o': 0.18095238095238095,
#   'a': 0.0761904761904762,
#   'f': 0.02857142857142857,
#   't': 0.009523809523809525,
#   'w': 0.009523809523809525,
#   'g': 0.009523809523809525},
#  '%%%m': {'y': 0.018325434439178515,
#   'e': 0.1819905213270142,
#   'o': 0.2037914691943128,
#   'a': 0.29731437598736177,
#   'u': 0.09541864139020537,
#   'i': 0.17883096366508688,
#   'ê': 0.0022116903633491313,
#   'è': 0.001579778830963665,
#   'á': 0.000315955766192733,
#   'c': 0.000315955766192733,
#   'h': 0.000631911532385466,
#   'g': 0.000631911532385466,
#   'ü': 0.0022116903633491313,
#   'í': 0.001263823064770932,
#   'å': 0.0009478672985781991,
#   'ö': 0.0022116903633491313,
#   'é': 0.008214849921011059,
#   'm': 0.000631911532385466,
#   'ä': 0.001579778830963665,
#   's': 0.000631911532385466,
#   'k': 0.000315955766192733,
#   'â': 0.000315955766192733,
#   'n': 0.000315955766192733},
#  '%%ar': {'e': 0.0221606648199446,
#   'o': 0.030470914127423823,
#   'm': 0.1440443213296399,
#   't': 0.14681440443213298,
#   'r': 0.2520775623268698,
#   'g': 0.04709141274238227,
#   'i': 0.07479224376731301,
#   'd': 0.036011080332409975,
#   'c': 0.13850415512465375,
#   'b': 0.0664819944598338,
#   'k': 0.00554016620498615,
#   'a': 0.013850415512465374,
#   's': 0.0110803324099723,
#   'v': 0.002770083102493075,
#   'q': 0.008310249307479225},
#  'thei': {'r': 0.23529411764705882,
#   's': 0.7058823529411765,
#   'm': 0.058823529411764705},
#  '%%on': {'e': 0.10526315789473684,
#   'l': 0.06578947368421052,
#   'c': 0.07894736842105263,
#   't': 0.11842105263157894,
#   's': 0.07894736842105263,
#   'w': 0.05263157894736842,
#   'd': 0.13157894736842105,
#   'z': 0.039473684210526314,
#   'i': 0.06578947368421052,
#   'y': 0.039473684210526314,
#   'k': 0.02631578947368421,
#   'm': 0.02631578947368421,
#   'g': 0.07894736842105263,
#   'n': 0.06578947368421052,
#   'h': 0.013157894736842105,
#   'u': 0.013157894736842105},
#  '%%%d': {'e': 0.3485182463874602,
#   'o': 0.09625275532696546,
#   'i': 0.3010041636051923,
#   'a': 0.08082292432035268,
#   'u': 0.04677932892481019,
#   'r': 0.08302718589272594,
#   'y': 0.00612294881214793,
#   'w': 0.005143277002204262,
#   'é': 0.02718589272593681,
#   'å': 0.0002449179524859172,
#   'è': 0.0002449179524859172,
#   'û': 0.0004898359049718344,
#   'ä': 0.0004898359049718344,
#   'î': 0.0004898359049718344,
#   'í': 0.0004898359049718344,
#   'ì': 0.0002449179524859172,
#   'ü': 0.0004898359049718344,
#   'ê': 0.0002449179524859172,
#   'l': 0.0002449179524859172,
#   'h': 0.0002449179524859172,
#   'ó': 0.0002449179524859172,
#   'ö': 0.0007347538574577516,
#   'ø': 0.0002449179524859172},
#  '%%wo': {'u': 0.05019305019305019,
#   'r': 0.444015444015444,
#   'm': 0.05791505791505792,
#   'n': 0.10038610038610038,
#   'o': 0.16216216216216217,
#   'h': 0.02702702702702703,
#   'e': 0.03474903474903475,
#   'k': 0.007722007722007722,
#   'l': 0.07335907335907337,
#   'v': 0.007722007722007722,
#   'd': 0.003861003861003861,
#   'f': 0.007722007722007722,
#   'b': 0.007722007722007722,
#   'z': 0.003861003861003861,
#   's': 0.003861003861003861,
#   'w': 0.003861003861003861,
#   'i': 0.003861003861003861},
#  '%wou': {'l': 0.4166666666666667, 'n': 0.5, 'd': 0.08333333333333333},
#  'woul': {'d': 1.0},
#  '%%sa': {'i': 0.07305194805194805,
#   'y': 0.027597402597402596,
#   'm': 0.03571428571428571,
#   'w': 0.016233766233766232,
#   't': 0.08603896103896104,
#   'v': 0.07305194805194805,
#   'n': 0.14772727272727273,
#   'k': 0.00974025974025974,
#   'f': 0.024350649350649352,
#   'd': 0.03571428571428571,
#   'c': 0.07954545454545454,
#   'l': 0.1396103896103896,
#   'g': 0.040584415584415584,
#   'h': 0.006493506493506494,
#   'a': 0.02922077922077922,
#   'u': 0.06655844155844155,
#   'b': 0.030844155844155844,
#   'e': 0.003246753246753247,
#   'p': 0.025974025974025976,
#   'r': 0.03409090909090909,
#   's': 0.00974025974025974,
#   'ß': 0.003246753246753247,
#   'á': 0.0016233766233766235},
#  '%sai': {'d': 0.09090909090909091,
#   'l': 0.3409090909090909,
#   't': 0.045454545454545456,
#   'n': 0.22727272727272727,
#   's': 0.22727272727272727,
#   'r': 0.022727272727272728,
#   'v': 0.022727272727272728,
#   'e': 0.022727272727272728},
#  '%%be': {'e': 0.03622250970245795,
#   'f': 0.03363518758085381,
#   'i': 0.018111254851228976,
#   't': 0.07891332470892626,
#   'c': 0.02199223803363519,
#   's': 0.12807244501940493,
#   'g': 0.10219922380336352,
#   'l': 0.09961190168175937,
#   'h': 0.0685640362225097,
#   'a': 0.11642949547218628,
#   'y': 0.00646830530401035,
#   'd': 0.05304010349288486,
#   'n': 0.07115135834411385,
#   'w': 0.042690815006468305,
#   'r': 0.04657179818887452,
#   'q': 0.007761966364812419,
#   'v': 0.014230271668822769,
#   'k': 0.016817593790426907,
#   'm': 0.009055627425614488,
#   'u': 0.0038809831824062097,
#   'z': 0.018111254851228976,
#   'p': 0.00258732212160414,
#   'b': 0.00129366106080207,
#   'o': 0.00258732212160414},
#  '%bee': {'n': 0.15384615384615385,
#   'r': 0.07692307692307693,
#   'f': 0.11538461538461539,
#   's': 0.11538461538461539,
#   't': 0.3076923076923077,
#   'c': 0.07692307692307693,
#   'v': 0.038461538461538464,
#   'l': 0.038461538461538464,
#   'h': 0.07692307692307693},
#  '%wil': {'l': 0.4791666666666667,
#   'd': 0.3333333333333333,
#   't': 0.0625,
#   'f': 0.0625,
#   'y': 0.020833333333333332,
#   'e': 0.041666666666666664},
#  '%whe': {'n': 0.10909090909090909,
#   'r': 0.38181818181818183,
#   't': 0.09090909090909091,
#   'e': 0.2727272727272727,
#   'a': 0.07272727272727272,
#   'l': 0.05454545454545454,
#   'y': 0.01818181818181818},
#  'ther': {'e': 0.36666666666666664,
#   's': 0.2,
#   'w': 0.03333333333333333,
#   't': 0.016666666666666666,
#   'n': 0.041666666666666664,
#   'i': 0.1,
#   'm': 0.05,
#   'h': 0.05,
#   'l': 0.075,
#   'y': 0.016666666666666666,
#   'a': 0.016666666666666666,
#   'f': 0.008333333333333333,
#   'c': 0.008333333333333333,
#   'd': 0.008333333333333333,
#   'o': 0.008333333333333333},
#  '%%mo': {'r': 0.15241057542768274,
#   's': 0.03576982892690513,
#   'm': 0.02021772939346812,
#   'n': 0.208398133748056,
#   't': 0.06220839813374806,
#   'v': 0.03421461897356143,
#   'u': 0.13530326594090203,
#   'd': 0.09486780715396578,
#   'o': 0.05443234836702955,
#   'i': 0.03421461897356143,
#   'b': 0.015552099533437015,
#   'c': 0.024883359253499222,
#   'y': 0.007776049766718507,
#   'a': 0.015552099533437015,
#   'e': 0.02332814930015552,
#   'l': 0.04821150855365474,
#   'g': 0.006220839813374806,
#   'p': 0.00933125972006221,
#   'w': 0.00933125972006221,
#   'z': 0.0015552099533437014,
#   'q': 0.004665629860031105,
#   'x': 0.0015552099533437014},
#  '%mor': {'e': 0.041237113402061855,
#   'n': 0.07216494845360824,
#   'a': 0.2268041237113402,
#   't': 0.3917525773195876,
#   'r': 0.020618556701030927,
#   's': 0.041237113402061855,
#   'g': 0.041237113402061855,
#   'c': 0.020618556701030927,
#   'o': 0.030927835051546393,
#   'i': 0.030927835051546393,
#   'b': 0.020618556701030927,
#   'd': 0.030927835051546393,
#   'p': 0.030927835051546393},
#  '%%ou': {'t': 0.7017543859649122,
#   'r': 0.04093567251461988,
#   'g': 0.023391812865497075,
#   'm': 0.005847953216374269,
#   'i': 0.011695906432748537,
#   'n': 0.017543859649122806,
#   's': 0.017543859649122806,
#   'd': 0.029239766081871343,
#   'v': 0.0935672514619883,
#   'l': 0.005847953216374269,
#   'b': 0.04678362573099415,
#   'e': 0.005847953216374269},
#  '%%%u': {'p': 0.05102040816326531,
#   's': 0.04591836734693878,
#   'n': 0.7908163265306123,
#   'm': 0.011661807580174927,
#   't': 0.029154518950437316,
#   'r': 0.01749271137026239,
#   'g': 0.00510204081632653,
#   'i': 0.004373177842565598,
#   'l': 0.013119533527696793,
#   'e': 0.008017492711370262,
#   'w': 0.0029154518950437317,
#   'd': 0.0036443148688046646,
#   'u': 0.006559766763848397,
#   'b': 0.0029154518950437317,
#   'v': 0.0007288629737609329,
#   'a': 0.0014577259475218659,
#   'h': 0.0007288629737609329,
#   'k': 0.0014577259475218659,
#   'o': 0.0014577259475218659,
#   'f': 0.0007288629737609329,
#   'y': 0.0007288629737609329},
#  '%%in': {'t': 0.21668742216687423,
#   'd': 0.13013698630136986,
#   'c': 0.13013698630136986,
#   'f': 0.09526774595267747,
#   's': 0.14508094645080946,
#   'h': 0.021170610211706103,
#   'n': 0.024283935242839352,
#   'q': 0.0224159402241594,
#   'v': 0.08094645080946451,
#   'j': 0.014321295143212951,
#   'e': 0.030510585305105854,
#   'a': 0.026774595267745952,
#   'w': 0.0043586550435865505,
#   'g': 0.0186799501867995,
#   'k': 0.0037359900373599006,
#   'l': 0.0037359900373599006,
#   'm': 0.0043586550435865505,
#   'i': 0.0112079701120797,
#   'u': 0.00684931506849315,
#   'o': 0.00560398505603985,
#   'b': 0.0018679950186799503,
#   'r': 0.0012453300124533001,
#   'z': 0.0006226650062266501},
#  '%int': {'o': 0.05187319884726225,
#   'e': 0.6829971181556196,
#   'r': 0.15561959654178675,
#   'i': 0.06051873198847262,
#   'u': 0.01729106628242075,
#   'a': 0.01440922190201729,
#   'é': 0.01729106628242075},
#  '%you': {'r': 0.3333333333333333,
#   'n': 0.4074074074074074,
#   't': 0.2222222222222222,
#   's': 0.037037037037037035},
#  '%wha': {'t': 0.3181818181818182,
#   'l': 0.36363636363636365,
#   'r': 0.18181818181818182,
#   'n': 0.045454545454545456,
#   'c': 0.045454545454545456,
#   'u': 0.045454545454545456},
#  '%%%c': {'o': 0.45820763087843835,
#   'a': 0.14942324755989353,
#   'e': 0.03371783496007098,
#   'h': 0.11836734693877551,
#   'r': 0.08589174800354925,
#   'i': 0.030168589174800354,
#   'l': 0.064773735581189,
#   'u': 0.05004436557231588,
#   'd': 0.0001774622892635315,
#   'f': 0.000354924578527063,
#   's': 0.0001774622892635315,
#   'ô': 0.0008873114463176575,
#   'y': 0.004081632653061225,
#   'p': 0.0001774622892635315,
#   'x': 0.0008873114463176575,
#   't': 0.0001774622892635315,
#   'é': 0.001419698314108252,
#   'm': 0.000354924578527063,
#   'w': 0.0001774622892635315,
#   'c': 0.0001774622892635315,
#   'ó': 0.0001774622892635315,
#   'z': 0.0001774622892635315},
#  '%%co': {'u': 0.09263565891472868,
#   'm': 0.22209302325581395,
#   'p': 0.012790697674418604,
#   'n': 0.4166666666666667,
#   'l': 0.053488372093023255,
#   'v': 0.012403100775193798,
#   's': 0.013953488372093023,
#   'r': 0.06589147286821706,
#   'a': 0.017829457364341085,
#   'o': 0.018604651162790697,
#   'f': 0.003875968992248062,
#   't': 0.00813953488372093,
#   'e': 0.0050387596899224806,
#   'd': 0.0027131782945736434,
#   'i': 0.009689922480620155,
#   'w': 0.009689922480620155,
#   'c': 0.011627906976744186,
#   'q': 0.005813953488372093,
#   'g': 0.005813953488372093,
#   'h': 0.001937984496124031,
#   'z': 0.0011627906976744186,
#   'b': 0.0034883720930232558,
#   'x': 0.0011627906976744186,
#   'y': 0.001937984496124031,
#   'k': 0.0003875968992248062,
#   'û': 0.0007751937984496124,
#   'ö': 0.0003875968992248062},
#  '%cou': {'l': 0.05063291139240506,
#   'n': 0.34177215189873417,
#   'r': 0.28270042194092826,
#   'p': 0.10548523206751055,
#   's': 0.029535864978902954,
#   'c': 0.05485232067510549,
#   'g': 0.03375527426160337,
#   'v': 0.06751054852320675,
#   't': 0.02109704641350211,
#   'd': 0.008438818565400843,
#   'e': 0.004219409282700422},
#  'coul': {'d': 0.3333333333333333,
#   'e': 0.4166666666666667,
#   'o': 0.08333333333333333,
#   'a': 0.16666666666666666},
#  '%%ot': {'h': 0.2727272727272727,
#   'r': 0.2727272727272727,
#   't': 0.36363636363636365,
#   'a': 0.09090909090909091},
#  '%oth': {'e': 1.0},
#  'othe': {'r': 0.6086956521739131,
#   's': 0.14492753623188406,
#   'd': 0.10144927536231885,
#   'c': 0.043478260869565216,
#   't': 0.014492753623188406,
#   'o': 0.014492753623188406,
#   'i': 0.028985507246376812,
#   'l': 0.028985507246376812,
#   'q': 0.014492753623188406},
#  '%%so': {'m': 0.07097791798107256,
#   'n': 0.06782334384858044,
#   'o': 0.02996845425867508,
#   'u': 0.23659305993690852,
#   'r': 0.09779179810725552,
#   'c': 0.05993690851735016,
#   'f': 0.028391167192429023,
#   'l': 0.20347003154574134,
#   'i': 0.04100946372239748,
#   'v': 0.012618296529968454,
#   'b': 0.02996845425867508,
#   'w': 0.022082018927444796,
#   'j': 0.011041009463722398,
#   'e': 0.00946372239747634,
#   'd': 0.012618296529968454,
#   'a': 0.014195583596214511,
#   'g': 0.00946372239747634,
#   't': 0.011041009463722398,
#   'y': 0.00473186119873817,
#   'p': 0.02365930599369085,
#   's': 0.0015772870662460567,
#   'z': 0.0015772870662460567},
#  '%som': {'e': 0.4772727272727273,
#   'b': 0.1590909090909091,
#   'm': 0.18181818181818182,
#   's': 0.022727272727272728,
#   'i': 0.022727272727272728,
#   'o': 0.022727272727272728,
#   'a': 0.045454545454545456,
#   'n': 0.06818181818181818},
#  '%%%v': {'e': 0.29255626081938835,
#   'o': 0.1852279284477784,
#   'a': 0.17541834968263129,
#   'i': 0.2683208309290248,
#   'u': 0.020196191575302943,
#   'r': 0.020196191575302943,
#   'b': 0.001154068090017311,
#   'n': 0.004039238315060588,
#   's': 0.0028851702250432777,
#   'é': 0.0051933064050779,
#   'p': 0.0005770340450086555,
#   'ä': 0.0075014425851125215,
#   'æ': 0.001154068090017311,
#   't': 0.001154068090017311,
#   'ö': 0.0005770340450086555,
#   'å': 0.0017311021350259665,
#   'ê': 0.0028851702250432777,
#   'ó': 0.0005770340450086555,
#   'l': 0.0051933064050779,
#   'ô': 0.0005770340450086555,
#   'g': 0.0005770340450086555,
#   'y': 0.001154068090017311,
#   'î': 0.001154068090017311},
#  '%%ve': {'r': 0.5375494071146245,
#   's': 0.0533596837944664,
#   'n': 0.17984189723320157,
#   'i': 0.039525691699604744,
#   'l': 0.037549407114624504,
#   'u': 0.015810276679841896,
#   'x': 0.017786561264822136,
#   'g': 0.019762845849802372,
#   'h': 0.015810276679841896,
#   'e': 0.011857707509881422,
#   'd': 0.01383399209486166,
#   't': 0.03162055335968379,
#   'z': 0.003952569169960474,
#   'c': 0.009881422924901186,
#   'a': 0.003952569169960474,
#   'm': 0.001976284584980237,
#   'o': 0.001976284584980237,
#   'v': 0.001976284584980237,
#   'í': 0.001976284584980237},
#  '%ver': {'y': 0.007434944237918215,
#   's': 0.22676579925650558,
#   'g': 0.048327137546468404,
#   'd': 0.08178438661710037,
#   'b': 0.08921933085501858,
#   'i': 0.06691449814126393,
#   't': 0.10780669144981413,
#   'a': 0.05204460966542751,
#   'r': 0.04460966542750929,
#   'l': 0.07806691449814127,
#   'm': 0.040892193308550186,
#   'o': 0.0037174721189591076,
#   'n': 0.02973977695167286,
#   'v': 0.011152416356877323,
#   'e': 0.011152416356877323,
#   'h': 0.01858736059479554,
#   'w': 0.03345724907063197,
#   'u': 0.0037174721189591076,
#   'z': 0.011152416356877323,
#   'k': 0.01858736059479554,
#   'f': 0.007434944237918215,
#   'p': 0.0037174721189591076,
#   'ä': 0.0037174721189591076},
#  '%%ma': {'n': 0.21855010660980811,
#   'y': 0.013859275053304905,
#   'd': 0.03091684434968017,
#   'k': 0.02025586353944563,
#   't': 0.09381663113006397,
#   's': 0.07249466950959488,
#   'r': 0.1865671641791045,
#   'i': 0.07356076759061833,
#   'c': 0.02771855010660981,
#   'j': 0.02025586353944563,
#   'l': 0.06823027718550106,
#   'g': 0.08102345415778252,
#   'a': 0.022388059701492536,
#   'x': 0.008528784648187633,
#   'm': 0.017057569296375266,
#   'p': 0.008528784648187633,
#   'î': 0.005330490405117271,
#   'u': 0.013859275053304905,
#   'h': 0.0042643923240938165,
#   'z': 0.0042643923240938165,
#   'e': 0.005330490405117271,
#   'w': 0.0021321961620469083,
#   'ñ': 0.0010660980810234541},
#  '%%up': {'o': 0.029411764705882353,
#   'p': 0.08823529411764706,
#   'r': 0.23529411764705882,
#   'w': 0.058823529411764705,
#   's': 0.19117647058823528,
#   'l': 0.08823529411764706,
#   'h': 0.19117647058823528,
#   't': 0.029411764705882353,
#   'b': 0.07352941176470588,
#   'd': 0.014705882352941176},
#  '%upo': {'n': 1.0},
#  '%%ab': {'o': 0.17391304347826086,
#   'l': 0.039525691699604744,
#   'e': 0.05138339920948617,
#   's': 0.25691699604743085,
#   'r': 0.07509881422924901,
#   'a': 0.1225296442687747,
#   'i': 0.043478260869565216,
#   'u': 0.06324110671936758,
#   'j': 0.019762845849802372,
#   'b': 0.05928853754940711,
#   'n': 0.015810276679841896,
#   'h': 0.02766798418972332,
#   'd': 0.03162055335968379,
#   'y': 0.011857707509881422,
#   'g': 0.003952569169960474,
#   'î': 0.003952569169960474},
#  '%abo': {'u': 0.25,
#   'v': 0.045454545454545456,
#   'd': 0.06818181818181818,
#   'a': 0.045454545454545456,
#   'l': 0.1590909090909091,
#   'm': 0.18181818181818182,
#   'r': 0.13636363636363635,
#   'o': 0.06818181818181818,
#   'n': 0.045454545454545456},
#  'abou': {'t': 0.40625, 'r': 0.34375, 'n': 0.21875, 'e': 0.03125},
#  '%%it': {'s': 0.325,
#   'e': 0.175,
#   'a': 0.225,
#   'i': 0.075,
#   'c': 0.075,
#   'h': 0.05,
#   'z': 0.025,
#   'o': 0.025,
#   'k': 0.025},
#  '%onl': {'y': 0.4, 'i': 0.2, 'o': 0.4},
#  '%%ti': {'m': 0.11020408163265306,
#   'l': 0.08979591836734693,
#   'r': 0.08571428571428572,
#   't': 0.06938775510204082,
#   'e': 0.17142857142857143,
#   'd': 0.05714285714285714,
#   'n': 0.12653061224489795,
#   'g': 0.08163265306122448,
#   'p': 0.053061224489795916,
#   'o': 0.012244897959183673,
#   'c': 0.061224489795918366,
#   's': 0.024489795918367346,
#   'j': 0.00816326530612245,
#   'v': 0.004081632653061225,
#   'b': 0.00816326530612245,
#   'a': 0.02040816326530612,
#   'u': 0.00816326530612245,
#   'è': 0.004081632653061225,
#   'f': 0.004081632653061225},
#  '%tim': {'e': 0.2962962962962963,
#   'b': 0.2222222222222222,
#   'i': 0.37037037037037035,
#   'o': 0.07407407407407407,
#   'p': 0.037037037037037035},
#  '%%%l': {'a': 0.25035902345619915,
#   'i': 0.23456199138343706,
#   'e': 0.1938726663475347,
#   'o': 0.18046912398276688,
#   'u': 0.08472953566299665,
#   'y': 0.011488750598372427,
#   'à': 0.0009573958831977022,
#   'b': 0.0014360938247965534,
#   'è': 0.0023934897079942556,
#   'l': 0.014360938247965534,
#   'ä': 0.010052656773575874,
#   'é': 0.004786979415988511,
#   'â': 0.0019147917663954045,
#   'h': 0.0014360938247965534,
#   'å': 0.0028721876495931067,
#   'ì': 0.0004786979415988511,
#   'î': 0.0004786979415988511,
#   't': 0.0004786979415988511,
#   'æ': 0.0004786979415988511,
#   'á': 0.0004786979415988511,
#   'ö': 0.0009573958831977022,
#   'j': 0.0004786979415988511,
#   'v': 0.0004786979415988511},
#  '%%li': {'k': 0.05942622950819672,
#   't': 0.08811475409836066,
#   'f': 0.03278688524590164,
#   'g': 0.0778688524590164,
#   'v': 0.0860655737704918,
#   'n': 0.10655737704918032,
#   'p': 0.010245901639344262,
#   'e': 0.11475409836065574,
#   'b': 0.11065573770491803,
#   's': 0.06352459016393443,
#   'c': 0.05327868852459016,
#   'm': 0.07377049180327869,
#   'a': 0.022540983606557378,
#   'o': 0.010245901639344262,
#   'q': 0.02663934426229508,
#   'l': 0.022540983606557378,
#   'r': 0.006147540983606557,
#   'd': 0.00819672131147541,
#   'z': 0.004098360655737705,
#   'i': 0.0020491803278688526,
#   'u': 0.006147540983606557,
#   'j': 0.010245901639344262,
#   'é': 0.0020491803278688526,
#   'è': 0.0020491803278688526},
#  '%lik': {'e': 0.75,
#   'i': 0.10714285714285714,
#   'a': 0.07142857142857142,
#   's': 0.03571428571428571,
#   'v': 0.03571428571428571},
#  '%lit': {'t': 0.3170731707317073,
#   'e': 0.34146341463414637,
#   'h': 0.024390243902439025,
#   'i': 0.0975609756097561,
#   'l': 0.024390243902439025,
#   'u': 0.04878048780487805,
#   's': 0.024390243902439025,
#   'a': 0.04878048780487805,
#   'r': 0.04878048780487805,
#   'm': 0.024390243902439025},
#  'litt': {'l': 0.28, 'e': 0.44, 'i': 0.12, 'é': 0.08, 'o': 0.04, 'ä': 0.04},
#  'ittl': {'e': 0.75, 'i': 0.25},
#  '%sho': {'u': 0.16,
#   'r': 0.232,
#   'w': 0.152,
#   't': 0.032,
#   'o': 0.072,
#   'p': 0.064,
#   'n': 0.016,
#   'e': 0.072,
#   'c': 0.072,
#   'v': 0.072,
#   'a': 0.032,
#   'd': 0.016,
#   'l': 0.008},
#  'shou': {'l': 0.5, 't': 0.4090909090909091, 's': 0.09090909090909091},
#  'houl': {'d': 1.0},
#  '%%ca': {'n': 0.13690476190476192,
#   'm': 0.05238095238095238,
#   'l': 0.10595238095238095,
#   's': 0.09047619047619047,
#   'r': 0.22380952380952382,
#   'u': 0.05,
#   'p': 0.1130952380952381,
#   't': 0.06190476190476191,
#   'v': 0.036904761904761905,
#   'b': 0.04642857142857143,
#   'k': 0.005952380952380952,
#   'g': 0.004761904761904762,
#   'd': 0.015476190476190477,
#   'f': 0.007142857142857143,
#   'c': 0.02261904761904762,
#   'y': 0.0035714285714285713,
#   'i': 0.009523809523809525,
#   'j': 0.004761904761904762,
#   'ñ': 0.0011904761904761906,
#   'e': 0.0011904761904761906,
#   'w': 0.002380952380952381,
#   'o': 0.0011904761904761906,
#   'h': 0.002380952380952381},
#  '%mad': {'e': 0.21428571428571427,
#   'a': 0.14285714285714285,
#   'n': 0.07142857142857142,
#   'l': 0.07142857142857142,
#   'm': 0.10714285714285714,
#   'd': 0.21428571428571427,
#   'r': 0.10714285714285714,
#   'c': 0.03571428571428571,
#   'h': 0.03571428571428571},
#  '%%di': {'d': 0.005700325732899023,
#   'e': 0.03745928338762215,
#   'f': 0.04071661237785016,
#   's': 0.5732899022801303,
#   't': 0.012214983713355049,
#   'n': 0.021986970684039087,
#   'r': 0.04804560260586319,
#   'v': 0.06270358306188925,
#   'g': 0.03501628664495114,
#   'm': 0.025244299674267102,
#   'c': 0.04234527687296417,
#   'a': 0.04071661237785016,
#   'p': 0.014657980456026058,
#   'x': 0.0024429967426710096,
#   'j': 0.0024429967426710096,
#   'l': 0.016286644951140065,
#   'z': 0.004071661237785016,
#   'o': 0.006514657980456026,
#   'k': 0.004885993485342019,
#   'u': 0.0024429967426710096,
#   'ó': 0.0008143322475570033},
#  '%%su': {'c': 0.08190709046454768,
#   'r': 0.13691931540342298,
#   'b': 0.19926650366748166,
#   'd': 0.008557457212713936,
#   'p': 0.20048899755501223,
#   'n': 0.05134474327628362,
#   'm': 0.04156479217603912,
#   'f': 0.05745721271393643,
#   'g': 0.02567237163814181,
#   'i': 0.05256723716381418,
#   's': 0.04645476772616137,
#   'e': 0.013447432762836185,
#   'l': 0.03667481662591687,
#   'a': 0.009779951100244499,
#   'o': 0.006112469437652812,
#   'j': 0.004889975550122249,
#   'u': 0.014669926650366748,
#   't': 0.0012224938875305623,
#   'h': 0.004889975550122249,
#   'y': 0.003667481662591687,
#   'z': 0.0024449877750611247},
#  '%suc': {'h': 0.13432835820895522,
#   'c': 0.6865671641791045,
#   'k': 0.13432835820895522,
#   'r': 0.014925373134328358,
#   't': 0.014925373134328358,
#   'e': 0.014925373134328358},
#  '%%%g': {'r': 0.25504587155963304,
#   'o': 0.08853211009174312,
#   'e': 0.2509174311926605,
#   'i': 0.05779816513761468,
#   'a': 0.14954128440366973,
#   'l': 0.0926605504587156,
#   'u': 0.07522935779816514,
#   'h': 0.004128440366972477,
#   'é': 0.006880733944954129,
#   'b': 0.00045871559633027525,
#   'n': 0.007339449541284404,
#   'w': 0.0009174311926605505,
#   'j': 0.0009174311926605505,
#   'y': 0.004128440366972477,
#   'å': 0.001834862385321101,
#   'ö': 0.0009174311926605505,
#   'x': 0.0009174311926605505,
#   'ø': 0.0009174311926605505,
#   'ä': 0.00045871559633027525,
#   'ê': 0.00045871559633027525},
#  '%%gr': {'e': 0.13200723327305605,
#   'o': 0.22784810126582278,
#   'a': 0.41952983725135623,
#   'i': 0.13924050632911392,
#   'k': 0.0018083182640144665,
#   'u': 0.059674502712477394,
#   'â': 0.0054249547920434,
#   'é': 0.0018083182640144665,
#   'ö': 0.007233273056057866,
#   'ü': 0.0018083182640144665,
#   'è': 0.0018083182640144665,
#   'ê': 0.0018083182640144665},
#  '%gre': {'a': 0.2361111111111111,
#   'w': 0.041666666666666664,
#   'e': 0.4027777777777778,
#   'y': 0.09722222222222222,
#   'n': 0.09722222222222222,
#   't': 0.027777777777777776,
#   'g': 0.013888888888888888,
#   'c': 0.041666666666666664,
#   'f': 0.013888888888888888,
#   'i': 0.027777777777777776},
#  'grea': {'t': 0.6666666666666666,
#   's': 0.2222222222222222,
#   'b': 0.05555555555555555,
#   'v': 0.05555555555555555},
#  '%%mu': {'s': 0.25249169435215946,
#   'c': 0.04983388704318937,
#   'r': 0.13953488372093023,
#   'l': 0.12624584717607973,
#   't': 0.10963455149501661,
#   'd': 0.019933554817275746,
#   'y': 0.0033222591362126247,
#   'n': 0.05647840531561462,
#   'z': 0.016611295681063124,
#   'j': 0.009966777408637873,
#   'ß': 0.016611295681063124,
#   'u': 0.046511627906976744,
#   'e': 0.046511627906976744,
#   'm': 0.036544850498338874,
#   'g': 0.006644518272425249,
#   'k': 0.013289036544850499,
#   'f': 0.019933554817275746,
#   'i': 0.026578073089700997,
#   'a': 0.0033222591362126247},
#  '%mus': {'t': 0.22666666666666666,
#   'i': 0.28,
#   'c': 0.05333333333333334,
#   's': 0.09333333333333334,
#   'e': 0.10666666666666667,
#   'k': 0.14666666666666667,
#   'l': 0.04,
#   'h': 0.05333333333333334},
#  'thes': {'e': 0.3333333333333333,
#   'i': 0.4,
#   't': 0.2,
#   'a': 0.06666666666666667},
#  '%%tw': {'o': 0.08571428571428572,
#   'e': 0.2,
#   'i': 0.6,
#   'a': 0.11428571428571428},
#  '%bef': {'o': 0.23076923076923078,
#   'a': 0.2692307692307692,
#   'e': 0.11538461538461539,
#   'i': 0.23076923076923078,
#   'r': 0.15384615384615385},
#  'befo': {'r': 0.7142857142857143,
#   'h': 0.14285714285714285,
#   'o': 0.14285714285714285},
#  'efor': {'e': 0.2727272727272727,
#   'm': 0.5757575757575758,
#   't': 0.09090909090909091,
#   'w': 0.06060606060606061},
#  '%%se': {'e': 0.058823529411764705,
#   't': 0.04005006257822278,
#   'n': 0.16145181476846057,
#   'v': 0.03629536921151439,
#   'c': 0.11764705882352941,
#   'a': 0.09011264080100125,
#   's': 0.012515644555694618,
#   'r': 0.15644555694618273,
#   'i': 0.04505632040050062,
#   'p': 0.03379224030037547,
#   'l': 0.06758448060075094,
#   'x': 0.01376720901126408,
#   'u': 0.023779724655819776,
#   'h': 0.010012515644555695,
#   'm': 0.03879849812265332,
#   'd': 0.03128911138923655,
#   'q': 0.017521902377972465,
#   'k': 0.0025031289111389237,
#   'w': 0.010012515644555695,
#   'ñ': 0.007509386733416771,
#   'y': 0.006257822277847309,
#   'g': 0.016270337922403004,
#   'j': 0.0012515644555694619,
#   'z': 0.0012515644555694619},
#  '%%ov': {'e': 0.9393939393939394,
#   'a': 0.048484848484848485,
#   'u': 0.006060606060606061,
#   'i': 0.006060606060606061},
#  '%ove': {'r': 0.9675324675324676,
#   'n': 0.01948051948051948,
#   'j': 0.006493506493506494,
#   's': 0.006493506493506494},
#  '%%%e': {'t': 0.02907168814007268,
#   'n': 0.22266270234555666,
#   'v': 0.036669970267591674,
#   'y': 0.009250082590023126,
#   'a': 0.035678889990089196,
#   'r': 0.05550049554013875,
#   'i': 0.028080607862570203,
#   'l': 0.061446977205153616,
#   's': 0.0637594978526594,
#   'x': 0.2233234225305583,
#   'f': 0.022134126197555334,
#   'e': 0.00958044268252395,
#   'q': 0.017509084902543774,
#   'm': 0.0829203832177073,
#   'd': 0.022464486290056162,
#   'g': 0.009250082590023126,
#   'u': 0.010571522960026428,
#   'c': 0.024777006937561942,
#   'h': 0.003303600925008259,
#   'û': 0.0003303600925008259,
#   'p': 0.017839444995044598,
#   'b': 0.005285761480013214,
#   'j': 0.003964321110009911,
#   'z': 0.0003303600925008259,
#   'k': 0.0009910802775024777,
#   'o': 0.0013214403700033035,
#   'w': 0.0019821605550049554},
#  '%muc': {'h': 0.6,
#   'k': 0.13333333333333333,
#   'o': 0.06666666666666667,
#   'u': 0.06666666666666667,
#   'i': 0.13333333333333333},
#  '%%%k': {'n': 0.13803680981595093,
#   'e': 0.147239263803681,
#   'i': 0.19631901840490798,
#   'u': 0.09049079754601227,
#   'm': 0.0015337423312883436,
#   'a': 0.16104294478527606,
#   'o': 0.12269938650306748,
#   'l': 0.04294478527607362,
#   'w': 0.004601226993865031,
#   'ö': 0.013803680981595092,
#   'y': 0.015337423312883436,
#   'h': 0.003067484662576687,
#   'r': 0.027607361963190184,
#   'ä': 0.027607361963190184,
#   'v': 0.004601226993865031,
#   'g': 0.0015337423312883436,
#   'ü': 0.0015337423312883436},
#  '%%kn': {'o': 0.43333333333333335,
#   'e': 0.18888888888888888,
#   'i': 0.2,
#   'a': 0.14444444444444443,
#   'u': 0.03333333333333333},
#  '%kno': {'w': 0.46153846153846156,
#   'c': 0.20512820512820512,
#   't': 0.1794871794871795,
#   'b': 0.07692307692307693,
#   'l': 0.05128205128205128,
#   'u': 0.02564102564102564},
#  '%%af': {'t': 0.13740458015267176,
#   'r': 0.030534351145038167,
#   'f': 0.6641221374045801,
#   'a': 0.015267175572519083,
#   'o': 0.061068702290076333,
#   'l': 0.030534351145038167,
#   'e': 0.015267175572519083,
#   'i': 0.030534351145038167,
#   's': 0.015267175572519083},
#  '%aft': {'e': 0.875, 'h': 0.0625, 'r': 0.0625},
#  'afte': {'r': 0.8148148148148148,
#   'd': 0.14814814814814814,
#   'n': 0.037037037037037035},
#  '%%fi': {'r': 0.13577023498694518,
#   'n': 0.23237597911227154,
#   'v': 0.007832898172323759,
#   'l': 0.13577023498694518,
#   'g': 0.07049608355091384,
#   't': 0.044386422976501305,
#   'f': 0.031331592689295036,
#   'e': 0.08877284595300261,
#   'x': 0.05483028720626632,
#   's': 0.06005221932114883,
#   'c': 0.02349869451697128,
#   'd': 0.04960835509138381,
#   'b': 0.020887728459530026,
#   'è': 0.007832898172323759,
#   'u': 0.005221932114882507,
#   'a': 0.020887728459530026,
#   'k': 0.0026109660574412533,
#   'j': 0.005221932114882507,
#   'o': 0.0026109660574412533},
#  '%fir': {'s': 0.13725490196078433,
#   'e': 0.5686274509803921,
#   'm': 0.2549019607843137,
#   'i': 0.0392156862745098},
#  'firs': {'t': 1.0},
#  '%%go': {'o': 0.1099476439790576,
#   't': 0.031413612565445025,
#   'i': 0.020942408376963352,
#   'n': 0.06282722513089005,
#   'v': 0.09424083769633508,
#   'l': 0.09424083769633508,
#   'e': 0.05235602094240838,
#   'd': 0.12041884816753927,
#   'w': 0.03664921465968586,
#   's': 0.05235602094240838,
#   'a': 0.06806282722513089,
#   'r': 0.07329842931937172,
#   'u': 0.10471204188481675,
#   'b': 0.04712041884816754,
#   'û': 0.015706806282722512,
#   'g': 0.005235602094240838,
#   'z': 0.005235602094240838,
#   'p': 0.005235602094240838},
#  '%goo': {'d': 0.8, 's': 0.15, 't': 0.05},
#  '%%do': {'w': 0.08439897698209718,
#   'n': 0.1278772378516624,
#   'e': 0.030690537084398978,
#   'o': 0.06905370843989769,
#   'u': 0.1483375959079284,
#   'i': 0.028132992327365727,
#   'm': 0.13554987212276215,
#   'c': 0.08439897698209718,
#   'g': 0.056265984654731455,
#   'l': 0.05115089514066496,
#   'z': 0.017902813299232736,
#   't': 0.03324808184143223,
#   's': 0.020460358056265986,
#   'r': 0.061381074168797956,
#   'v': 0.01278772378516624,
#   'd': 0.010230179028132993,
#   'p': 0.0076726342710997444,
#   'f': 0.0076726342710997444,
#   'ñ': 0.0025575447570332483,
#   'k': 0.0025575447570332483,
#   'y': 0.0025575447570332483,
#   'a': 0.005115089514066497},
#  '%dow': {'n': 0.7878787878787878,
#   'r': 0.06060606060606061,
#   'a': 0.06060606060606061,
#   'e': 0.06060606060606061,
#   'd': 0.030303030303030304},
#  '%%ne': {'v': 0.025806451612903226,
#   'w': 0.07419354838709677,
#   'x': 0.0064516129032258064,
#   'a': 0.07741935483870968,
#   'e': 0.09032258064516129,
#   'c': 0.11935483870967742,
#   'i': 0.0967741935483871,
#   'r': 0.054838709677419356,
#   'g': 0.14193548387096774,
#   's': 0.041935483870967745,
#   'p': 0.00967741935483871,
#   't': 0.04838709677419355,
#   'u': 0.08387096774193549,
#   'l': 0.012903225806451613,
#   'd': 0.012903225806451613,
#   'b': 0.025806451612903226,
#   'h': 0.012903225806451613,
#   'z': 0.0064516129032258064,
#   'n': 0.01935483870967742,
#   'q': 0.0032258064516129032,
#   'm': 0.012903225806451613,
#   'f': 0.00967741935483871,
#   'j': 0.0032258064516129032,
#   'o': 0.0064516129032258064,
#   'k': 0.0032258064516129032},
#  '%nev': {'e': 1.0},
#  'neve': {'r': 0.5454545454545454,
#   'n': 0.36363636363636365,
#   'u': 0.09090909090909091},
#  '%mos': {'t': 0.36363636363636365,
#   's': 0.22727272727272727,
#   'q': 0.3181818181818182,
#   'a': 0.09090909090909091},
#  'wher': {'e': 0.9393939393939394,
#   'r': 0.030303030303030304,
#   'd': 0.030303030303030304},
#  '%tho': {'s': 0.044444444444444446,
#   'u': 0.4888888888888889,
#   'r': 0.37777777777777777,
#   'n': 0.044444444444444446,
#   'c': 0.022222222222222223,
#   't': 0.022222222222222223},
#  'thos': {'e': 1.0},
#  '%%ol': {'d': 0.14814814814814814,
#   'i': 0.37037037037037035,
#   'e': 0.25925925925925924,
#   'l': 0.14814814814814814,
#   'f': 0.018518518518518517,
#   'k': 0.018518518518518517,
#   't': 0.018518518518518517,
#   'h': 0.018518518518518517},
#  '%%me': {'n': 0.14285714285714285,
#   'a': 0.11149825783972125,
#   't': 0.11846689895470383,
#   'e': 0.050522648083623695,
#   'r': 0.13240418118466898,
#   'd': 0.10278745644599303,
#   'm': 0.07142857142857142,
#   's': 0.07491289198606271,
#   'l': 0.06794425087108014,
#   'h': 0.006968641114982578,
#   'i': 0.04529616724738676,
#   'c': 0.024390243902439025,
#   'j': 0.003484320557491289,
#   'b': 0.003484320557491289,
#   'g': 0.006968641114982578,
#   'z': 0.0017421602787456446,
#   'u': 0.020905923344947737,
#   'v': 0.0017421602787456446,
#   'p': 0.0017421602787456446,
#   'w': 0.008710801393728223,
#   'o': 0.0017421602787456446},
#  '%%ow': {'n': 0.52, 'i': 0.04, 'e': 0.24, 'l': 0.12, 'd': 0.04, 'r': 0.04},
#  '%sha': {'l': 0.10569105691056911,
#   'r': 0.23577235772357724,
#   'd': 0.12195121951219512,
#   'p': 0.07317073170731707,
#   'm': 0.13821138211382114,
#   'k': 0.06504065040650407,
#   'f': 0.024390243902439025,
#   't': 0.032520325203252036,
#   'w': 0.024390243902439025,
#   'b': 0.032520325203252036,
#   'g': 0.008130081300813009,
#   'v': 0.04878048780487805,
#   'n': 0.04065040650406504,
#   'c': 0.04878048780487805},
#  'shal': {'l': 0.5555555555555556,
#   't': 0.05555555555555555,
#   's': 0.05555555555555555,
#   'b': 0.16666666666666666,
#   'e': 0.16666666666666666},
#  '%cam': {'e': 0.2558139534883721,
#   'p': 0.5116279069767442,
#   'i': 0.06976744186046512,
#   'a': 0.11627906976744186,
#   'b': 0.046511627906976744},
#  'with': {'o': 0.10526315789473684,
#   'i': 0.05263157894736842,
#   's': 0.15789473684210525,
#   'd': 0.2631578947368421,
#   'e': 0.15789473684210525,
#   'a': 0.13157894736842105,
#   'h': 0.13157894736842105},
#  'itho': {'u': 1.0},
# ...
#   'm': 0.06896551724137931},
#  'livi': {'n': 0.2, 'o': 0.2, 'd': 0.2, 't': 0.4},
#  'ivin': {'g': 0.6415094339622641,
#   'e': 0.16981132075471697,
#   'i': 0.11320754716981132,
#   'a': 0.05660377358490566,
#   'o': 0.018867924528301886},
#  '%blo': {'o': 0.25,
#   'c': 0.2,
#   'w': 0.1375,
#   's': 0.1125,
#   't': 0.1,
#   'n': 0.05,
#   'u': 0.05,
#   'ß': 0.0375,
#   'a': 0.0125,
#   'e': 0.025,
#   'd': 0.0125,
#   'k': 0.0125},
#  'bloo': {'d': 0.7142857142857143,
#   'm': 0.23809523809523808,
#   'n': 0.047619047619047616},
#  '%dau': {'g': 0.3076923076923077,
#   'n': 0.23076923076923078,
#   'p': 0.07692307692307693,
#   'b': 0.23076923076923078,
#   'e': 0.07692307692307693,
#   't': 0.07692307692307693},
#  'daug': {'h': 1.0},
#  'augh': {'t': 0.8269230769230769,
#   'e': 0.038461538461538464,
#   'i': 0.07692307692307693,
#   's': 0.038461538461538464,
#   'a': 0.019230769230769232},
#  'ught': {'e': 0.4186046511627907,
#   's': 0.16279069767441862,
#   'f': 0.11627906976744186,
#   'y': 0.11627906976744186,
#   'l': 0.06976744186046512,
#   'i': 0.11627906976744186},
#  'ghte': {'r': 0.2980769230769231,
#   'd': 0.21153846153846154,
#   'n': 0.3269230769230769,
#   's': 0.057692307692307696,
#   'e': 0.028846153846153848,
#   'o': 0.0673076923076923,
#   't': 0.009615384615384616},
#  'open': {'e': 0.2608695652173913,
#   'i': 0.21739130434782608,
#   'l': 0.08695652173913043,
#   's': 0.21739130434782608,
#   'n': 0.08695652173913043,
#   'c': 0.043478260869565216,
#   'd': 0.08695652173913043},
#  'pene': {'d': 0.43333333333333335,
#   't': 0.5,
#   's': 0.03333333333333333,
#   'n': 0.03333333333333333},
#  '%%ru': {'n': 0.1319796954314721,
#   'l': 0.06091370558375635,
#   's': 0.14720812182741116,
#   'i': 0.09644670050761421,
#   'd': 0.07614213197969544,
#   'e': 0.04060913705583756,
#   'b': 0.09137055837563451,
#   'r': 0.005076142131979695,
#   'g': 0.030456852791878174,
#   'm': 0.1116751269035533,
#   'p': 0.04060913705583756,
#   't': 0.03553299492385787,
#   'f': 0.06598984771573604,
#   'h': 0.030456852791878174,
#   'v': 0.01015228426395939,
#   'u': 0.01015228426395939,
#   'c': 0.005076142131979695,
#   'o': 0.005076142131979695,
#   'a': 0.005076142131979695},
#  '%doi': {'n': 0.36363636363636365,
#   't': 0.09090909090909091,
#   's': 0.09090909090909091,
#   'v': 0.18181818181818182,
#   'g': 0.2727272727272727},
#  'doin': {'g': 1.0},
#  '%fal': {'l': 0.37254901960784315,
#   's': 0.37254901960784315,
#   't': 0.1568627450980392,
#   'c': 0.0784313725490196,
#   'd': 0.0196078431372549},
#  '%%ef': {'f': 0.9393939393939394,
#   't': 0.045454545454545456,
#   'e': 0.015151515151515152},
#  '%eff': {'e': 0.3548387096774194,
#   'o': 0.08064516129032258,
#   'i': 0.1935483870967742,
#   'a': 0.08064516129032258,
#   'u': 0.11290322580645161,
#   'r': 0.12903225806451613,
#   'l': 0.04838709677419355},
#  'effe': {'c': 0.7241379310344828,
#   't': 0.13793103448275862,
#   'm': 0.034482758620689655,
#   'n': 0.06896551724137931,
#   'r': 0.034482758620689655},
#  'ffec': {'t': 1.0},
#  '%roa': {'d': 0.39285714285714285,
#   'r': 0.25,
#   's': 0.17857142857142858,
#   'm': 0.14285714285714285,
#   'n': 0.03571428571428571},
#  '%ava': {'i': 0.4,
#   'n': 0.3,
#   'r': 0.13333333333333333,
#   'l': 0.13333333333333333,
#   's': 0.03333333333333333},
#  'avai': {'t': 0.12903225806451613,
#   'l': 0.7096774193548387,
#   'e': 0.06451612903225806,
#   's': 0.0967741935483871},
#  '%hus': {'b': 0.32142857142857145,
#   'h': 0.14285714285714285,
#   'k': 0.17857142857142858,
#   't': 0.17857142857142858,
#   's': 0.14285714285714285,
#   'e': 0.03571428571428571},
#  'husb': {'a': 1.0},
#  'usba': {'n': 1.0},
#  'sban': {'d': 1.0},
#  'harg': {'e': 0.7142857142857143,
#   'i': 0.10714285714285714,
#   'é': 0.10714285714285714,
#   'y': 0.07142857142857142},
#  '%tri': {'e': 0.032520325203252036,
#   'a': 0.06504065040650407,
#   'u': 0.08943089430894309,
#   'b': 0.21138211382113822,
#   'p': 0.08130081300813008,
#   'c': 0.13821138211382114,
#   'f': 0.06504065040650407,
#   'v': 0.032520325203252036,
#   'm': 0.04065040650406504,
#   'l': 0.04878048780487805,
#   't': 0.016260162601626018,
#   'o': 0.04878048780487805,
#   's': 0.04878048780487805,
#   'n': 0.032520325203252036,
#   'g': 0.024390243902439025,
#   'd': 0.008130081300813009,
#   'r': 0.016260162601626018},
#  'trie': {'d': 0.15384615384615385,
#   's': 0.46153846153846156,
#   'v': 0.19230769230769232,
#   'b': 0.07692307692307693,
#   'r': 0.07692307692307693,
#   'm': 0.038461538461538464},
#  'tain': {'l': 0.04032258064516129,
#   'e': 0.41935483870967744,
#   's': 0.20161290322580644,
#   'i': 0.11290322580645161,
#   't': 0.08870967741935484,
#   'm': 0.06451612903225806,
#   'o': 0.008064516129032258,
#   'a': 0.04838709677419355,
#   'd': 0.008064516129032258,
#   'c': 0.008064516129032258},
#  'ainl': {'y': 0.6428571428571429,
#   'a': 0.14285714285714285,
#   'e': 0.21428571428571427},
#  '%%im': {'p': 0.6971830985915493,
#   'm': 0.16666666666666666,
#   'a': 0.07042253521126761,
#   'i': 0.03051643192488263,
#   'b': 0.028169014084507043,
#   'o': 0.002347417840375587,
#   's': 0.002347417840375587,
#   'e': 0.002347417840375587},
#  '%imp': {'o': 0.22372881355932203,
#   'r': 0.24067796610169492,
#   'u': 0.08813559322033898,
#   'l': 0.09152542372881356,
#   'a': 0.09830508474576272,
#   'e': 0.2271186440677966,
#   'i': 0.023728813559322035,
#   's': 0.003389830508474576,
#   'é': 0.003389830508474576},
#  'impo': {'r': 0.42857142857142855,
#   's': 0.4142857142857143,
#   't': 0.07142857142857142,
#   'v': 0.04285714285714286,
#   'l': 0.04285714285714286},
#  'mpor': {'t': 0.6727272727272727,
#   'a': 0.2,
#   'e': 0.03636363636363636,
#   'i': 0.09090909090909091},
#  'port': {'a': 0.203125,
#   'u': 0.057291666666666664,
#   'i': 0.20833333333333334,
#   'e': 0.2760416666666667,
#   's': 0.10416666666666667,
#   'r': 0.0625,
#   'm': 0.026041666666666668,
#   'l': 0.005208333333333333,
#   'f': 0.015625,
#   'é': 0.03125,
#   'c': 0.005208333333333333,
#   'o': 0.005208333333333333},
#  'orta': {'n': 0.2328767123287671,
#   'b': 0.1780821917808219,
#   'l': 0.273972602739726,
#   't': 0.1095890410958904,
#   'r': 0.0410958904109589,
#   'i': 0.1095890410958904,
#   'g': 0.0547945205479452},
#  'rtan': {'t': 0.7777777777777778, 'c': 0.2222222222222222},
#  'want': {'e': 0.36363636363636365,
#   's': 0.18181818181818182,
#   'i': 0.18181818181818182,
#   'o': 0.2727272727272727},
#  'ante': {'d': 0.2403846153846154,
#   'r': 0.3076923076923077,
#   'e': 0.07692307692307693,
#   's': 0.16346153846153846,
#   'l': 0.057692307692307696,
#   'c': 0.057692307692307696,
#   'a': 0.04807692307692308,
#   'n': 0.038461538461538464,
#   't': 0.009615384615384616},
#  '%ser': {'v': 0.3252032520325203,
#   'i': 0.13821138211382114,
#   'a': 0.08130081300813008,
#   'm': 0.056910569105691054,
#   'e': 0.0975609756097561,
#   'p': 0.04065040650406504,
#   'g': 0.04878048780487805,
#   'o': 0.024390243902439025,
#   'f': 0.024390243902439025,
#   't': 0.008130081300813009,
#   'á': 0.016260162601626018,
#   'r': 0.08130081300813008,
#   'j': 0.008130081300813009,
#   'u': 0.04065040650406504,
#   'í': 0.008130081300813009},
#  'serv': {'i': 0.26153846153846155,
#   'e': 0.38461538461538464,
#   'a': 0.3153846153846154,
#   'o': 0.015384615384615385,
#   'é': 0.023076923076923078},
#  'ervi': {'c': 0.14814814814814814,
#   'e': 0.24074074074074073,
#   'n': 0.16666666666666666,
#   'r': 0.05555555555555555,
#   't': 0.12962962962962962,
#   'l': 0.037037037037037035,
#   's': 0.18518518518518517,
#   'd': 0.018518518518518517,
#   'o': 0.018518518518518517},
#  'rvic': {'e': 0.875, 'i': 0.125},
#  'fron': {'t': 0.9333333333333333, 'd': 0.06666666666666667},
#  '%pro': {'b': 0.03927492447129909,
#   'p': 0.1661631419939577,
#   'v': 0.09516616314199396,
#   'd': 0.0634441087613293,
#   'm': 0.09818731117824774,
#   'u': 0.01812688821752266,
#   'g': 0.03927492447129909,
#   'c': 0.0891238670694864,
#   'o': 0.010574018126888218,
#   't': 0.0755287009063444,
#   'f': 0.1148036253776435,
#   's': 0.07854984894259819,
#   'n': 0.03172205438066465,
#   'h': 0.015105740181268883,
#   'j': 0.022658610271903322,
#   'l': 0.019637462235649546,
#   'w': 0.010574018126888218,
#   'x': 0.0075528700906344415,
#   'i': 0.0015105740181268882,
#   'r': 0.0015105740181268882,
#   'a': 0.0015105740181268882},
#  'prob': {'a': 0.6153846153846154,
#   'l': 0.20512820512820512,
#   'i': 0.05128205128205128,
#   'e': 0.05128205128205128,
#   'r': 0.05128205128205128,
#   'o': 0.02564102564102564},
#  'roba': {'b': 0.4444444444444444, 't': 0.5555555555555556},
#  'obab': {'l': 0.5833333333333334, 'i': 0.4166666666666667},
#  'babl': {'y': 0.46153846153846156, 'e': 0.5384615384615384},
#  '%fut': {'u': 0.75, 'i': 0.25},
#  'futu': {'r': 1.0},
#  'utur': {'e': 0.6, 'i': 0.4},
#  'lace': {'d': 0.3235294117647059,
#   's': 0.29411764705882354,
#   'm': 0.058823529411764705,
#   'n': 0.17647058823529413,
#   'r': 0.08823529411764706,
#   'o': 0.029411764705882353,
#   'e': 0.029411764705882353},
#  '%esp': {'e': 0.32608695652173914,
#   'r': 0.08695652173913043,
#   'i': 0.06521739130434782,
#   'è': 0.043478260869565216,
#   'o': 0.13043478260869565,
#   'í': 0.021739130434782608,
#   'a': 0.15217391304347827,
#   'y': 0.043478260869565216,
#   'é': 0.10869565217391304,
#   'l': 0.021739130434782608},
#  'espe': {'c': 0.5901639344262295,
#   'r': 0.32786885245901637,
#   'a': 0.04918032786885246,
#   'o': 0.01639344262295082,
#   't': 0.01639344262295082},
#  'spec': {'i': 0.2535211267605634,
#   't': 0.647887323943662,
#   'u': 0.06338028169014084,
#   'k': 0.02112676056338028,
#   'e': 0.014084507042253521},
#  'peci': {'a': 0.5,
#   'e': 0.1111111111111111,
#   'f': 0.25,
#   'm': 0.1111111111111111,
#   'o': 0.027777777777777776},
#  'ecia': {'l': 0.5,
#   't': 0.4166666666666667,
#   'b': 0.05555555555555555,
#   'n': 0.027777777777777776},
#  'cial': {'l': 0.32558139534883723,
#   's': 0.06976744186046512,
#   'i': 0.4186046511627907,
#   't': 0.06976744186046512,
#   'e': 0.11627906976744186},
#  'iall': {'y': 0.9705882352941176, 'a': 0.029411764705882353},
#  'quil': {'l': 0.6, 'i': 0.16, 't': 0.16, 's': 0.04, 'a': 0.04},
#  '%des': {'i': 0.16595744680851063,
#   'c': 0.16595744680851063,
#   't': 0.16170212765957448,
#   'e': 0.13191489361702127,
#   'p': 0.2170212765957447,
#   'k': 0.01276595744680851,
#   'o': 0.03829787234042553,
#   's': 0.06808510638297872,
#   'd': 0.00425531914893617,
#   'u': 0.00851063829787234,
#   'h': 0.00425531914893617,
#   'q': 0.00851063829787234,
#   'w': 0.00425531914893617,
#   'z': 0.00425531914893617,
#   'g': 0.00425531914893617},
#  'desi': {'r': 0.42857142857142855,
#   'g': 0.40476190476190477,
#   's': 0.07142857142857142,
#   'e': 0.023809523809523808,
#   'd': 0.047619047619047616,
#   'm': 0.023809523809523808},
#  'esir': {'e': 0.5294117647058824,
#   'a': 0.29411764705882354,
#   'o': 0.058823529411764705,
#   'i': 0.058823529411764705,
#   's': 0.058823529411764705},
#  '%ell': {'e': 0.42857142857142855,
#   'a': 0.14285714285714285,
#   'o': 0.14285714285714285,
#   'i': 0.23809523809523808,
#   's': 0.047619047619047616},
#  '%off': {'i': 0.3291139240506329,
#   'e': 0.45569620253164556,
#   's': 0.0759493670886076,
#   'r': 0.11392405063291139,
#   'h': 0.012658227848101266,
#   'a': 0.012658227848101266},
#  'offi': {'c': 0.7941176470588235, 'n': 0.20588235294117646},
#  'ffic': {'e': 0.18571428571428572,
#   'u': 0.14285714285714285,
#   'i': 0.5857142857142857,
#   'a': 0.07142857142857142,
#   'k': 0.014285714285714285},
#  'reat': {'e': 0.31958762886597936,
#   'l': 0.020618556701030927,
#   'h': 0.2268041237113402,
#   'u': 0.041237113402061855,
#   'm': 0.030927835051546393,
#   'y': 0.041237113402061855,
#   'i': 0.20618556701030927,
#   'n': 0.020618556701030927,
#   's': 0.05154639175257732,
#   'o': 0.030927835051546393,
#   'c': 0.010309278350515464},
#  'eate': {'r': 0.23076923076923078,
#   's': 0.07692307692307693,
#   'd': 0.4461538461538462,
#   'n': 0.23076923076923078,
#   't': 0.015384615384615385},
#  '%%bi': {'g': 0.05699481865284974,
#   'e': 0.07253886010362694,
#   't': 0.13471502590673576,
#   'r': 0.08290155440414508,
#   'l': 0.15025906735751296,
#   'd': 0.07253886010362694,
#   'n': 0.07772020725388601,
#   's': 0.10362694300518134,
#   'j': 0.031088082901554404,
#   'o': 0.06217616580310881,
#   'c': 0.04145077720207254,
#   'a': 0.025906735751295335,
#   'z': 0.010362694300518135,
#   'v': 0.02072538860103627,
#   'b': 0.03626943005181347,
#   'p': 0.010362694300518135,
#   'è': 0.0051813471502590676,
#   'ß': 0.0051813471502590676},
#  'tter': {'s': 0.2119205298013245,
#   'e': 0.2913907284768212,
#   'l': 0.033112582781456956,
#   'n': 0.0728476821192053,
#   'i': 0.2052980132450331,
#   'y': 0.052980132450331126,
#   'a': 0.059602649006622516,
#   'f': 0.026490066225165563,
#   'm': 0.026490066225165563,
#   'c': 0.013245033112582781,
#   't': 0.006622516556291391},
#  '%pea': {'c': 0.34782608695652173,
#   's': 0.1956521739130435,
#   'r': 0.13043478260869565,
#   'k': 0.08695652173913043,
#   'l': 0.08695652173913043,
#   'u': 0.06521739130434782,
#   't': 0.043478260869565216,
#   'n': 0.043478260869565216},
#  'peac': {'e': 0.47619047619047616,
#   'h': 0.42857142857142855,
#   'o': 0.09523809523809523},
#  '%hai': {'r': 0.4166666666666667,
#   'l': 0.3333333333333333,
#   'n': 0.125,
#   'e': 0.08333333333333333,
#   's': 0.041666666666666664},
#  '%ple': {'a': 0.5194805194805194,
#   'n': 0.12987012987012986,
#   'd': 0.06493506493506493,
#   'i': 0.05194805194805195,
#   'b': 0.06493506493506493,
#   'u': 0.11688311688311688,
#   'j': 0.012987012987012988,
#   'k': 0.012987012987012988,
#   't': 0.025974025974025976},
#  'plea': {'s': 0.7692307692307693,
#   'd': 0.21153846153846154,
#   't': 0.019230769230769232},
#  'easu': {'r': 1.0},
#  'asur': {'e': 0.7894736842105263,
#   'y': 0.05263157894736842,
#   'a': 0.13157894736842105,
#   'i': 0.02631578947368421},
#  'live': {'d': 0.06818181818181818,
#   's': 0.13636363636363635,
#   'r': 0.5,
#   'l': 0.18181818181818182,
#   't': 0.045454545454545456,
#   'n': 0.06818181818181818},
#  '%inc': {'l': 0.125,
#   'r': 0.11057692307692307,
#   'h': 0.02403846153846154,
#   'i': 0.09615384615384616,
#   'o': 0.3701923076923077,
#   'a': 0.10096153846153846,
#   'e': 0.07692307692307693,
#   'u': 0.09615384615384616},
#  'incl': {'u': 0.2857142857142857,
#   'i': 0.42857142857142855,
#   'o': 0.21428571428571427,
#   'e': 0.07142857142857142},
#  'nclu': {'d': 0.43478260869565216,
#   's': 0.4782608695652174,
#   'r': 0.043478260869565216,
#   't': 0.043478260869565216},
#  'clud': {'i': 0.1111111111111111, 'e': 0.8888888888888888},
#  'ludi': {'n': 0.625, 'c': 0.375},
#  'udin': {'g': 0.8333333333333334,
#   'o': 0.05555555555555555,
#   'a': 0.1111111111111111},
#  '%%fl': {'d': 0.0029498525073746312,
#   'o': 0.25663716814159293,
#   'e': 0.12094395280235988,
#   'y': 0.017699115044247787,
#   'a': 0.32448377581120946,
#   'i': 0.14454277286135694,
#   'u': 0.12389380530973451,
#   'ü': 0.0029498525073746312,
#   'è': 0.0058997050147492625},
#  '%hor': {'s': 0.30357142857142855,
#   'r': 0.30357142857142855,
#   'i': 0.08928571428571429,
#   'n': 0.16071428571428573,
#   'd': 0.03571428571428571,
#   'a': 0.03571428571428571,
#   'o': 0.017857142857142856,
#   't': 0.05357142857142857},
#  'hors': {'e': 0.8947368421052632, 'h': 0.10526315789473684},
#  '%%gl': {'a': 0.3069306930693069,
#   'o': 0.29207920792079206,
#   'i': 0.16831683168316833,
#   'e': 0.15841584158415842,
#   'u': 0.0594059405940594,
#   'ü': 0.0049504950495049506,
#   'y': 0.0049504950495049506,
#   'ä': 0.0049504950495049506},
#  '%gla': {'d': 0.27419354838709675,
#   's': 0.11290322580645161,
#   'n': 0.1774193548387097,
#   'r': 0.08064516129032258,
#   'c': 0.16129032258064516,
#   'z': 0.04838709677419355,
#   'm': 0.016129032258064516,
#   'u': 0.0967741935483871,
#   'i': 0.016129032258064516,
#   't': 0.016129032258064516},
#  'rema': {'i': 0.2926829268292683,
#   'r': 0.43902439024390244,
#   'c': 0.04878048780487805,
#   'n': 0.0975609756097561,
#   't': 0.0975609756097561,
#   's': 0.024390243902439025},
#  'emai': {'n': 0.8076923076923077,
#   'l': 0.07692307692307693,
#   'd': 0.11538461538461539},
#  'main': {'e': 0.3111111111111111,
#   's': 0.2222222222222222,
#   'i': 0.044444444444444446,
#   't': 0.28888888888888886,
#   'd': 0.044444444444444446,
#   'l': 0.06666666666666667,
#   'm': 0.022222222222222223},
#  'aine': {'d': 0.6274509803921569,
#   'm': 0.029411764705882353,
#   's': 0.1568627450980392,
#   'r': 0.09803921568627451,
#   'e': 0.0196078431372549,
#   't': 0.029411764705882353,
#   'n': 0.0392156862745098},
#  '%opi': {'n': 0.6, 'u': 0.2, 'a': 0.2},
#  'opin': {'i': 0.2, 'g': 0.6, 'e': 0.1, 'q': 0.05, 'j': 0.05},
#  'pini': {'o': 0.7, 'n': 0.2, 'f': 0.1},
#  'inio': {'n': 0.8666666666666667, 'u': 0.13333333333333333},
#  ...}

# %%
def predicterV2(n, probs):
    txt = r'%%%'
    while (curr := input("Next Letter: ")) != '':
        if curr == ' ':
            txt = r'%%%'
            continue

        txt += curr
        top3 = get_top3_weights(txt, probs, n)
        print(f'\n{txt} \nBest 3 letters are: {list(reversed(top3.keys()))}')

# %%
predicterV2(N, second_probs)
# Out:
# %%%hell
# Best 3 letters are: ['e', 's', 'i']
#
# %%%hella
# Best 3 letters are: ['t', 'n', 'r']
#
# %%%a
# Best 3 letters are: ['n', 'l', 'r']
#
# %%%an
# Best 3 letters are: ['n', 't', 'g']
#
# %%%ann
# Best 3 letters are: ['o', 'u', 'i']
#
# %%%anno
# Best 3 letters are: ['u', 'n', 'y']
#
# %%%annou
# Best 3 letters are: ['n', 's']
#
# %%%announ
# Best 3 letters are: ['c', 's']
#
# %%%announc
# Best 3 letters are: ['e', 'i']
#
# %%%announce
# Best 3 letters are: ['d', 'r', 's']

# %% [markdown]
# With quick tests, it seems like the second model seems very similar to the first one. Therefore, for visualization, let's focus on the first table on the [next notebook](letter-stats.ipynb)!

# %%
with open('../data/out/wiki-100k/wiki-100k_probs.json', 'w') as f:
    json.dump(second_probs, f)

with open('../data/out/wiki-100k/wiki-100k_prefix-count.json', 'w') as f:
    json.dump(second_prefix_count, f)

# %% [markdown]
# ## **Third Dataset: WikiNews**
#
# Let's try with real texts to get better frequency of words that are very much used.

# %%
with open('../data/en_wikinews.txt', 'r', encoding='utf-8') as f:
    wikinews = f.read().splitlines()

# %%
def flatmap(lst):
    return [item for sublist in lst for item in sublist.split()]

wikinews = list(
        filter(
            lambda x: x and x.islower() and x.isalpha(),
            flatmap(wikinews)
        )
    )

# %%
wikinews[:10], len(wikinews)
# Out:
# (['in',
#   'a',
#   'statement',
#   'today',
#   'senior',
#   'investigating',
#   'officer',
#   'detective',
#   'superintendent',
#   'mike'],
#  19425254)

# %% [markdown]
# We have A LOT of words! Let's parallelize this process to make it feasible.
#
# Python notebooks are AWFUL with parallelization. Therefore, I created a python script that does the process for us! You can check it [here](parallel_generate_probs.py)
#
# You can run it with the following cell:

# %%
# !python ./parallel_generate_probs.py ../data/en_wikinews.txt 4 --prepro -o wikinews/wikinews
# Out:
# Using 16 cores and chunk size of 1214078
# Processing chunk with 1214078 words
# Processing chunk with 1214078 words
# Processing chunk with 1214078 words
# Processing chunk with 1214078 words
# Processing chunk with 1214078 words
# Processing chunk with 1214078 words
# Processing chunk with 1214078 words
# Processing chunk with 1214078 words
# Chunk processed with 1214078 words
# Processing chunk with 1214078 words
# Chunk processed with 1214078 words
# Processing chunk with 1214078 words
# Chunk processed with 1214078 words
# Processing chunk with 1214078 words
# Chunk processed with 1214078 words
# Chunk processed with 1214078 words
# Processing chunk with 1214078 words
# Chunk processed with 1214078 words
# Chunk processed with 1214078 words
# Chunk processed with 1214078 words
# Processing chunk with 1214078 words
# Chunk processed with 1214078 words
# Processing chunk with 1214078 words
# Chunk processed with 1214078 words
# Chunk processed with 1214078 words
# Processing chunk with 1214078 words
# Processing chunk with 6 words
# Chunk processed with 6 words
# Chunk processed with 1214078 words
# Processing chunk with 1214078 words
# Chunk processed with 1214078 words
# Chunk processed with 1214078 words
# Chunk processed with 1214078 words
# Chunk processed with 1214078 words
# Elapsed time: 24.42s

# %% [markdown]
# Now let's import the results and test!

# %%
import json

with open('../data/out/wikinews_probs.json', 'r') as f:
    wikinews_probs = json.load(f)

# %%
predicterV2(N, wikinews_probs)
# Out:
# %%%a
# Best 3 letters are: ['n', 'r', 's']
#
# %%%an
# Best 3 letters are: ['d', 'y', 'o']

# %% [markdown]
# ## **Fourth Dataset: Kaggle**
#
# Let's test some Kaggle datasets!
#
# ### A. Unigram Frequency
#
# This is the 333,333 most frequent english words and their frequency

# %%
df_unigram = pd.read_csv('../data/unigram_freq.csv')

# %%
df_unigram.head()
# Out:
#   word        count
# 0  the  23135851162
# 1   of  13151942776
# 2  and  12997637966
# 3   to  12136980858
# 4    a   9081174698

# %% [markdown]
# To be able to consider the frequencies, let's take the log:

# %%
df_unigram['log_count'] = np.log(df_unigram['count'])

df_unigram.head()
# Out:
#   word        count  log_count
# 0  the  23135851162  23.864649
# 1   of  13151942776  23.299835
# 2  and  12997637966  23.288033
# 3   to  12136980858  23.219523
# 4    a   9081174698  22.929469

# %%
# Filtering words that are not string
df_unigram = df_unigram[df_unigram['word'].apply(lambda x: type(x) == str)]

# Filtering words that are not alpha
df_unigram = df_unigram[df_unigram['word'].apply(lambda x: x.isalpha())]

# lowering all words
df_unigram['word'] = df_unigram['word'].apply(lambda x: x.lower())

# Filtering words with length 1
df_unigram = df_unigram[df_unigram['word'].apply(len) != 1]

# %%
# Let's keep only the first 100k words
df_unigram = df_unigram[:100000]

# %%
# To create the training set, we will just remove the "words" list from the dataframe
df_unigram_filtered = df_unigram[~df_unigram['word'].isin(words)]

# %%
df_unigram_filtered.head()
# Out:
#          word      count  log_count
# 159      info  352363058  19.680173
# 216      ebay  293178760  19.496293
# 230    hotels  275510917  19.434138
# 255       dvd  256530337  19.362757
# 256  shipping  256521328  19.362722

# %% [markdown]
# Now, we are going to create a txt where each line is a word, and each word on the dataframe will appear log_count times

# %%
df_unigram.shape, df_unigram_filtered.shape
# Out:
# ((100000, 3), (94993, 3))

# %%
with open('../data/unigram_freq_processed.txt', 'w') as f:
    for word, count in zip(df_unigram['word'], df_unigram['log_count']):
        f.write((word + '\n') * int(count))

with open('../data/unigram_freq_filtered.txt', 'w') as f:
    for word, count in zip(df_unigram_filtered['word'], df_unigram_filtered['log_count']):
        f.write((word + '\n') * int(count))

# %%
# !python ./parallel_generate_probs.py ../data/unigram_freq_processed.txt 4 -o kaggle/unigram
# Out:
# Using 16 cores and chunk size of 79131
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Chunk processed with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Chunk processed with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Processing chunk with 79131 words
# Processing chunk with 3 words
# Chunk processed with 3 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Chunk processed with 79131 words
# Elapsed time: 2.23s

# %%
# !python ./parallel_generate_probs.py ../data/unigram_freq_filtered.txt 4 -o kaggle/unigram-filtered
# Out:
# Using 16 cores and chunk size of 73909
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Chunk processed with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 73909 words
# Chunk processed with 73909 words
# Processing chunk with 73909 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Processing chunk with 73909 words
# Chunk processed with 73909 words
# Processing chunk with 73909 words
# Processing chunk with 10 words
# Chunk processed with 10 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Chunk processed with 73909 words
# Elapsed time: 1.79s

# %%
with open('../data/out/kaggle/unigram-filtered_probs.json', 'r') as f:
    import json
    unigram_probs = json.load(f)

# %%
predicterV2(4, unigram_probs)
# Out:
# %%%a
# Best 3 letters are: ['n', 'l', 'r']
#
# %%%an
# Best 3 letters are: ['t', 'a', 'n']
#
# %%%ant
# Best 3 letters are: ['i', 'h', 'e']

# %% [markdown]
# ## **Fifth Dataset: Dictionary**
#
# Let's use `nltk` library and the wordnet dataset to create our data!

# %%
from nltk.corpus import wordnet as wn

def get_all_words():
    words = {}
    for synset in wn.all_synsets():
        for lemma in synset.lemmas():
            words[lemma.name().lower()] = words.get(lemma.name().lower(), 0) + 1

    return words

wordnet = get_all_words()

# %%
# Filter words with "-" and "_"

wordnet = {word: count for word, count in wordnet.items() if '-' not in word and '_' not in word and word.isalpha()}

# %%
# Filter 

wordnet = {word: count for word, count in wordnet.items() if len(word) > 1 and word not in words}

# %%
wordnet
# Out:
# {'abaxial': 1,
#  'dorsal': 2,
#  'adaxial': 1,
#  'ventral': 2,
#  'acroscopic': 1,
#  'basiscopic': 1,
#  'abducent': 2,
#  'abducting': 1,
#  'adducent': 1,
#  'adductive': 1,
#  'adducting': 1,
#  'nascent': 1,
#  'emergent': 2,
#  'dissilient': 1,
#  'parturient': 2,
#  'moribund': 2,
#  'abridged': 1,
#  'shortened': 4,
#  'potted': 3,
#  'unabridged': 2,
#  'uncut': 7,
#  'implicit': 2,
#  'unquestioning': 2,
#  'infinite': 5,
#  'comparative': 3,
#  'relational': 1,
#  'absorbent': 2,
#  'absorptive': 1,
#  'absorbefacient': 1,
#  'sorbefacient': 1,
#  'assimilating': 1,
#  'assimilative': 2,
#  'assimilatory': 1,
#  'hygroscopic': 1,
#  'receptive': 4,
#  'spongy': 2,
#  'spongelike': 2,
#  'thirsty': 4,
#  'nonabsorbent': 1,
#  'nonabsorptive': 1,
#  'repellent': 6,
#  'resistant': 5,
#  'adsorbent': 2,
#  'adsorptive': 1,
#  'chemisorptive': 1,
#  'chemosorptive': 1,
#  'nonadsorbent': 1,
#  'nonadsorptive': 1,
#  'absorbable': 1,
#  'adsorbable': 1,
#  'adsorbate': 2,
#  'abstemious': 2,
#  'abstinent': 2,
#  'abstentious': 1,
#  'ascetic': 3,
#  'ascetical': 2,
#  'austere': 3,
#  'spartan': 5,
#  'gluttonous': 1,
#  'crapulous': 2,
#  'crapulent': 1,
#  'edacious': 1,
#  'esurient': 3,
#  'rapacious': 3,
#  'ravening': 3,
#  'ravenous': 2,
#  'voracious': 2,
#  'wolfish': 2,
#  'greedy': 3,
#  'hoggish': 1,
#  'piggish': 1,
#  'piggy': 2,
#  'porcine': 3,
#  'swinish': 2,
#  'overgreedy': 1,
#  'conceptional': 1,
#  'ideational': 1,
#  'notional': 4,
#  'conceptual': 1,
#  'ideological': 2,
#  'ideologic': 1,
#  'tangible': 4,
#  'abundant': 1,
#  'abounding': 1,
#  'galore': 2,
#  'ample': 3,
#  'copious': 2,
#  'plenteous': 1,
#  'plentiful': 3,
#  'voluminous': 3,
#  'exuberant': 3,
#  'lush': 4,
#  'luxuriant': 3,
#  'profuse': 1,
#  'riotous': 3,
#  'overabundant': 1,
#  'plethoric': 1,
#  'rife': 2,
#  'rampant': 3,
#  'superabundant': 1,
#  'teeming': 1,
#  'torrential': 3,
#  'verdant': 1,
#  'scarce': 2,
#  'abused': 2,
#  'maltreated': 1,
#  'mistreated': 1,
#  'battered': 3,
#  'unabused': 1,
#  'bankable': 2,
#  'unexceptionable': 1,
#  'unimpeachable': 3,
#  'unobjectionable': 3,
#  'unacceptable': 4,
#  'exceptionable': 1,
#  'objectionable': 2,
#  'approachable': 3,
#  'reachable': 1,
#  'getatable': 1,
#  'handy': 4,
#  'inaccessible': 2,
#  'unaccessible': 1,
#  'outback': 2,
#  'pathless': 1,
#  'roadless': 1,
#  'trackless': 2,
#  'untracked': 1,
#  'untrod': 1,
#  'untrodden': 1,
#  'unapproachable': 2,
#  'unreachable': 1,
#  'unreached': 1,
#  'ungetatable': 1,
#  'accommodating': 2,
#  'accommodative': 3,
#  'complaisant': 1,
#  'obliging': 1,
#  'unaccommodating': 2,
#  'unobliging': 1,
#  'disobliging': 1,
#  'uncooperative': 2,
#  'faithful': 5,
#  'surgical': 3,
#  'true': 15,
#  'veracious': 2,
#  'inaccurate': 1,
#  'faulty': 2,
#  'incorrect': 4,
#  'unfaithful': 4,
#  'accustomed': 2,
#  'unaccustomed': 2,
#  'unused': 4,
#  'acidic': 2,
#  'alkaline': 1,
#  'alkalic': 1,
#  'alkalescent': 1,
#  'alcalescent': 1,
#  'saltlike': 1,
#  'amphoteric': 1,
#  'amphiprotic': 1,
#  'acidophilic': 1,
#  'acidophilous': 1,
#  'aciduric': 1,
#  'recognised': 2,
#  'assumptive': 2,
#  'declarable': 1,
#  'putative': 1,
#  'unacknowledged': 2,
#  'unappreciated': 2,
#  'unsung': 2,
#  'unvalued': 1,
#  'unavowed': 3,
#  'unconfessed': 2,
#  'unrecognized': 2,
#  'unrecognised': 2,
#  'acquisitive': 1,
#  'accumulative': 2,
#  'avaricious': 1,
#  'covetous': 2,
#  'grabby': 1,
#  'grasping': 3,
#  'prehensile': 3,
#  'possessive': 4,
#  'plundering': 2,
#  'predaceous': 2,
#  'predacious': 2,
#  'predatory': 3,
#  'sordid': 4,
#  'unacquisitive': 1,
#  'acropetal': 1,
#  'basipetal': 1,
#  'astir': 2,
#  'acrobatic': 1,
#  'gymnastic': 2,
#  'agile': 2,
#  'nimble': 2,
#  'spry': 1,
#  'hyperactive': 1,
#  'overactive': 1,
#  'sporty': 3,
#  'inactive': 10,
#  'deskbound': 1,
#  'abeyant': 1,
#  'dormant': 4,
#  'hypoactive': 1,
#  'underactive': 1,
#  'inert': 3,
#  'sluggish': 3,
#  'soggy': 3,
#  'torpid': 2,
#  'sedentary': 1,
#  'activated': 4,
#  'brisk': 4,
#  'bustling': 1,
#  'springy': 2,
#  'dull': 19,
#  'idle': 10,
#  'strikebound': 1,
#  'indolent': 2,
#  'latent': 2,
#  'quiescent': 4,
#  'activist': 2,
#  'activistic': 1,
#  'proactive': 2,
#  'passive': 4,
#  'resistless': 2,
#  'supine': 2,
#  'unresisting': 1,
#  'eruptive': 3,
#  'extinct': 3,
#  'stative': 1,
#  'counteractive': 1,
#  'existent': 3,
#  'acute': 7,
#  'subacute': 1,
#  'degenerative': 1,
#  'virulent': 3,
#  'avirulent': 1,
#  'adaptive': 1,
#  'adaptative': 1,
#  'reconciling': 1,
#  'adaptational': 1,
#  'adjustive': 1,
#  'maladaptive': 1,
#  'dysfunctional': 2,
#  'nonadaptive': 1,
#  'maladjustive': 1,
#  'addicted': 1,
#  'alcoholic': 3,
#  'dependant': 3,
#  'hooked': 3,
#  'unaddicted': 1,
#  'addictive': 1,
#  'nonaddictive': 1,
#  'additive': 3,
#  'cumulative': 1,
#  'addable': 1,
#  'addible': 1,
#  'complemental': 1,
#  'complementary': 3,
#  'completing': 1,
#  'incremental': 1,
#  'intercalary': 1,
#  'summational': 1,
#  'summative': 1,
#  'supplementary': 2,
#  'supplemental': 2,
#  'subtractive': 1,
#  'ablative': 3,
#  'reductive': 1,
#  'unaddressed': 1,
#  'competent': 3,
#  'inadequate': 2,
#  'unequal': 2,
#  'deficient': 3,
#  'lacking': 2,
#  'incapable': 4,
#  'incompetent': 6,
#  'undermanned': 1,
#  'understaffed': 1,
#  'adhesive': 2,
#  'adherent': 2,
#  'agglutinate': 3,
#  'agglutinative': 2,
#  'bondable': 2,
#  'coherent': 4,
#  'tenacious': 3,
#  'cohesive': 2,
#  'gluey': 1,
#  'glutinous': 1,
#  'gummy': 2,
#  'mucilaginous': 1,
#  'pasty': 4,
#  'sticky': 5,
#  'viscid': 1,
#  'viscous': 2,
#  'gooey': 1,
#  'icky': 2,
#  'gummed': 1,
#  'pitchy': 2,
#  'resinous': 1,
#  'resiny': 1,
#  'tarry': 3,
#  'nonadhesive': 1,
#  'nonglutinous': 1,
#  'nonviscid': 1,
#  'nonresinous': 1,
#  'nonresiny': 1,
#  'ungummed': 1,
#  'adjective': 4,
#  'procedural': 2,
#  'substantive': 4,
#  'adoptable': 1,
#  'unadoptable': 1,
#  'adorned': 1,
#  'decorated': 1,
#  'beady': 2,
#  'gemmed': 1,
#  'jeweled': 1,
#  'jewelled': 1,
#  'sequined': 1,
#  'spangled': 1,
#  'spangly': 1,
#  'bedaubed': 1,
#  'bespectacled': 1,
#  'monocled': 1,
#  'spectacled': 1,
#  'brocaded': 1,
#  'embossed': 1,
#  'buttony': 2,
#  'carbuncled': 2,
#  'champleve': 1,
#  'cloisonne': 2,
#  'clinquant': 1,
#  'tinseled': 1,
#  'tinselly': 1,
#  'crested': 3,
#  'plumed': 3,
#  'topknotted': 1,
#  'tufted': 3,
#  'crocketed': 1,
#  'feathery': 3,
#  'feathered': 2,
#  'plumy': 3,
#  'frilled': 1,
#  'frilly': 1,
#  'ruffled': 2,
#  'fringed': 3,
#  'inflamed': 3,
#  'inlaid': 1,
#  'inwrought': 1,
#  'tessellated': 2,
#  'mounted': 2,
#  'paneled': 1,
#  'wainscoted': 1,
#  'studded': 1,
#  'tapestried': 1,
#  'tasseled': 1,
#  'tasselled': 1,
#  'unadorned': 1,
#  'undecorated': 1,
#  'unembellished': 1,
#  'unornamented': 1,
#  'untufted': 1,
#  'cholinergic': 1,
#  'anticholinergic': 2,
#  'adroit': 1,
#  'neat': 6,
#  'clever': 3,
#  'cunning': 5,
#  'ingenious': 1,
#  'coordinated': 3,
#  'deft': 1,
#  'dexterous': 1,
#  'dextrous': 1,
#  'maladroit': 1,
#  'bumbling': 1,
#  'bungling': 2,
#  'butterfingered': 1,
#  'handless': 2,
#  'inept': 3,
#  'tactless': 2,
#  'uncoordinated': 2,
#  'unmechanical': 1,
#  'nonmechanical': 2,
#  'advantageous': 2,
#  'beneficial': 1,
#  'discriminatory': 4,
#  'preferential': 1,
#  'disadvantageous': 1,
#  'minus': 3,
#  'adventurous': 1,
#  'adventuresome': 1,
#  'audacious': 3,
#  'daring': 4,
#  'venturesome': 1,
#  'venturous': 1,
#  'sporting': 4,
#  'swaggering': 2,
#  'swashbuckling': 2,
#  'unadventurous': 1,
#  'advisable': 1,
#  'inadvisable': 2,
#  'unadvisable': 1,
#  'advised': 2,
#  'unadvised': 2,
#  'aerobic': 2,
#  'aerophilic': 1,
#  'aerophilous': 1,
#  'aerobiotic': 1,
#  'oxidative': 1,
#  'anaerobic': 2,
#  'anaerobiotic': 1,
#  'aesthetic': 4,
#  'esthetic': 4,
#  'aesthetical': 1,
#  'esthetical': 1,
#  'cosmetic': 3,
#  'enhancive': 2,
#  'painterly': 1,
#  'sensuous': 1,
#  'inaesthetic': 1,
#  'unaesthetic': 1,
#  'inartistic': 1,
#  'unartistic': 1,
#  'smitten': 2,
#  'stricken': 3,
#  'unaffected': 4,
#  'immune': 5,
#  'unimpressed': 1,
#  'uninfluenced': 1,
#  'unswayed': 1,
#  'untouched': 4,
#  'unnatural': 3,
#  'agonistic': 3,
#  'strained': 4,
#  'artificial': 3,
#  'contrived': 2,
#  'hokey': 2,
#  'stilted': 1,
#  'constrained': 1,
#  'elocutionary': 2,
#  'mannered': 1,
#  'plummy': 2,
#  'lifelike': 2,
#  'unmannered': 2,
#  'unselfconscious': 1,
#  'unstilted': 1,
#  'affirmative': 4,
#  'affirmatory': 1,
#  'assentient': 1,
#  'dissentient': 2,
#  'dissenting': 1,
#  'dissident': 3,
#  'acceptive': 2,
#  'accepting': 1,
#  'rejective': 1,
#  'dismissive': 2,
#  'repudiative': 1,
#  'afloat': 3,
#  'adrift': 4,
#  'floating': 6,
#  'waterborne': 2,
#  'aground': 2,
#  'acrophobic': 1,
#  'afeard': 1,
#  'afeared': 1,
#  'aghast': 1,
#  'appalled': 1,
#  'dismayed': 1,
#  'agoraphobic': 1,
#  'alarmed': 1,
#  'algophobic': 1,
#  'apprehensive': 3,
#  'hangdog': 2,
#  'claustrophobic': 2,
#  'fearful': 5,
#  'frightened': 2,
#  'horrified': 1,
#  'hunted': 1,
#  'hydrophobic': 2,
#  'aquaphobic': 1,
#  'mysophobic': 1,
#  'panicky': 1,
#  'panicked': 1,
#  'terrified': 1,
#  'numb': 4,
#  'shitless': 1,
#  'triskaidekaphobic': 1,
#  'unnerved': 1,
#  'xenophobic': 1,
#  'unafraid': 2,
#  'fearless': 2,
#  'unapprehensive': 1,
#  'unblinking': 2,
#  'unflinching': 1,
#  'unintimidated': 1,
#  'unshrinking': 1,
#  'unfrightened': 1,
#  'battleful': 1,
#  'bellicose': 1,
#  'combative': 3,
#  'militant': 4,
#  'hostile': 6,
#  'obstreperous': 2,
#  'raptorial': 2,
#  'vulturine': 1,
#  'vulturous': 1,
#  'pugnacious': 2,
#  'scrappy': 1,
#  'truculent': 1,
#  'unaggressive': 1,
#  'nonaggressive': 1,
#  'agitated': 2,
#  'aroused': 6,
#  'distraught': 1,
#  'overwrought': 1,
#  'jolted': 2,
#  'shaken': 1,
#  'feverish': 3,
#  'hectic': 1,
#  'frantic': 2,
#  'frenetic': 1,
#  'phrenetic': 1,
#  'frenzied': 2,
#  'hysterical': 2,
#  'psychedelic': 3,
#  'unagitated': 3,
#  'churning': 2,
#  'roiling': 1,
#  'roiled': 2,
#  'roily': 1,
#  'turbulent': 2,
#  'rippled': 2,
#  'seething': 1,
#  'stirred': 3,
#  'nonturbulent': 1,
#  'unstirred': 1,
#  'agreeable': 3,
#  'disagreeable': 3,
#  'annoying': 2,
#  'bothersome': 1,
#  'galling': 1,
#  'irritating': 3,
#  'nettlesome': 2,
#  'pesky': 1,
#  'pestering': 1,
#  'pestiferous': 4,
#  'plaguy': 2,
#  'plaguey': 3,
#  'teasing': 6,
#  'vexatious': 1,
#  'vexing': 2,
#  'harsh': 6,
#  'abrasive': 3,
#  'stressful': 1,
#  'unsweet': 2,
#  'watchful': 2,
#  'vigilant': 1,
#  'wakeful': 3,
#  'lidless': 3,
#  'sleepless': 2,
#  'unalert': 1,
#  'unwatchful': 1,
#  'unvigilant': 1,
#  'algorithmic': 1,
#  'recursive': 1,
#  'heuristic': 2,
#  'alienable': 1,
#  'appropriable': 1,
#  'assignable': 1,
#  'conveyable': 1,
#  'negotiable': 3,
#  'transferable': 2,
#  'transferrable': 2,
#  'inalienable': 2,
#  'unalienable': 1,
#  'infrangible': 2,
#  'inviolable': 4,
#  'nontransferable': 1,
#  'unassignable': 1,
#  'untransferable': 1,
#  'liveborn': 1,
#  'viable': 2,
#  'deceased': 2,
#  'departed': 3,
#  'assassinated': 1,
#  'bloodless': 5,
#  'exsanguine': 1,
#  'exsanguinous': 1,
#  'breathless': 3,
#  'inanimate': 3,
#  'pulseless': 1,
#  'deathlike': 1,
#  'deathly': 3,
#  'defunct': 2,
#  'doomed': 5,
#  'executed': 1,
#  'lifeless': 4,
#  'exanimate': 1,
#  'nonviable': 1,
#  'slain': 2,
#  'stillborn': 2,
#  'apocrine': 1,
#  'eccrine': 1,
#  'artesian': 1,
#  'subartesian': 1,
#  'alphabetic': 2,
#  'alphabetical': 2,
#  'abecedarian': 3,
#  'alphabetized': 1,
#  'alphabetised': 1,
#  'analphabetic': 4,
#  'altricial': 1,
#  'precocial': 1,
#  'altruistic': 1,
#  'selfless': 1,
#  'egoistic': 1,
#  'egoistical': 1,
#  'egocentric': 2,
#  'ambiguous': 3,
#  'enigmatic': 2,
#  'oracular': 3,
#  'multivalent': 3,
#  'polysemous': 1,
#  'polysemantic': 1,
#  'uncertain': 7,
#  'unambiguous': 2,
#  'monosemous': 1,
#  'ambitious': 2,
#  'pushful': 1,
#  'pushy': 1,
#  'aspirant': 2,
#  'aspiring': 1,
#  'wishful': 2,
#  'compulsive': 3,
#  'manque': 1,
#  'overambitious': 1,
#  'unambitious': 1,
#  'ambitionless': 1,
#  'shiftless': 1,
#  'ametropic': 1,
#  'emmetropic': 1,
#  'meager': 1,
#  'meagre': 1,
#  'meagerly': 2,
#  'stingy': 2,
#  'scrimpy': 1,
#  'scanty': 2,
#  'exiguous': 1,
#  'hardscrabble': 1,
#  'measly': 1,
#  'miserable': 6,
#  'paltry': 2,
#  'anabolic': 2,
#  'catabolic': 2,
#  'katabolic': 2,
#  'anaclinal': 1,
#  'cataclinal': 1,
#  'anastigmatic': 2,
#  'stigmatic': 4,
#  'astigmatic': 1,
#  'anticlinal': 1,
#  'synclinal': 1,
#  'anadromous': 1,
#  'catadromous': 1,
#  'diadromous': 1,
#  'anabatic': 1,
#  'katabatic': 1,
#  'catabatic': 1,
#  'anal': 2,
#  'analogue': 2,
#  'analog': 2,
#  'linear': 5,
#  'analytic': 4,
#  'analytical': 2,
#  'synthetic': 7,
#  'synthetical': 2,
#  'uninflected': 3,
#  'isolating': 1,
#  'polysynthetic': 1,
#  'inflectional': 1,
#  'derivational': 1,
#  'apocarpous': 1,
#  'syncarpous': 1,
#  'aggravated': 2,
#  'provoked': 1,
#  'angered': 1,
#  'enraged': 1,
#  'furious': 3,
#  'infuriated': 1,
#  'maddened': 1,
#  'choleric': 3,
#  'irascible': 2,
#  'huffy': 2,
#  'sore': 4,
#  'indignant': 1,
#  'incensed': 1,
#  'outraged': 1,
#  'umbrageous': 2,
#  'irate': 1,
#  'ireful': 1,
#  'livid': 4,
#  'smoldering': 1,
#  'smouldering': 1,
#  'wrathful': 1,
#  'wroth': 1,
#  'wrothful': 1,
#  'unangry': 1,
#  'resentful': 1,
#  'acrimonious': 1,
#  'rancorous': 1,
#  'unresentful': 1,
#  'unbitter': 1,
#  'sentient': 2,
#  'animate': 7,
#  'sensate': 1,
#  'insentient': 1,
#  'insensate': 2,
#  'unfeeling': 2,
#  'nonliving': 1,
#  'nonconscious': 2,
#  'animated': 2,
#  'enlivened': 2,
#  'spirited': 4,
#  'lively': 6,
#  'reanimated': 1,
#  'revived': 2,
#  'unanimated': 1,
#  'unenlivened': 1,
#  'nameless': 1,
#  'unnamed': 1,
#  'onymous': 1,
#  'binomial': 3,
#  'binominal': 1,
#  'pseudonymous': 1,
#  'antemortem': 1,
#  'postmortem': 4,
#  'postmortal': 1,
#  'antecedent': 5,
#  'anterior': 3,
#  'anticipatory': 1,
#  'prevenient': 1,
#  'preexistent': 1,
#  'preexisting': 1,
#  'attendant': 5,
#  'consequent': 1,
#  'accompanying': 1,
#  'concomitant': 2,
#  'incidental': 5,
#  'ensuant': 1,
#  'resultant': 4,
#  'sequent': 2,
#  'ulterior': 3,
#  'posterior': 4,
#  'antrorse': 1,
#  'retrorse': 1,
#  'decurved': 1,
#  'aquatic': 3,
#  'semiaquatic': 2,
#  'subaquatic': 2,
#  'subaqueous': 1,
#  'submerged': 2,
#  'submersed': 2,
#  'underwater': 2,
#  'terrestrial': 5,
#  'onshore': 3,
#  'overland': 1,
#  'amphibious': 2,
#  'amphibiotic': 1,
#  'preceding': 2,
#  'foregoing': 1,
#  'introductory': 3,
#  'prefatorial': 1,
#  'prefatory': 1,
#  'precedent': 5,
#  'premedical': 2,
#  'preparatory': 1,
#  'preparative': 1,
#  'propaedeutic': 2,
#  'succeeding': 2,
#  'consecutive': 4,
#  'ensuing': 1,
#  'undermentioned': 1,
#  'precedented': 1,
#  'unprecedented': 1,
#  'unexampled': 1,
#  'nonprehensile': 1,
#  'prenatal': 1,
#  'antenatal': 1,
#  'antepartum': 1,
#  'perinatal': 1,
#  'postnatal': 1,
#  'postpartum': 1,
#  'preprandial': 1,
#  'postprandial': 1,
#  'prewar': 1,
#  'postwar': 1,
#  'retrograde': 9,
#  'anterograde': 1,
#  'antemeridian': 1,
#  'postmeridian': 1,
#  'frontal': 7,
#  'prefrontal': 1,
#  'hind': 3,
#  'hinder': 4,
#  'caudal': 4,
#  'retral': 2,
#  'dorsoventral': 1,
#  'appealable': 1,
#  'unappealable': 1,
#  'appendaged': 1,
#  'unappendaged': 1,
#  'appetizing': 1,
#  'appetising': 1,
#  'savory': 7,
#  'savoury': 5,
#  'unappetizing': 1,
#  'unappetising': 1,
#  'offish': 1,
#  'standoffish': 1,
#  'befitting': 1,
#  'inappropriate': 2,
#  'unbefitting': 1,
#  'improper': 3,
#  'callable': 1,
#  'cod': 7,
#  'collectible': 2,
#  'collectable': 2,
#  'payable': 2,
#  'delinquent': 4,
#  'overdue': 1,
#  'receivable': 1,
#  'repayable': 1,
#  'undue': 4,
#  'apropos': 3,
#  'apposite': 1,
#  'apt': 4,
#  'pertinent': 2,
#  'malapropos': 2,
#  'inapposite': 1,
#  'apteral': 2,
#  'amphiprostylar': 1,
#  'amphiprostyle': 1,
#  'amphistylar': 2,
#  'porticoed': 1,
#  'prostyle': 1,
#  'pseudoprostyle': 1,
#  'peripteral': 1,
#  'monopteral': 1,
#  'peristylar': 1,
#  'pseudoperipteral': 1,
#  'arbitrable': 1,
#  'nonarbitrable': 1,
#  'columned': 1,
#  'columnar': 2,
#  'columniform': 1,
#  'columnlike': 1,
#  'colonnaded': 1,
#  'pillared': 1,
#  'noncolumned': 1,
#  'uncolumned': 1,
#  'astylar': 1,
#  'unpillared': 1,
#  'arboreal': 3,
#  'arboreous': 3,
#  'nonarboreal': 1,
#  'arenaceous': 1,
#  'sandlike': 1,
#  'argillaceous': 1,
#  'clayey': 2,
#  'equipped': 4,
#  'weaponed': 1,
#  'militarized': 1,
#  'militarised': 1,
#  'unarmed': 2,
#  'barehanded': 1,
#  'defenseless': 4,
#  'defenceless': 3,
#  'weaponless': 1,
#  'armored': 3,
#  'armoured': 2,
#  'bulletproof': 3,
#  'mailed': 1,
#  'scaled': 2,
#  'unarmored': 2,
#  'unarmoured': 2,
#  'barbed': 2,
#  'barbellate': 1,
#  'briary': 1,
#  'briery': 1,
#  'bristled': 1,
#  'bristly': 2,
#  'burred': 1,
#  'burry': 1,
#  'prickly': 2,
#  'setose': 1,
#  'setaceous': 1,
#  'spiny': 2,
#  'thorny': 2,
#  'bristlelike': 1,
#  'brushlike': 1,
#  'thistlelike': 1,
#  'clawed': 2,
#  'taloned': 1,
#  'thornless': 1,
#  'spineless': 4,
#  'armlike': 1,
#  'brachiate': 3,
#  'armless': 1,
#  'scaly': 2,
#  'scaley': 1,
#  'scaleless': 1,
#  'artful': 2,
#  'crafty': 1,
#  'dodgy': 2,
#  'foxy': 1,
#  'guileful': 1,
#  'knavish': 1,
#  'slick': 10,
#  'sly': 1,
#  'tricksy': 1,
#  'tricky': 3,
#  'wily': 1,
#  'designing': 2,
#  'scheming': 2,
#  'elusive': 4,
#  'manipulative': 1,
#  'pawky': 1,
#  'artless': 4,
#  'careless': 3,
#  'articulate': 7,
#  'eloquent': 1,
#  'facile': 3,
#  'fluent': 2,
#  'inarticulate': 1,
#  'unarticulate': 1,
#  'aphasic': 3,
#  'aphonic': 1,
#  'voiceless': 4,
#  'mute': 5,
#  'incoherent': 3,
#  'tongueless': 2,
#  'unspoken': 2,
#  'wordless': 1,
#  'speechless': 1,
#  'unarticulated': 2,
#  'tongued': 2,
#  'nonspeaking': 1,
#  'articulated': 1,
#  'jointed': 1,
#  'unjointed': 1,
#  'ashamed': 1,
#  'discredited': 2,
#  'disgraced': 1,
#  'dishonored': 1,
#  'shamed': 2,
#  'embarrassed': 2,
#  'humiliated': 2,
#  'mortified': 2,
#  'shamefaced': 3,
#  'sheepish': 2,
#  'unashamed': 1,
#  'barefaced': 2,
#  'bodacious': 2,
#  'brassy': 3,
#  'brazen': 3,
#  'insolent': 2,
#  'shameless': 1,
#  'unblushing': 1,
#  'unabashed': 1,
#  'unembarrassed': 1,
#  'assertive': 1,
#  'cocky': 1,
#  'emphatic': 3,
#  'forceful': 2,
#  'unassertive': 1,
#  'nonassertive': 1,
#  'reticent': 3,
#  'retiring': 3,
#  'associative': 1,
#  'associatory': 1,
#  'associable': 1,
#  'nonassociative': 1,
#  'bespoken': 2,
#  'betrothed': 2,
#  'unattached': 3,
#  'uncommitted': 3,
#  'unengaged': 2,
#  'unpledged': 1,
#  'unpromised': 1,
#  'affixed': 1,
#  'appendant': 1,
#  'basifixed': 1,
#  'glued': 1,
#  'pasted': 1,
#  'unaffixed': 1,
#  'sessile': 2,
#  'stalkless': 1,
#  'pedunculate': 1,
#  ...}

# %%
# !python ./parallel_generate_probs.py ../data/wordnet_words.txt 4 -o wordnet/wordnet
# Out:
# Using 16 cores and chunk size of 4622
# Processing chunk with 4622 words
# Processing chunk with 4622 words
# Processing chunk with 4622 words
# Processing chunk with 4622 words
# Processing chunk with 4622 words
# Chunk processed with 4622 words
# Processing chunk with 4622 words
# Chunk processed with 4622 words
# Processing chunk with 4622 words
# Processing chunk with 4622 words
# Chunk processed with 4622 words
# Processing chunk with 4622 words
# Chunk processed with 4622 words
# Chunk processed with 4622 words
# Chunk processed with 4622 words
# Processing chunk with 4622 words
# Processing chunk with 4622 words
# Chunk processed with 4622 words
# Chunk processed with 4622 words
# Processing chunk with 4622 words
# Processing chunk with 4622 words
# Chunk processed with 4622 words
# Processing chunk with 4622 words
# Chunk processed with 4622 words
# Chunk processed with 4622 words
# Processing chunk with 4622 words
# Processing chunk with 4622 words
# Chunk processed with 4622 words
# Chunk processed with 4622 words
# Chunk processed with 4622 words
# Chunk processed with 4622 words
# Chunk processed with 4622 words
# Processing chunk with 13 words
# Chunk processed with 13 words
# Elapsed time: 1.05s

# %% [markdown]
# Important to note it doesn't include words like "the", "of", "that".

# %%
with open('../data/wordnet_words.txt', 'w') as f:
    for word in wordnet.keys():
        f.write(word + '\n')

# %% [markdown]
# -----
#
# # **Testing Accuracy**

# %% [markdown]
# Now, our goal is to test the accuracy of our model by splitting the words in 80/20 to create a cross-validation-like test. We will shuffle the data, separate it, train the probability table, and then use it to try to predict the next letter for all 4-grams of the testing set.
#
# In that way, we can calculate an accuracy for our model and test different N values!

# %% [markdown]
# ## 1. Words from WordFrequency

# %%
# set seed
np.random.seed(42)

# %%
words = np.array(words)

# shuffle the words
np.random.shuffle(words)

# split the words into 80% training and 20% test
train = words[:int(len(words)*0.8)]
test = words[int(len(words)*0.8):]

# %%
train[:10], test[:10]
# Out:
# (array(['ta', 'tips', 'looks', 'powers', 'practically', 'italian',
#         'command', 'sleep', 'mine', 'bottom'], dtype=object),
#  array(['disagree', 'minority', 'emergency', 'clip', 'awesome', 'jumped',
#         'experiences', 'wolf', 'swear', 'voting'], dtype=object))

# %% [markdown]
# Let's train the model with the training set

# %%
N = 4

train_probs, train_prev_counts = generate_probs(N, train)

# %%
N = 4

def evaluate_model(n, probs, test):
    acc_exact = 0
    acc_top3 = 0
    acc_top5 = 0
    total = 0

    for word in test:
        word = r'%'*(n-1) + str(word)
        for idx in range(4, len(word)):
            prev = word[idx - n:idx]
            
            nxt = word[idx]

            if prev in probs:
                if nxt == max(probs[prev], key=probs[prev].get):
                    acc_exact += 1
                if nxt in list(sorted(probs[prev], key=probs[prev].get, reverse=True))[:3]:
                    acc_top3 += 1
                if nxt in list(sorted(probs[prev], key=probs[prev].get, reverse=True))[:5]:
                    acc_top5 += 1
                total += 1

    return acc_exact / total, acc_top3 / total, acc_top5 / total

# %%
print(evaluate_model(N, train_probs, test))
# Out:
# (0.42818257956448913, 0.6735762144053601, 0.7644472361809045)

# %% [markdown]
# ## 2. Wiki-100k.txt

# %%
words100k = np.array(words100k)

# filter out the words that are in the list "words"
words100k = np.array([word for word in words100k if word not in words])

# %%
train_probs, train_prev_counts = generate_probs(N, words100k)

# %%
print(evaluate_model(N, train_probs, words))
# Out:
# (0.43210376976084314, 0.7168810111655674, 0.8335851420569702)

# %%
print(evaluate_model(N, train_probs, words100k))
# Out:
# (0.48963141499351964, 0.7848177539280111, 0.8966580640760363)

# %% [markdown]
# That is interesting! The accuracy for top 3 increased when we start using some pre-processing into the 100k dataset.

# %% [markdown]
# ## 3. WikiNews
#
# Let's try to use the probabilites to predict the wiki-100k words!

# %%
with open('../data/out/wordnet_probs.json', 'r') as f:
    wikinews_probs = json.load(f)

# %%
print(evaluate_model(N, wikinews_probs, words))
# Out:
# (0.41606928423274264, 0.7024125759615735, 0.8325388450201958)

# %%
print(evaluate_model(N, wikinews_probs, words100k))
# Out:
# (0.4000644916989125, 0.682248216124108, 0.8022471511235756)

# %%
with open('../data/en_wikinews.txt', 'r', encoding='utf-8') as f:
    wikinews_words = f.read().splitlines()

def flatmap(lst):
    return [item for sublist in lst for item in sublist.split()]

wikinews_words = list(
        filter(
            lambda x: x and x.islower() and x.isalpha(),
            flatmap(wikinews_words)
        )
    )

print(evaluate_model(N, wikinews_probs, wikinews_words))
# Out:
# (0.37904610319025484, 0.6429882445285331, 0.8083054314914152)

# %% [markdown]
# ## 4. Unigram Frequency - Kaggle

# %%
with open('../data/out/unigram_probs.json', 'r') as f:
    unigram_probs = json.load(f)

with open('../data/unigram_freq_processed.txt', 'r') as f:
    unigram_words = f.read().splitlines()

# %% [markdown]
# Let's test with all the previous sets:

# %%
print(evaluate_model(4, unigram_probs, words))
# Out:
# (0.46188422082865116, 0.7519483814840323, 0.8671838184652191)

# %%
print(evaluate_model(4, unigram_probs, words100k))
# Out:
# (0.41246404151350335, 0.699955630386427, 0.8207614530901526)

# %%
print(evaluate_model(4, unigram_probs, wikinews_words))
# Out:
# (0.42411277866727887, 0.6979728323347932, 0.8505233322804715)

# %% [markdown]
# Finally, an "overfitting" test:

# %%
print(evaluate_model(4, unigram_probs, unigram_words))
# Out:
# (0.43677892963231385, 0.7277194451999962, 0.8503549837166152)

# %% [markdown]
# ## 5. Wordnet

# %%
with open('../data/out/wordnet_probs.json', 'r') as f:
    wordnet_probs = json.load(f)

with open('../data/wordnet_words.txt', 'r') as f:
    wordnet_words = f.read().splitlines()

# %% [markdown]
# Let's test with all the other sets!

# %%
print(evaluate_model(4, wordnet_probs, words))
# Out:
# (0.41606928423274264, 0.7024125759615735, 0.8325388450201958)

# %%
print(evaluate_model(4, wordnet_probs, words100k))
# Out:
# (0.4000644916989125, 0.682248216124108, 0.8022471511235756)

# %%
print(evaluate_model(4, wordnet_probs, unigram_words))
# Out:
# (0.3663244880587427, 0.6324557087923475, 0.7538018180848113)

# %%
print(evaluate_model(4, wordnet_probs, wikinews_words))
# Out:
# (0.37904610319025484, 0.6429882445285331, 0.8083054314914152)

# %%
print(evaluate_model(4, wordnet_probs, wordnet_words))
# Out:
# (0.4706894691506729, 0.7664761743049329, 0.8842471483629507)

# %% [markdown]
# **Conclusion: the best and most stable results come from the *Kaggle Unigram Dataset*!**
