# %%
import numpy as np
import pandas as pd

# %%
# get a specific page from the xlsx
df_words = pd.read_excel('./data/wordFrequency.xlsx', sheet_name='4 forms (219k)')

# %%
df_words.head()
# Out:
#    rank word      freq  #texts  %caps     blog      web      TVM     spok  \
# 0     1  the  50074257  483041   0.11  6272412  7101104  3784652  5769026
# 1     2   to  25557793  478977   0.02  3579158  3590504  2911924  3427348
# 2     3  and  24821791  478727   0.09  3211226  3458960  1828166  3325442
# 3     4   of  23605964  478144   0.01  2952017  3462140  1486604  2678416
# 4     5    a  21889251  477421   0.05  2783458  2827106  2519099  2716641
#
#        fic  ...     news     acad    blogPM     webPM     TVMPM    spokPM  \
# 0  6311500  ...  6582642  7447070  50480.69  55212.83  29550.39  45736.71
# 1  2871517  ...  3013501  2978222  28805.25  27917.05  22736.17  27171.94
# 2  3064047  ...  2995111  3633119  25844.11  26894.26  14274.24  26364.03
# 3  2330823  ...  2893200  4517563  23757.98  26918.99  11607.33  21234.42
# 4  2749208  ...  2959649  2229222  22401.41  21981.44  19669.01  21537.47
#
#       ficPM     magPM    newsPM    acadPM
# 0  53341.69  53975.61  54070.43  62167.47
# 1  24268.65  25264.13  24753.18  24861.93
# 2  25895.82  26215.95  24602.12  30328.95
# 3  19698.97  26054.07  23765.01  37712.21
# 4  23234.95  24619.48  24310.83  18609.35
#
# [5 rows x 21 columns]

# %%
words = df_words['word'].values
print(words[:10])
# Out:
# ['the' 'to' 'and' 'of' 'a' 'in' 'i' 'that' 'you' 'it']

# %%
N = 4 #4-gram on the way!

def generate_probs(n, words):
    num_transitions = {}

    for word in words:
        word = str(word)
        for idx in range(1, len(word)):
            if idx < n:
                prev = "%"*(n - idx) + word[:idx] # get the n-gram behind
            else:
                prev = word[idx - n:idx] # get the n-gram behind
            
            nxt = word[idx] # get the curr letter

            # if the n-gram isn't already in the dict adds it as an empty dict
            num_transitions.setdefault(prev, {})

            # then updates the count of that n-gram with the following nth word by 1
            num_transitions[prev][nxt] = num_transitions[prev].setdefault(nxt, 0) + 1
        
        # for eacah one of the n-1-grams, count the sum of the occurences of that prefix
        prev_counts = {prev: sum(num_transitions[prev].values()) for prev in num_transitions}

    probs = {}
    for prev, nxt_dict in num_transitions.items():
        # for each n-1-gram prefix, compute the prob that the next one is nxt
        for nxt in nxt_dict:
            probs.setdefault(prev, {})
            probs[prev][nxt] = num_transitions[prev][nxt] / prev_counts[prev]
    
    # returns relative frequency (prob) and absolute frequency for each n-1-gram and following word on the corpus
    return probs, prev_counts

# %%
generate_probs(N, words)
# Out:
# ({'%%%t': {'h': 0.20973782771535582,
#    'o': 0.1348314606741573,
#    'i': 0.06741573033707865,
#    'w': 0.02247191011235955,
#    'a': 0.11235955056179775,
#    'e': 0.19101123595505617,
#    'r': 0.20973782771535582,
#    'u': 0.033707865168539325,
#    'y': 0.0149812734082397,
#    'v': 0.003745318352059925},
#   '%%th': {'e': 0.30357142857142855,
#    'a': 0.10714285714285714,
#    'i': 0.17857142857142858,
#    'o': 0.14285714285714285,
#    'r': 0.23214285714285715,
#    'u': 0.03571428571428571},
#   '%%%a': {'n': 0.11977715877437325,
#    's': 0.07799442896935933,
#    'r': 0.08913649025069638,
#    't': 0.07242339832869081,
#    'l': 0.09192200557103064,
#    'b': 0.03899721448467967,
#    'f': 0.036211699164345405,
#    'g': 0.04735376044568245,
#    'm': 0.036211699164345405,
#    'w': 0.022284122562674095,
#    'c': 0.11420612813370473,
#    'i': 0.022284122562674095,
#    'v': 0.011142061281337047,
#    'd': 0.08913649025069638,
#    'h': 0.005571030640668524,
#    'p': 0.08635097493036212,
#    'u': 0.036211699164345405,
#    'a': 0.002785515320334262},
#   '%%an': {'d': 0.11904761904761904,
#    'y': 0.16666666666666666,
#    'o': 0.047619047619047616,
#    's': 0.07142857142857142,
#    'a': 0.09523809523809523,
#    'i': 0.047619047619047616,
#    'n': 0.19047619047619047,
#    'g': 0.14285714285714285,
#    'c': 0.047619047619047616,
#    'x': 0.023809523809523808,
#    't': 0.047619047619047616},
#   '%%%o': {'f': 0.12598425196850394,
#    'n': 0.06299212598425197,
#    'r': 0.13385826771653545,
#    'u': 0.07086614173228346,
#    't': 0.023622047244094488,
#    'v': 0.05511811023622047,
#    'h': 0.015748031496062992,
#    'w': 0.06299212598425197,
#    'k': 0.023622047244094488,
#    'l': 0.047244094488188976,
#    'p': 0.15748031496062992,
#    'b': 0.09448818897637795,
#    'i': 0.007874015748031496,
#    'c': 0.07086614173228346,
#    'd': 0.015748031496062992,
#    'o': 0.007874015748031496,
#    'x': 0.007874015748031496,
#    's': 0.007874015748031496,
#    "'": 0.007874015748031496},
#   '%%%i': {'n': 0.6210526315789474,
#    't': 0.03684210526315789,
#    's': 0.05789473684210526,
#    'f': 0.005263157894736842,
#    'm': 0.14210526315789473,
#    'd': 0.04736842105263158,
#    'r': 0.02631578947368421,
#    'c': 0.005263157894736842,
#    'i': 0.010526315789473684,
#    'l': 0.021052631578947368,
#    'g': 0.010526315789473684,
#    'o': 0.005263157894736842,
#    'p': 0.005263157894736842,
#    '-': 0.005263157894736842},
#   '%tha': {'t': 0.3333333333333333, 'n': 0.6666666666666666},
#   '%%%y': {'o': 0.42857142857142855,
#    'e': 0.38095238095238093,
#    'a': 0.14285714285714285,
#    'i': 0.047619047619047616},
#   '%%yo': {'u': 0.875, 'r': 0.125},
#   '%%%f': {'o': 0.2,
#    'r': 0.11666666666666667,
#    'i': 0.20416666666666666,
#    'e': 0.11666666666666667,
#    'a': 0.2125,
#    'u': 0.08333333333333333,
#    'l': 0.0625,
#    'b': 0.004166666666666667},
#   '%%fo': {'r': 0.5416666666666666,
#    'u': 0.14583333333333334,
#    'o': 0.10416666666666667,
#    'l': 0.10416666666666667,
#    'c': 0.0625,
#    'x': 0.020833333333333332,
#    's': 0.020833333333333332},
#   '%%%w': {'a': 0.2413793103448276,
#    'i': 0.20114942528735633,
#    'e': 0.16091954022988506,
#    'h': 0.12643678160919541,
#    'o': 0.20689655172413793,
#    'r': 0.06321839080459771},
#   '%%wa': {'s': 0.09523809523809523,
#    'y': 0.07142857142857142,
#    'n': 0.11904761904761904,
#    't': 0.11904761904761904,
#    'r': 0.19047619047619047,
#    'i': 0.07142857142857142,
#    'l': 0.21428571428571427,
#    'k': 0.023809523809523808,
#    'v': 0.047619047619047616,
#    'g': 0.047619047619047616},
#   '%%%h': {'e': 0.23214285714285715,
#    'a': 0.23214285714285715,
#    'i': 0.16666666666666666,
#    'o': 0.25,
#    'u': 0.10714285714285714,
#    't': 0.005952380952380952,
#    'm': 0.005952380952380952},
#   '%%wi': {'t': 0.14285714285714285,
#    'l': 0.2,
#    'f': 0.02857142857142857,
#    'n': 0.34285714285714286,
#    's': 0.14285714285714285,
#    'd': 0.11428571428571428,
#    'r': 0.02857142857142857},
#   '%wit': {'h': 0.6, 'n': 0.4},
#   '%thi': {'s': 0.1, 'n': 0.6, 'r': 0.2, 'c': 0.1},
#   '%%%n': {"'": 0.010416666666666666,
#    'o': 0.28125,
#    'e': 0.3020833333333333,
#    'a': 0.20833333333333334,
#    'i': 0.0625,
#    'u': 0.08333333333333333,
#    'f': 0.010416666666666666,
#    't': 0.010416666666666666,
#    'p': 0.010416666666666666,
#    'b': 0.020833333333333332},
#   "%%n'": {'t': 1.0},
#   '%%%b': {'e': 0.22267206477732793,
#    'u': 0.12550607287449392,
#    'y': 0.008097165991902834,
#    'a': 0.18218623481781376,
#    'o': 0.14979757085020243,
#    'i': 0.10121457489878542,
#    'l': 0.05263157894736842,
#    'r': 0.15789473684210525},
#   '%%ha': {'v': 0.05263157894736842,
#    'd': 0.02631578947368421,
#    's': 0.02631578947368421,
#    'r': 0.23684210526315788,
#    'n': 0.2631578947368421,
#    'p': 0.15789473684210525,
#    'l': 0.05263157894736842,
#    'i': 0.02631578947368421,
#    't': 0.07894736842105263,
#    'b': 0.05263157894736842,
#    'm': 0.02631578947368421},
#   '%hav': {'e': 0.5, 'i': 0.5},
#   '%%ar': {'e': 0.125,
#    'o': 0.03125,
#    't': 0.25,
#    'm': 0.125,
#    'g': 0.1875,
#    'r': 0.15625,
#    'a': 0.0625,
#    'i': 0.03125,
#    'c': 0.03125},
#   '%%no': {'t': 0.3076923076923077,
#    'w': 0.07692307692307693,
#    'r': 0.19230769230769232,
#    'b': 0.038461538461538464,
#    'n': 0.07692307692307693,
#    'v': 0.11538461538461539,
#    's': 0.038461538461538464,
#    'i': 0.038461538461538464,
#    'd': 0.038461538461538464,
#    'o': 0.038461538461538464,
#    'm': 0.038461538461538464},
#   '%%bu': {'t': 0.12903225806451613,
#    's': 0.16129032258064516,
#    'i': 0.12903225806451613,
#    'y': 0.06451612903225806,
#    'd': 0.06451612903225806,
#    'n': 0.03225806451612903,
#    'r': 0.25806451612903225,
#    'c': 0.06451612903225806,
#    'l': 0.0967741935483871},
#   '%the': {'y': 0.0625,
#    'r': 0.1875,
#    'i': 0.0625,
#    'm': 0.25,
#    'n': 0.0625,
#    's': 0.0625,
#    'o': 0.1875,
#    'a': 0.125},
#   '%%%d': {'o': 0.10954063604240283,
#    'i': 0.24734982332155478,
#    'a': 0.10954063604240283,
#    'u': 0.028268551236749116,
#    'e': 0.3745583038869258,
#    'r': 0.1166077738515901,
#    'y': 0.007067137809187279,
#    'n': 0.0035335689045936395,
#    'c': 0.0035335689045936395},
#   '%%wh': {'a': 0.09090909090909091,
#    'o': 0.2727272727272727,
#    'e': 0.36363636363636365,
#    'i': 0.22727272727272727,
#    'y': 0.045454545454545456},
#   '%wha': {'t': 1.0},
#   '%%hi': {'s': 0.2222222222222222,
#    'm': 0.07407407407407407,
#    'g': 0.18518518518518517,
#    't': 0.1111111111111111,
#    'l': 0.1111111111111111,
#    'd': 0.1111111111111111,
#    'r': 0.1111111111111111,
#    'p': 0.037037037037037035,
#    'v': 0.037037037037037035},
#   '%%fr': {'o': 0.10714285714285714,
#    'e': 0.2857142857142857,
#    'i': 0.17857142857142858,
#    'a': 0.32142857142857145,
#    'u': 0.10714285714285714},
#   '%fro': {'m': 0.3333333333333333,
#    'n': 0.3333333333333333,
#    'z': 0.3333333333333333},
#   '%%%s': {'h': 0.08872458410351201,
#    'o': 0.08687615526802218,
#    'a': 0.07208872458410351,
#    'e': 0.14972273567467653,
#    't': 0.19963031423290203,
#    'u': 0.12199630314232902,
#    'c': 0.051756007393715345,
#    'i': 0.08687615526802218,
#    'y': 0.009242144177449169,
#    'm': 0.022181146025878003,
#    'p': 0.06284658040665435,
#    'l': 0.022181146025878003,
#    'k': 0.009242144177449169,
#    'w': 0.012939001848428836,
#    'q': 0.0018484288354898336,
#    'n': 0.0018484288354898336},
#   '%%sh': {'e': 0.14583333333333334,
#    'o': 0.4791666666666667,
#    'a': 0.25,
#    'i': 0.10416666666666667,
#    'u': 0.020833333333333332},
#   '%%%m': {'y': 0.016194331983805668,
#    'e': 0.18218623481781376,
#    'o': 0.20242914979757085,
#    'a': 0.340080971659919,
#    'u': 0.05668016194331984,
#    'i': 0.17408906882591094,
#    'r': 0.008097165991902834,
#    's': 0.004048582995951417,
#    'm': 0.008097165991902834,
#    'c': 0.004048582995951417,
#    'g': 0.004048582995951417},
#   '%%al': {'l': 0.3125,
#    's': 0.03125,
#    'w': 0.03125,
#    'r': 0.0625,
#    'm': 0.03125,
#    'o': 0.09375,
#    't': 0.0625,
#    'i': 0.09375,
#    'b': 0.03125,
#    'c': 0.03125,
#    'e': 0.09375,
#    'a': 0.125},
#   'ther': {'e': 0.23076923076923078,
#    's': 0.3076923076923077,
#    'w': 0.07692307692307693,
#    'n': 0.15384615384615385,
#    'a': 0.07692307692307693,
#    'm': 0.07692307692307693,
#    'i': 0.07692307692307693},
#   '%%he': {'r': 0.18421052631578946,
#    'l': 0.23684210526315788,
#    'a': 0.47368421052631576,
#    'y': 0.02631578947368421,
#    'n': 0.05263157894736842,
#    'i': 0.02631578947368421},
#   '%%ab': {'o': 0.21428571428571427,
#    'l': 0.07142857142857142,
#    'i': 0.14285714285714285,
#    's': 0.2857142857142857,
#    'u': 0.07142857142857142,
#    'c': 0.07142857142857142,
#    'a': 0.07142857142857142,
#    'r': 0.07142857142857142},
#   '%abo': {'u': 0.3333333333333333,
#    'v': 0.3333333333333333,
#    'r': 0.3333333333333333},
#   'abou': {'t': 1.0},
#   '%%on': {'e': 0.2857142857142857,
#    'l': 0.2857142857142857,
#    'c': 0.14285714285714285,
#    't': 0.14285714285714285,
#    'g': 0.14285714285714285},
#   '%you': {'r': 0.5, 'n': 0.3333333333333333, 't': 0.16666666666666666},
#   '%%%c': {'a': 0.1442687747035573,
#    'o': 0.45652173913043476,
#    'h': 0.14031620553359683,
#    'i': 0.02766798418972332,
#    'e': 0.03162055335968379,
#    'l': 0.08300395256916997,
#    'u': 0.037549407114624504,
#    'r': 0.07312252964426877,
#    'n': 0.001976284584980237,
#    'y': 0.001976284584980237,
#    'b': 0.001976284584980237},
#   '%%ca': {'n': 0.09722222222222222,
#    'm': 0.1111111111111111,
#    'l': 0.1388888888888889,
#    's': 0.05555555555555555,
#    'r': 0.2777777777777778,
#    'u': 0.06944444444444445,
#    'p': 0.1111111111111111,
#    't': 0.08333333333333333,
#    'b': 0.041666666666666664,
#    'k': 0.013888888888888888},
#   '%%ou': {'t': 0.5555555555555556,
#    'r': 0.3333333333333333,
#    'g': 0.1111111111111111},
#   'thei': {'r': 1.0},
#   '%%we': {'r': 0.037037037037037035,
#    'l': 0.14814814814814814,
#    'n': 0.037037037037037035,
#    'e': 0.14814814814814814,
#    's': 0.07407407407407407,
#    'i': 0.07407407407407407,
#    'b': 0.07407407407407407,
#    'a': 0.2962962962962963,
#    'd': 0.07407407407407407,
#    't': 0.037037037037037035},
#   '%wer': {'e': 1.0},
#   '%%%l': {'i': 0.25773195876288657,
#    'o': 0.23195876288659795,
#    'e': 0.22164948453608246,
#    'a': 0.24742268041237114,
#    'u': 0.030927835051546393,
#    'y': 0.005154639175257732,
#    't': 0.005154639175257732},
#   '%%li': {'k': 0.08,
#    't': 0.12,
#    'f': 0.1,
#    'v': 0.08,
#    'n': 0.14,
#    'g': 0.04,
#    's': 0.14,
#    'm': 0.08,
#    'e': 0.08,
#    'b': 0.08,
#    'p': 0.02,
#    'c': 0.02,
#    'q': 0.02},
#   '%lik': {'e': 1.0},
#   '%%%j': {'u': 0.22666666666666666,
#    'o': 0.3466666666666667,
#    'a': 0.21333333333333335,
#    'e': 0.17333333333333334,
#    'i': 0.02666666666666667,
#    'r': 0.013333333333333334},
#   '%%ju': {'s': 0.23529411764705882,
#    'd': 0.29411764705882354,
#    'n': 0.11764705882352941,
#    'l': 0.11764705882352941,
#    'r': 0.058823529411764705,
#    'm': 0.11764705882352941,
#    'i': 0.058823529411764705},
#   '%jus': {'t': 1.0},
#   '%%wo': {'u': 0.08571428571428572,
#    'r': 0.5428571428571428,
#    'm': 0.05714285714285714,
#    'n': 0.14285714285714285,
#    'w': 0.02857142857142857,
#    'o': 0.08571428571428572,
#    'l': 0.02857142857142857,
#    'k': 0.02857142857142857},
#   '%wou': {'l': 0.3333333333333333, 'n': 0.6666666666666666},
#   'woul': {'d': 1.0},
#   '%%%u': {'p': 0.1016949152542373,
#    's': 0.1864406779661017,
#    'n': 0.5254237288135594,
#    'h': 0.03389830508474576,
#    'm': 0.01694915254237288,
#    'l': 0.03389830508474576,
#    'r': 0.03389830508474576,
#    'g': 0.01694915254237288,
#    'k': 0.01694915254237288,
#    't': 0.03389830508474576},
#   '%whe': {'n': 0.25, 'r': 0.375, 't': 0.125, 'e': 0.25},
#   '%%mo': {'r': 0.14,
#    's': 0.06,
#    'n': 0.16,
#    't': 0.1,
#    'v': 0.16,
#    'm': 0.08,
#    'd': 0.12,
#    'u': 0.1,
#    'o': 0.06,
#    'b': 0.02},
#   '%mor': {'e': 0.2857142857142857,
#    'n': 0.14285714285714285,
#    'a': 0.14285714285714285,
#    'g': 0.14285714285714285,
#    't': 0.14285714285714285,
#    'r': 0.14285714285714285},
#   '%wil': {'l': 0.5714285714285714,
#    'd': 0.2857142857142857,
#    's': 0.14285714285714285},
#   '%%%k': {'n': 0.24444444444444444,
#    'i': 0.35555555555555557,
#    'e': 0.26666666666666666,
#    'o': 0.06666666666666667,
#    'a': 0.06666666666666667},
#   '%%kn': {'o': 0.6363636363636364,
#    'e': 0.2727272727272727,
#    'i': 0.09090909090909091},
#   '%kno': {'w': 0.7142857142857143, 'c': 0.2857142857142857},
#   '%%sa': {'i': 0.05128205128205128,
#    'y': 0.07692307692307693,
#    'm': 0.10256410256410256,
#    'w': 0.02564102564102564,
#    'n': 0.1282051282051282,
#    'v': 0.10256410256410256,
#    'f': 0.05128205128205128,
#    't': 0.1282051282051282,
#    'l': 0.1282051282051282,
#    'd': 0.05128205128205128,
#    'r': 0.02564102564102564,
#    'k': 0.02564102564102564,
#    'u': 0.05128205128205128,
#    'c': 0.05128205128205128},
#   '%sai': {'d': 0.5, 'n': 0.5},
#   '%%di': {'d': 0.014285714285714285,
#    'f': 0.1,
#    'r': 0.12857142857142856,
#    'e': 0.05714285714285714,
#    's': 0.4714285714285714,
#    'n': 0.02857142857142857,
#    'v': 0.1,
#    'g': 0.02857142857142857,
#    'c': 0.014285714285714285,
#    'a': 0.05714285714285714},
#   '%%be': {'e': 0.05555555555555555,
#    'c': 0.09259259259259259,
#    'f': 0.018518518518518517,
#    'i': 0.037037037037037035,
#    't': 0.05555555555555555,
#    's': 0.05555555555555555,
#    'l': 0.16666666666666666,
#    'h': 0.09259259259259259,
#    'g': 0.09259259259259259,
#    'y': 0.018518518518518517,
#    'a': 0.16666666666666666,
#    'd': 0.037037037037037035,
#    'n': 0.1111111111111111},
#   '%bee': {'n': 0.3333333333333333,
#    'r': 0.3333333333333333,
#    'f': 0.3333333333333333},
#   '%%%p': {'e': 0.10852713178294573,
#    'r': 0.3281653746770026,
#    'u': 0.06201550387596899,
#    'a': 0.18604651162790697,
#    'l': 0.07751937984496124,
#    'o': 0.13178294573643412,
#    'h': 0.05167958656330749,
#    'i': 0.041343669250646,
#    'm': 0.002583979328165375,
#    's': 0.00516795865633075,
#    'p': 0.002583979328165375,
#    'c': 0.002583979328165375},
#   '%%pe': {'o': 0.047619047619047616,
#    'r': 0.6428571428571429,
#    'a': 0.07142857142857142,
#    't': 0.07142857142857142,
#    'p': 0.023809523809523808,
#    'n': 0.09523809523809523,
#    'e': 0.047619047619047616},
#   '%peo': {'p': 1.0},
#   'peop': {'l': 1.0},
#   'eopl': {'e': 1.0},
#   '%%%g': {'e': 0.16,
#    'o': 0.18666666666666668,
#    'r': 0.24,
#    'i': 0.07333333333333333,
#    'a': 0.16,
#    'u': 0.11333333333333333,
#    'l': 0.04666666666666667,
#    'h': 0.006666666666666667,
#    'y': 0.006666666666666667,
#    'm': 0.006666666666666667},
#   '%%ge': {'t': 0.125,
#    'n': 0.6666666666666666,
#    'o': 0.08333333333333333,
#    'r': 0.08333333333333333,
#    'a': 0.041666666666666664},
#   '%%ti': {'m': 0.2222222222222222,
#    't': 0.1111111111111111,
#    'n': 0.05555555555555555,
#    'r': 0.05555555555555555,
#    'g': 0.05555555555555555,
#    'l': 0.05555555555555555,
#    'e': 0.16666666666666666,
#    'p': 0.1111111111111111,
#    'c': 0.1111111111111111,
#    's': 0.05555555555555555},
#   '%tim': {'e': 0.6666666666666666, 'i': 0.3333333333333333},
#   '%%so': {'m': 0.17391304347826086,
#    'c': 0.08695652173913043,
#    'r': 0.06521739130434782,
#    'n': 0.08695652173913043,
#    'u': 0.21739130434782608,
#    'o': 0.043478260869565216,
#    'l': 0.1956521739130435,
#    'f': 0.043478260869565216,
#    'v': 0.021739130434782608,
#    'i': 0.021739130434782608,
#    '-': 0.021739130434782608,
#    'p': 0.021739130434782608},
#   '%som': {'e': 1.0},
#   '%%ho': {'w': 0.07142857142857142,
#    'm': 0.07142857142857142,
#    'u': 0.16666666666666666,
#    'p': 0.11904761904761904,
#    'l': 0.19047619047619047,
#    't': 0.047619047619047616,
#    's': 0.07142857142857142,
#    'n': 0.11904761904761904,
#    'r': 0.11904761904761904,
#    'o': 0.023809523809523808},
#   '%whi': {'c': 0.2, 'l': 0.2, 't': 0.4, 's': 0.2},
#   'whic': {'h': 1.0},
#   '%%co': {'u': 0.09130434782608696,
#    'm': 0.24782608695652175,
#    'n': 0.4043478260869565,
#    'l': 0.07391304347826087,
#    's': 0.008695652173913044,
#    'v': 0.021739130434782608,
#    'o': 0.02608695652173913,
#    'a': 0.030434782608695653,
#    'f': 0.004347826086956522,
#    'r': 0.05217391304347826,
#    'd': 0.004347826086956522,
#    'p': 0.021739130434782608,
#    'g': 0.004347826086956522,
#    't': 0.004347826086956522,
#    'h': 0.004347826086956522},
#   '%cou': {'l': 0.047619047619047616,
#    'n': 0.5238095238095238,
#    'r': 0.23809523809523808,
#    'p': 0.09523809523809523,
#    's': 0.047619047619047616,
#    'c': 0.047619047619047616},
#   'coul': {'d': 1.0},
#   'thin': {'k': 0.2727272727272727, 'g': 0.7272727272727273},
#   '%%in': {'t': 0.26495726495726496,
#    'f': 0.05982905982905983,
#    'c': 0.13675213675213677,
#    's': 0.1623931623931624,
#    'd': 0.13675213675213677,
#    'v': 0.13675213675213677,
#    'i': 0.02564102564102564,
#    'j': 0.02564102564102564,
#    'n': 0.02564102564102564,
#    'g': 0.008547008547008548,
#    'e': 0.008547008547008548,
#    'p': 0.008547008547008548},
#   '%int': {'o': 0.03333333333333333, 'e': 0.8666666666666667, 'r': 0.1},
#   '%%ot': {'h': 1.0},
#   '%oth': {'e': 1.0},
#   'othe': {'r': 0.9090909090909091, 's': 0.09090909090909091},
#   '%%%r': {'i': 0.05901639344262295,
#    'e': 0.6524590163934426,
#    'o': 0.12131147540983607,
#    'u': 0.03934426229508197,
#    'a': 0.12131147540983607,
#    'y': 0.003278688524590164,
#    'h': 0.003278688524590164},
#   '%%ri': {'g': 0.1111111111111111,
#    's': 0.2222222222222222,
#    'v': 0.1111111111111111,
#    'c': 0.2222222222222222,
#    'd': 0.2222222222222222,
#    'n': 0.1111111111111111},
#   '%rig': {'h': 1.0},
#   'righ': {'t': 1.0},
#   '%her': {'e': 0.16666666666666666,
#    's': 0.3333333333333333,
#    'o': 0.3333333333333333,
#    'i': 0.16666666666666666},
#   '%wel': {'l': 0.5, 'c': 0.25, 'f': 0.25},
#   '%%ne': {'w': 0.1724137931034483,
#    'e': 0.10344827586206896,
#    'v': 0.06896551724137931,
#    'x': 0.034482758620689655,
#    'a': 0.10344827586206896,
#    'c': 0.10344827586206896,
#    't': 0.10344827586206896,
#    'i': 0.1724137931034483,
#    'g': 0.06896551724137931,
#    'r': 0.034482758620689655,
#    'l': 0.034482758620689655},
#   '%bec': {'a': 0.4, 'o': 0.6},
#   'beca': {'u': 0.5, 'm': 0.5},
#   'ecau': {'s': 1.0},
#   'caus': {'e': 0.8, 'i': 0.2},
#   '%%se': {'e': 0.14814814814814814,
#    'c': 0.14814814814814814,
#    't': 0.08641975308641975,
#    'v': 0.037037037037037035,
#    'n': 0.13580246913580246,
#    'r': 0.12345679012345678,
#    'a': 0.1111111111111111,
#    'x': 0.037037037037037035,
#    'l': 0.07407407407407407,
#    'p': 0.04938271604938271,
#    's': 0.024691358024691357,
#    'q': 0.012345679012345678,
#    'g': 0.012345679012345678},
#   '%%ba': {'c': 0.1111111111111111,
#    'd': 0.044444444444444446,
#    's': 0.17777777777777778,
#    'b': 0.044444444444444446,
#    'n': 0.13333333333333333,
#    'l': 0.13333333333333333,
#    'r': 0.15555555555555556,
#    't': 0.06666666666666667,
#    'g': 0.06666666666666667,
#    'y': 0.022222222222222223,
#    'k': 0.044444444444444446},
#   '%bac': {'k': 0.8, 't': 0.2},
#   '%onl': {'y': 0.5, 'i': 0.5},
#   'thes': {'e': 1.0},
#   '%%ov': {'e': 1.0},
#   '%ove': {'r': 0.8571428571428571, 'n': 0.14285714285714285},
#   '%%go': {'i': 0.037037037037037035,
#    'o': 0.18518518518518517,
#    't': 0.07407407407407407,
#    'd': 0.1111111111111111,
#    'v': 0.14814814814814814,
#    'n': 0.07407407407407407,
#    'e': 0.037037037037037035,
#    'a': 0.07407407407407407,
#    'l': 0.1111111111111111,
#    'p': 0.037037037037037035,
#    'r': 0.07407407407407407,
#    's': 0.037037037037037035},
#   '%goi': {'n': 1.0},
#   'goin': {'g': 1.0},
#   '%als': {'o': 1.0},
#   '%%tw': {'o': 0.16666666666666666, 'i': 0.5, 'e': 0.3333333333333333},
#   '%%fi': {'r': 0.14285714285714285,
#    'n': 0.2653061224489796,
#    'v': 0.02040816326530612,
#    'g': 0.12244897959183673,
#    'e': 0.04081632653061224,
#    'l': 0.16326530612244897,
#    's': 0.061224489795918366,
#    't': 0.04081632653061224,
#    'x': 0.04081632653061224,
#    'f': 0.061224489795918366,
#    'c': 0.02040816326530612,
#    'b': 0.02040816326530612},
#   '%fir': {'s': 0.14285714285714285,
#    'e': 0.42857142857142855,
#    'm': 0.2857142857142857,
#    'i': 0.14285714285714285},
#   'firs': {'t': 1.0},
#   '%%it': {'s': 0.3333333333333333,
#    'e': 0.3333333333333333,
#    'a': 0.3333333333333333},
#   '%%%e': {'v': 0.07509881422924901,
#    'a': 0.07114624505928854,
#    'n': 0.17391304347826086,
#    'l': 0.06719367588932806,
#    'y': 0.007905138339920948,
#    'x': 0.28063241106719367,
#    'd': 0.04743083003952569,
#    'i': 0.007905138339920948,
#    's': 0.05138339920948617,
#    'c': 0.011857707509881422,
#    'f': 0.03557312252964427,
#    't': 0.023715415019762844,
#    'u': 0.007905138339920948,
#    'm': 0.07905138339920949,
#    'q': 0.019762845849802372,
#    'r': 0.015810276679841896,
#    '-': 0.003952569169960474,
#    'p': 0.007905138339920948,
#    'g': 0.011857707509881422},
#   '%%ev': {'e': 0.6842105263157895,
#    'i': 0.15789473684210525,
#    'o': 0.05263157894736842,
#    'a': 0.10526315789473684},
#   '%eve': {'n': 0.4166666666666667, 'r': 0.5833333333333334},
#   '%goo': {'d': 0.8, 'g': 0.2},
#   'wher': {'e': 1.0},
#   '%%af': {'t': 0.15384615384615385,
#    'r': 0.3076923076923077,
#    'f': 0.46153846153846156,
#    'g': 0.07692307692307693},
#   '%aft': {'e': 1.0},
#   'afte': {'r': 1.0},
#   '%wan': {'t': 1.0},
#   '%%%v': {'e': 0.1527777777777778,
#    'i': 0.4305555555555556,
#    'o': 0.19444444444444445,
#    'a': 0.19444444444444445,
#    's': 0.013888888888888888,
#    'u': 0.013888888888888888},
#   '%%ve': {'r': 0.36363636363636365,
#    'h': 0.18181818181818182,
#    't': 0.18181818181818182,
#    'g': 0.18181818181818182,
#    'n': 0.09090909090909091},
#   '%ver': {'y': 0.25, 's': 0.75},
#   '%%ye': {'a': 0.375, 's': 0.25, 't': 0.125, 'l': 0.125, 'p': 0.125},
#   '%yea': {'r': 0.6666666666666666, 'h': 0.3333333333333333},
#   'year': {'s': 1.0},
#   '%%ma': {'k': 0.04819277108433735,
#    'n': 0.1566265060240964,
#    'y': 0.03614457831325301,
#    'd': 0.024096385542168676,
#    't': 0.12048192771084337,
#    'j': 0.024096385542168676,
#    'r': 0.24096385542168675,
#    'i': 0.10843373493975904,
#    'l': 0.03614457831325301,
#    's': 0.060240963855421686,
#    'c': 0.03614457831325301,
#    'g': 0.03614457831325301,
#    'p': 0.024096385542168676,
#    'x': 0.024096385542168676,
#    'm': 0.012048192771084338,
#    "'": 0.012048192771084338},
#   '%mak': {'e': 0.75, 'i': 0.25},
#   '%mos': {'t': 0.6666666666666666, 'c': 0.3333333333333333},
#   '%%mu': {'c': 0.07142857142857142,
#    's': 0.5714285714285714,
#    'r': 0.21428571428571427,
#    'l': 0.07142857142857142,
#    't': 0.07142857142857142},
#   '%muc': {'h': 1.0},
#   '%%do': {'e': 0.03333333333333333,
#    'w': 0.06666666666666667,
#    'i': 0.03333333333333333,
#    'n': 0.13333333333333333,
#    'o': 0.06666666666666667,
#    'c': 0.23333333333333334,
#    'g': 0.06666666666666667,
#    'l': 0.06666666666666667,
#    'u': 0.13333333333333333,
#    'm': 0.1,
#    'z': 0.06666666666666667},
#   '%doe': {'s': 1.0},
#   '%tho': {'s': 0.125, 'u': 0.625, 'm': 0.25},
#   'thos': {'e': 1.0},
#   '%dow': {'n': 1.0},
#   '%sho': {'u': 0.13043478260869565,
#    'w': 0.2608695652173913,
#    'r': 0.13043478260869565,
#    't': 0.08695652173913043,
#    'o': 0.13043478260869565,
#    'p': 0.13043478260869565,
#    'e': 0.043478260869565216,
#    'c': 0.08695652173913043},
#   'shou': {'l': 1.0},
#   'houl': {'d': 1.0},
#   '%com': {'e': 0.05263157894736842,
#    'i': 0.03508771929824561,
#    'p': 0.45614035087719296,
#    'm': 0.3508771929824561,
#    'f': 0.03508771929824561,
#    'b': 0.07017543859649122},
#   '%man': {'y': 0.08333333333333333,
#    'a': 0.5,
#    'n': 0.08333333333333333,
#    'h': 0.08333333333333333,
#    'u': 0.25},
#   '%%re': {'a': 0.1111111111111111,
#    's': 0.16161616161616163,
#    'm': 0.0707070707070707,
#    'p': 0.13636363636363635,
#    'd': 0.025252525252525252,
#    'c': 0.10606060606060606,
#    'l': 0.09090909090909091,
#    't': 0.03535353535353535,
#    'v': 0.050505050505050504,
#    'q': 0.04040404040404041,
#    'g': 0.08080808080808081,
#    'f': 0.07575757575757576,
#    'n': 0.005050505050505051,
#    'j': 0.005050505050505051,
#    'w': 0.005050505050505051},
#   '%rea': {'l': 0.2727272727272727,
#    'd': 0.2727272727272727,
#    's': 0.13636363636363635,
#    'c': 0.22727272727272727,
#    'g': 0.045454545454545456,
#    'r': 0.045454545454545456},
#   'real': {'l': 0.2, 'i': 0.8},
#   'eall': {'y': 1.0},
#   '%%ta': {'k': 0.13793103448275862,
#    'l': 0.27586206896551724,
#    'b': 0.06896551724137931,
#    'x': 0.06896551724137931,
#    'r': 0.10344827586206896,
#    's': 0.10344827586206896,
#    'u': 0.034482758620689655,
#    'p': 0.06896551724137931,
#    'y': 0.034482758620689655,
#    'n': 0.034482758620689655,
#    'i': 0.034482758620689655,
#    'g': 0.034482758620689655},
#   '%tak': {'e': 0.75, 'i': 0.25},
#   '%thr': {'o': 0.46153846153846156, 'e': 0.5384615384615384},
#   'thro': {'u': 0.2857142857142857,
#    'w': 0.42857142857142855,
#    'o': 0.14285714285714285,
#    'a': 0.14285714285714285},
#   'hrou': {'g': 1.0},
#   'roug': {'h': 1.0},
#   '%say': {'s': 0.5, 'i': 0.5},
#   '%bef': {'o': 1.0},
#   'befo': {'r': 1.0},
#   'efor': {'e': 0.4, 'm': 0.6},
#   '%wor': {'k': 0.3157894736842105,
#    'l': 0.15789473684210525,
#    'd': 0.10526315789473684,
#    't': 0.10526315789473684,
#    's': 0.10526315789473684,
#    'r': 0.10526315789473684,
#    'e': 0.05263157894736842,
#    'n': 0.05263157894736842},
#   '%%st': {'i': 0.028037383177570093,
#    'a': 0.32710280373831774,
#    'u': 0.09345794392523364,
#    'o': 0.16822429906542055,
#    'r': 0.2616822429906542,
#    'e': 0.102803738317757,
#    'y': 0.018691588785046728},
#   '%sti': {'l': 0.3333333333333333,
#    'c': 0.3333333333333333,
#    'r': 0.3333333333333333},
#   'stil': {'l': 1.0},
#   '%%lo': {'o': 0.1111111111111111,
#    'n': 0.1111111111111111,
#    't': 0.044444444444444446,
#    'v': 0.1111111111111111,
#    's': 0.13333333333333333,
#    'c': 0.13333333333333333,
#    'w': 0.06666666666666667,
#    'r': 0.022222222222222223,
#    'u': 0.06666666666666667,
#    'a': 0.1111111111111111,
#    'g': 0.06666666666666667,
#    'b': 0.022222222222222223},
#   '%loo': {'k': 0.8, 's': 0.2},
#   'some': {'t': 0.2857142857142857,
#    'o': 0.14285714285714285,
#    'b': 0.14285714285714285,
#    'w': 0.2857142857142857,
#    'h': 0.14285714285714285},
#   'omet': {'h': 0.5, 'i': 0.5},
#   'meth': {'i': 0.3333333333333333, 'o': 0.6666666666666666},
#   'ethi': {'n': 0.3333333333333333, 'c': 0.6666666666666666},
#   '%%to': {'o': 0.11428571428571428,
#    'd': 0.05714285714285714,
#    'l': 0.02857142857142857,
#    'g': 0.02857142857142857,
#    'p': 0.08571428571428572,
#    'w': 0.14285714285714285,
#    'n': 0.14285714285714285,
#    't': 0.05714285714285714,
#    'm': 0.08571428571428572,
#    'u': 0.17142857142857143,
#    'b': 0.02857142857142857,
#    'y': 0.02857142857142857,
#    'i': 0.02857142857142857},
#   '%nee': {'d': 1.0},
#   '%%le': {'t': 0.11904761904761904,
#    'f': 0.023809523809523808,
#    's': 0.07142857142857142,
#    'a': 0.40476190476190477,
#    'v': 0.047619047619047616,
#    'd': 0.023809523809523808,
#    'g': 0.21428571428571427,
#    'e': 0.023809523809523808,
#    'n': 0.023809523809523808,
#    'w': 0.023809523809523808,
#    'm': 0.023809523809523808},
#   '%lit': {'t': 0.2, 'e': 0.8},
#   'litt': {'l': 1.0},
#   'ittl': {'e': 1.0},
#   '%bei': {'n': 1.0},
#   'bein': {'g': 1.0},
#   '%%of': {'f': 0.9333333333333333, 't': 0.06666666666666667},
#   '%%da': {'y': 0.06666666666666667,
#    't': 0.16666666666666666,
#    'v': 0.1,
#    'd': 0.06666666666666667,
#    'r': 0.1,
#    'u': 0.06666666666666667,
#    'i': 0.03333333333333333,
#    'm': 0.1,
#    'n': 0.23333333333333334,
#    'l': 0.03333333333333333,
#    'w': 0.03333333333333333},
#   '%nev': {'e': 1.0},
#   'neve': {'r': 1.0},
#   '%%la': {'s': 0.0425531914893617,
#    't': 0.1276595744680851,
#    'w': 0.14893617021276595,
#    'r': 0.10638297872340426,
#    'n': 0.1702127659574468,
#    'c': 0.02127659574468085,
#    'd': 0.0425531914893617,
#    'b': 0.0851063829787234,
#    'k': 0.02127659574468085,
#    'y': 0.0425531914893617,
#    'u': 0.1702127659574468,
#    'i': 0.02127659574468085},
#   '%las': {'t': 1.0},
#   '%lif': {'e': 0.6, 't': 0.4},
#   '%%su': {'c': 0.07575757575757576,
#    'r': 0.22727272727272727,
#    'p': 0.19696969696969696,
#    'm': 0.06060606060606061,
#    'b': 0.09090909090909091,
#    'n': 0.030303030303030304,
#    'd': 0.030303030303030304,
#    'g': 0.10606060606060606,
#    'i': 0.045454545454545456,
#    's': 0.06060606060606061,
#    'f': 0.06060606060606061,
#    'e': 0.015151515151515152},
#   '%suc': {'h': 0.2, 'c': 0.8},
#   'worl': {'d': 1.0},
#   '%mad': {'e': 1.0},
#   'whil': {'e': 1.0},
#   '%aro': {'u': 1.0},
#   'arou': {'n': 1.0},
#   'roun': {'d': 1.0},
#   'hing': {'s': 0.5, 't': 0.5},
#   '%%ow': {'n': 0.8571428571428571, 'e': 0.14285714285714285},
#   '%sam': {'e': 0.3333333333333333, 'p': 0.6666666666666666},
#   '%ano': {'t': 0.5, 'n': 0.5},
#   'anot': {'h': 1.0},
#   'noth': {'e': 0.5, 'i': 0.5},
#   '%lon': {'g': 0.6, 'd': 0.2, 'e': 0.2},
#   '%%bo': {'t': 0.10810810810810811,
#    'o': 0.13513513513513514,
#    'd': 0.05405405405405406,
#    'y': 0.08108108108108109,
#    'a': 0.08108108108108109,
#    'x': 0.05405405405405406,
#    'r': 0.10810810810810811,
#    'b': 0.05405405405405406,
#    'u': 0.08108108108108109,
#    'w': 0.05405405405405406,
#    's': 0.05405405405405406,
#    'n': 0.10810810810810811,
#    'm': 0.02702702702702703},
#   '%bot': {'h': 0.5, 't': 0.5},
#   '%%us': {'e': 0.6, 'i': 0.1, 'u': 0.2, 'a': 0.1},
#   '%sta': {'t': 0.2857142857142857,
#    'r': 0.22857142857142856,
#    'y': 0.08571428571428572,
#    'n': 0.17142857142857143,
#    'f': 0.02857142857142857,
#    'g': 0.05714285714285714,
#    'b': 0.05714285714285714,
#    'd': 0.02857142857142857,
#    'i': 0.02857142857142857,
#    'k': 0.02857142857142857},
#   'stat': {'e': 0.5454545454545454,
#    'u': 0.09090909090909091,
#    'i': 0.36363636363636365},
#   'thre': {'e': 0.14285714285714285,
#    'a': 0.7142857142857143,
#    'w': 0.14285714285714285},
#   '%bet': {'w': 0.5, 't': 0.5},
#   'betw': {'e': 1.0},
#   'etwe': {'e': 1.0},
#   'twee': {'n': 1.0},
#   'ever': {'y': 0.6, 'a': 0.1, 'e': 0.1, 't': 0.1, 's': 0.1},
#   '%%gr': {'e': 0.2222222222222222, 'o': 0.2777777777777778, 'a': 0.5},
#   '%gre': {'a': 0.5, 'e': 0.25, 'w': 0.125, 'g': 0.125},
#   'grea': {'t': 1.0},
#   '%hom': {'e': 1.0},
#   '%%ea': {'c': 0.05555555555555555,
#    'r': 0.4444444444444444,
#    's': 0.3333333333333333,
#    't': 0.1111111111111111,
#    'g': 0.05555555555555555},
#   '%eac': {'h': 1.0},
#   '%%ag': {'a': 0.11764705882352941,
#    'o': 0.058823529411764705,
#    'e': 0.4117647058823529,
#    'r': 0.29411764705882354,
#    'g': 0.058823529411764705,
#    'i': 0.058823529411764705},
#   '%aga': {'i': 1.0},
#   'agai': {'n': 1.0},
#   '%%te': {'l': 0.09803921568627451,
#    'a': 0.19607843137254902,
#    's': 0.09803921568627451,
#    'r': 0.17647058823529413,
#    'c': 0.13725490196078433,
#    'x': 0.058823529411764705,
#    'n': 0.09803921568627451,
#    'm': 0.0784313725490196,
#    'e': 0.0392156862745098,
#    'd': 0.0196078431372549},
#   '%tel': {'l': 0.6, 'e': 0.4},
#   '%hel': {'p': 0.5555555555555556,
#    'd': 0.1111111111111111,
#    'l': 0.2222222222222222,
#    'e': 0.1111111111111111},
#   '%%pr': {'e': 0.25196850393700787,
#    'o': 0.5196850393700787,
#    'i': 0.1732283464566929,
#    'a': 0.05511811023622047},
#   '%pre': {'s': 0.40625,
#    't': 0.0625,
#    'v': 0.125,
#    'p': 0.125,
#    'g': 0.0625,
#    'f': 0.09375,
#    'c': 0.0625,
#    'd': 0.0625},
#   'pres': {'i': 0.14814814814814814,
#    's': 0.37037037037037035,
#    'e': 0.48148148148148145},
#   'resi': {'d': 0.75, 's': 0.25},
#   'esid': {'e': 1.0},
#   'side': {'n': 0.42857142857142855,
#    'r': 0.35714285714285715,
#    's': 0.14285714285714285,
#    'b': 0.07142857142857142},
#   'iden': {'t': 0.8235294117647058, 'c': 0.17647058823529413},
#   '%%sc': {'h': 0.25,
#    'i': 0.17857142857142858,
#    'e': 0.10714285714285714,
#    'r': 0.14285714285714285,
#    'a': 0.14285714285714285,
#    'o': 0.17857142857142858},
#   '%sch': {'o': 0.5714285714285714, 'e': 0.42857142857142855},
#   'scho': {'o': 0.5, 'l': 0.5},
#   'choo': {'l': 0.5, 's': 0.5},
#   '%%mi': {'g': 0.023255813953488372,
#    'l': 0.16279069767441862,
#    'n': 0.27906976744186046,
#    'd': 0.046511627906976744,
#    'c': 0.09302325581395349,
#    's': 0.18604651162790697,
#    'k': 0.023255813953488372,
#    'x': 0.06976744186046512,
#    'r': 0.046511627906976744,
#    'a': 0.023255813953488372,
#    't': 0.046511627906976744},
#   '%mig': {'h': 1.0},
#   'migh': {'t': 1.0},
#   '%%me': {'a': 0.2727272727272727,
#    'n': 0.11363636363636363,
#    'm': 0.13636363636363635,
#    'd': 0.11363636363636363,
#    'e': 0.09090909090909091,
#    't': 0.09090909090909091,
#    's': 0.06818181818181818,
#    'x': 0.045454545454545456,
#    'r': 0.045454545454545456,
#    'c': 0.022727272727272728},
#   '%mea': {'n': 0.5,
#    's': 0.25,
#    't': 0.08333333333333333,
#    'l': 0.16666666666666666},
#   '%fin': {'d': 0.3076923076923077,
#    'a': 0.3076923076923077,
#    'e': 0.07692307692307693,
#    'i': 0.15384615384615385,
#    'g': 0.15384615384615385},
#   '%hou': {'s': 0.7142857142857143, 'r': 0.2857142857142857},
#   'hous': {'e': 0.42857142857142855,
#    'a': 0.2857142857142857,
#    't': 0.14285714285714285,
#    'i': 0.14285714285714285},
#   '%%pu': {'t': 0.125,
#    'b': 0.20833333333333334,
#    'l': 0.16666666666666666,
#    'r': 0.2916666666666667,
#    's': 0.125,
#    'n': 0.08333333333333333},
#   '%lov': {'e': 0.8, 'i': 0.2},
#   'bett': {'e': 1.0},
#   'ette': {'r': 1.0},
#   '%%si': {'n': 0.14893617021276595,
#    'd': 0.06382978723404255,
#    'x': 0.0425531914893617,
#    'm': 0.14893617021276595,
#    't': 0.14893617021276595,
#    'r': 0.02127659574468085,
#    'g': 0.2553191489361702,
#    'z': 0.02127659574468085,
#    's': 0.0425531914893617,
#    'c': 0.02127659574468085,
#    'l': 0.0851063829787234},
#   '%sin': {'c': 0.16666666666666666,
#    'g': 0.6666666666666666,
#    'k': 0.16666666666666666},
#   'sinc': {'e': 1.0},
#   '%alw': {'a': 1.0},
#   'alwa': {'y': 1.0},
#   'lway': {'s': 1.0},
#   '%nex': {'t': 1.0},
#   '%use': {'d': 0.2, 's': 0.2, 'r': 0.4, 'f': 0.2},
#   '%%aw': {'a': 0.75, 'e': 0.125, 'f': 0.125},
#   '%awa': {'y': 0.16666666666666666,
#    'r': 0.6666666666666666,
#    'k': 0.16666666666666666},
#   '%%pa': {'r': 0.323943661971831,
#    's': 0.11267605633802817,
#    'y': 0.07042253521126761,
#    'p': 0.028169014084507043,
#    'u': 0.028169014084507043,
#    't': 0.09859154929577464,
#    'g': 0.028169014084507043,
#    'i': 0.11267605633802817,
#    'n': 0.056338028169014086,
#    'c': 0.07042253521126761,
#    'l': 0.056338028169014086,
#    'k': 0.014084507042253521},
#   '%par': {'t': 0.6086956521739131,
#    'e': 0.08695652173913043,
#    'k': 0.17391304347826086,
#    'i': 0.043478260869565216,
#    'a': 0.043478260869565216,
#    'l': 0.043478260869565216},
#   '%%pl': {'a': 0.7666666666666667,
#    'e': 0.16666666666666666,
#    'u': 0.03333333333333333,
#    'o': 0.03333333333333333},
#   '%pla': {'c': 0.13043478260869565,
#    'y': 0.2608695652173913,
#    'n': 0.391304347826087,
#    's': 0.043478260869565216,
#    't': 0.13043478260869565,
#    'i': 0.043478260869565216},
#   'plac': {'e': 1.0},
#   '%%fe': {'w': 0.07142857142857142,
#    'e': 0.35714285714285715,
#    'l': 0.10714285714285714,
#    'd': 0.07142857142857142,
#    'a': 0.17857142857142858,
#    'm': 0.07142857142857142,
#    'b': 0.07142857142857142,
#    's': 0.03571428571428571,
#    'n': 0.03571428571428571},
#   'thou': {'g': 0.5714285714285714,
#    't': 0.14285714285714285,
#    's': 0.2857142857142857},
#   'houg': {'h': 1.0},
#   'ough': {'t': 0.7777777777777778,
#    'o': 0.1111111111111111,
#    'l': 0.1111111111111111},
#   '%%bi': {'g': 0.12,
#    't': 0.2,
#    'l': 0.2,
#    'r': 0.16,
#    'b': 0.04,
#    'k': 0.04,
#    'o': 0.08,
#    'n': 0.04,
#    's': 0.04,
#    'a': 0.04,
#    'd': 0.04},
#   'gain': {'s': 0.6666666666666666, 'e': 0.3333333333333333},
#   'ains': {'t': 1.0},
#   '%%gi': {'v': 0.36363636363636365,
#    'r': 0.2727272727272727,
#    'f': 0.18181818181818182,
#    'a': 0.18181818181818182},
#   '%giv': {'e': 0.75, 'i': 0.25},
#   '%doi': {'n': 1.0},
#   'doin': {'g': 1.0},
#   '%sur': {'e': 0.13333333333333333,
#    'f': 0.06666666666666667,
#    'p': 0.26666666666666666,
#    'v': 0.3333333333333333,
#    'g': 0.06666666666666667,
#    'r': 0.13333333333333333},
#   '%bes': {'t': 0.3333333333333333, 'i': 0.6666666666666666},
#   'with': {'o': 0.5, 'i': 0.5},
#   'itho': {'u': 1.0},
#   '%wom': {'e': 0.5, 'a': 0.5},
#   'wome': {'n': 1.0},
#   '%%ch': {'i': 0.14084507042253522,
#    'a': 0.4507042253521127,
#    'u': 0.056338028169014086,
#    'e': 0.1267605633802817,
#    'o': 0.11267605633802817,
#    'r': 0.11267605633802817},
#   '%chi': {'l': 0.3, 'n': 0.2, 'e': 0.1, 'c': 0.2, 'p': 0.2},
#   'chil': {'d': 1.0},
#   'hild': {'r': 0.5, 'h': 0.5},
#   'ildr': {'e': 1.0},
#   'ldre': {'n': 1.0},
#   '%fou': {'n': 0.5714285714285714,
#    'r': 0.2857142857142857,
#    'g': 0.14285714285714285},
#   'foun': {'d': 1.0},
#   '%%fa': {'m': 0.09803921568627451,
#    'c': 0.2549019607843137,
#    'r': 0.0784313725490196,
#    't': 0.0784313725490196,
#    'l': 0.0784313725490196,
#    's': 0.0784313725490196,
#    'i': 0.13725490196078433,
#    'v': 0.0392156862745098,
#    'n': 0.09803921568627451,
#    'u': 0.0196078431372549,
#    'k': 0.0196078431372549,
#    'b': 0.0196078431372549},
#   '%fam': {'i': 0.6, 'o': 0.2, 'e': 0.2},
#   'fami': {'l': 1.0},
#   'amil': {'y': 0.3333333333333333, 'i': 0.6666666666666666},
#   '%mon': {'e': 0.125, 't': 0.375, 'd': 0.125, 'i': 0.25, 's': 0.125},
#   'mone': {'y': 1.0},
#   '%tod': {'a': 0.5, 'd': 0.5},
#   'toda': {'y': 1.0},
#   '%mus': {'t': 0.125, 'i': 0.25, 'e': 0.125, 'l': 0.25, 'c': 0.25},
#   '%tol': {'d': 1.0},
#   '%%ok': {'a': 0.5, 'l': 0.5},
#   '%oka': {'y': 1.0},
#   '%%ol': {'d': 0.5, 'y': 0.3333333333333333, 'i': 0.16666666666666666},
#   '%%am': {'e': 0.3333333333333333,
#    'o': 0.25,
#    'a': 0.16666666666666666,
#    'y': 0.08333333333333333,
#    'b': 0.16666666666666666},
#   '%ame': {'r': 0.75, 'n': 0.25},
#   'amer': {'i': 0.6666666666666666, 'a': 0.3333333333333333},
#   'meri': {'c': 1.0},
#   'eric': {'a': 1.0},
#   'rica': {'n': 0.75, 'l': 0.25},
#   '%%du': {'r': 0.125,
#    'e': 0.125,
#    't': 0.25,
#    'd': 0.125,
#    's': 0.125,
#    'k': 0.125,
#    'm': 0.125},
#   '%dur': {'i': 1.0},
#   'duri': {'n': 1.0},
#   'urin': {'g': 1.0},
#   '%%ni': {'g': 0.3333333333333333,
#    'c': 0.3333333333333333,
#    'n': 0.16666666666666666,
#    'x': 0.16666666666666666},
#   '%nig': {'h': 1.0},
#   'nigh': {'t': 1.0},
#   '%%un': {'d': 0.2,
#    't': 0.03333333333333333,
#    'i': 0.4,
#    'l': 0.1,
#    'f': 0.03333333333333333,
#    'c': 0.06666666666666667,
#    'a': 0.03333333333333333,
#    'u': 0.03333333333333333,
#    'k': 0.03333333333333333,
#    'e': 0.06666666666666667},
#   '%und': {'e': 1.0},
#   'unde': {'r': 0.6363636363636364, 'd': 0.36363636363636365},
#   '%lef': {'t': 1.0},
#   '%%po': {'i': 0.0784313725490196,
#    'w': 0.09803921568627451,
#    'l': 0.19607843137254902,
#    's': 0.23529411764705882,
#    'o': 0.0392156862745098,
#    't': 0.0784313725490196,
#    'p': 0.09803921568627451,
#    'u': 0.0392156862745098,
#    'v': 0.0196078431372549,
#    'c': 0.0196078431372549,
#    'r': 0.058823529411764705,
#    'e': 0.0392156862745098},
#   '%poi': {'n': 1.0},
#   'poin': {'t': 1.0},
#   '%%ki': {'n': 0.25,
#    'd': 0.1875,
#    'l': 0.25,
#    't': 0.0625,
#    's': 0.0625,
#    'c': 0.125,
#    'm': 0.0625},
#   '%kin': {'d': 0.5, 'g': 0.5},
#   '%dif': {'f': 1.0},
#   'diff': {'e': 0.5714285714285714, 'i': 0.42857142857142855},
#   'iffe': {'r': 1.0},
#   'ffer': {'e': 0.6, 's': 0.2, 'i': 0.2},
#   'fere': {'n': 0.7777777777777778, 'd': 0.2222222222222222},
#   'eren': {'t': 0.2857142857142857, 'c': 0.7142857142857143},
#   '%%en': {'d': 0.11627906976744186,
#    'o': 0.046511627906976744,
#    'e': 0.06976744186046512,
#    't': 0.23255813953488372,
#    'g': 0.23255813953488372,
#    'v': 0.046511627906976744,
#    'j': 0.06976744186046512,
#    's': 0.023255813953488372,
#    'f': 0.023255813953488372,
#    'c': 0.09302325581395349,
#    'h': 0.023255813953488372,
#    'a': 0.023255813953488372},
#   '%cam': {'e': 0.375, 'p': 0.625},
#   '%fee': {'l': 0.4444444444444444,
#    't': 0.1111111111111111,
#    'd': 0.3333333333333333,
#    's': 0.1111111111111111},
#   '%%ke': {'e': 0.25,
#    'y': 0.16666666666666666,
#    'p': 0.08333333333333333,
#    'v': 0.08333333333333333,
#    'n': 0.25,
#    'l': 0.08333333333333333,
#    'r': 0.08333333333333333},
#   '%kee': {'p': 1.0},
#   '%hig': {'h': 1.0},
#   'tate': {'s': 0.25, 'm': 0.5, 'd': 0.25},
#   '%eno': {'u': 0.5, 'r': 0.5},
#   'enou': {'g': 1.0},
#   'noug': {'h': 1.0},
#   '%gov': {'e': 1.0},
#   'gove': {'r': 1.0},
#   'over': {'n': 0.2222222222222222,
#    'a': 0.1111111111111111,
#    'e': 0.1111111111111111,
#    't': 0.05555555555555555,
#    'y': 0.1111111111111111,
#    'i': 0.05555555555555555,
#    's': 0.2222222222222222,
#    'c': 0.05555555555555555,
#    'w': 0.05555555555555555},
#   'vern': {'m': 0.5, 'o': 0.25, 'i': 0.25},
#   'ernm': {'e': 1.0},
#   'rnme': {'n': 1.0},
#   'nmen': {'t': 1.0},
#   '%any': {'t': 0.16666666666666666,
#    'o': 0.16666666666666666,
#    'w': 0.3333333333333333,
#    'b': 0.16666666666666666,
#    'm': 0.16666666666666666},
#   'anyt': {'h': 1.0},
#   'nyth': {'i': 1.0},
#   'ythi': {'n': 1.0},
#   '%not': {'h': 0.14285714285714285,
#    'e': 0.42857142857142855,
#    'i': 0.42857142857142855},
#   'othi': {'n': 1.0},
#   '%stu': {'d': 0.7, 'f': 0.1, 'p': 0.1, 'c': 0.1},
#   'stud': {'e': 0.2857142857142857,
#    'y': 0.2857142857142857,
#    'i': 0.42857142857142855},
#   'tude': {'n': 0.6666666666666666, 's': 0.3333333333333333},
#   'uden': {'t': 1.0},
#   'dent': {'s': 0.4, 'i': 0.6},
#   '%unt': {'i': 1.0},
#   'unti': {'l': 0.2, 'n': 0.6, 'e': 0.2},
#   'coun': {'t': 0.8, 'c': 0.06666666666666667, 's': 0.13333333333333333},
#   'ount': {'r': 0.15384615384615385,
#    'y': 0.07692307692307693,
#    'a': 0.15384615384615385,
#    's': 0.23076923076923078,
#    'e': 0.15384615384615385,
#    'i': 0.23076923076923078},
#   'untr': {'y': 0.5, 'i': 0.5},
#   '%wen': {'t': 1.0},
#   '%%ci': {'t': 0.35714285714285715,
#    'v': 0.21428571428571427,
#    'r': 0.2857142857142857,
#    'a': 0.07142857142857142,
#    'g': 0.07142857142857142},
#   '%cit': {'y': 0.2, 'i': 0.6, 'e': 0.2},
#   '%bel': {'i': 0.5555555555555556,
#    'o': 0.2222222222222222,
#    'l': 0.1111111111111111,
#    't': 0.1111111111111111},
#   'beli': {'e': 1.0},
#   'elie': {'v': 0.5, 'f': 0.5},
#   'liev': {'e': 1.0},
#   '%onc': {'e': 1.0},
#   '%may': {'b': 0.5, 'o': 0.5},
#   'mayb': {'e': 1.0},
#   '%pub': {'l': 1.0},
#   'publ': {'i': 1.0},
#   'ubli': {'c': 0.75, 's': 0.25},
#   '%cal': {'l': 0.4444444444444444,
#    'i': 0.2222222222222222,
#    'm': 0.1111111111111111,
#    'o': 0.1111111111111111,
#    'c': 0.1111111111111111},
#   'call': {'e': 0.2,
#    's': 0.13333333333333333,
#    'i': 0.06666666666666667,
#    'y': 0.6},
#   'alle': {'d': 0.25,
#    'n': 0.375,
#    'r': 0.125,
#    'y': 0.0625,
#    'g': 0.125,
#    'l': 0.0625},
#   'whit': {'e': 1.0},
#   '%cas': {'e': 0.5, 'h': 0.25, 't': 0.25},
#   '%tal': {'k': 0.5, 'l': 0.125, 'e': 0.375},
#   'cour': {'s': 0.3333333333333333,
#    't': 0.2222222222222222,
#    'a': 0.4444444444444444},
#   'ours': {'e': 1.0},
#   '%per': {'c': 0.19230769230769232,
#    's': 0.2692307692307692,
#    'h': 0.038461538461538464,
#    'i': 0.07692307692307693,
#    'f': 0.2692307692307692,
#    'm': 0.11538461538461539,
#    'r': 0.038461538461538464},
#   'perc': {'e': 1.0},
#   'erce': {'n': 0.4, 'i': 0.2, 'p': 0.4},
#   'rcen': {'t': 1.0},
#   '%don': {'e': 0.3333333333333333, 'a': 0.6666666666666666},
#   'time': {'s': 1.0},
#   '%%ac': {'t': 0.36585365853658536,
#    'r': 0.04878048780487805,
#    'c': 0.36585365853658536,
#    'a': 0.04878048780487805,
#    'h': 0.07317073170731707,
#    'k': 0.04878048780487805,
#    'q': 0.024390243902439025,
#    'i': 0.024390243902439025},
#   '%act': {'u': 0.14285714285714285,
#    'i': 0.5714285714285714,
#    's': 0.07142857142857142,
#    'o': 0.14285714285714285,
#    'r': 0.07142857142857142},
#   'actu': {'a': 0.5, 'r': 0.5},
#   'ctua': {'l': 1.0},
#   'tual': {'l': 1.0},
#   'uall': {'y': 1.0},
#   '%day': {'s': 1.0},
#   '%fac': {'t': 0.38461538461538464,
#    'e': 0.3076923076923077,
#    'i': 0.23076923076923078,
#    'u': 0.07692307692307693},
#   '%too': {'k': 0.3333333333333333, 'l': 0.6666666666666666},
#   '%car': {'e': 0.2631578947368421,
#    'd': 0.10526315789473684,
#    's': 0.05263157894736842,
#    'r': 0.21052631578947367,
#    'o': 0.10526315789473684,
#    't': 0.05263157894736842,
#    'b': 0.05263157894736842,
#    'l': 0.10526315789473684,
#    'i': 0.05263157894736842},
#   '%%nu': {'m': 0.375, 'c': 0.125, 'r': 0.375, 't': 0.125},
#   '%num': {'b': 0.6666666666666666, 'e': 0.3333333333333333},
#   'numb': {'e': 1.0},
#   'umbe': {'r': 1.0},
#   '%hea': {'d': 0.2777777777777778,
#    'l': 0.2222222222222222,
#    'r': 0.2777777777777778,
#    't': 0.05555555555555555,
#    'v': 0.16666666666666666},
#   '%les': {'s': 1.0},
#   '%sec': {'o': 0.2727272727272727,
#    'u': 0.18181818181818182,
#    't': 0.2727272727272727,
#    'r': 0.2727272727272727},
#   'seco': {'n': 1.0},
#   'econ': {'d': 0.5, 'o': 0.5},
#   '%%sy': {'s': 0.4, 'm': 0.4, 'r': 0.2},
#   '%sys': {'t': 1.0},
#   'syst': {'e': 1.0},
#   'yste': {'m': 0.6666666666666666, 'r': 0.3333333333333333},
#   '%%im': {'p': 0.6538461538461539,
#    'a': 0.19230769230769232,
#    'm': 0.15384615384615385},
#   '%imp': {'o': 0.23529411764705882,
#    'a': 0.058823529411764705,
#    'r': 0.47058823529411764,
#    'l': 0.23529411764705882},
#   'impo': {'r': 0.75, 's': 0.25},
#   'mpor': {'t': 0.6, 'a': 0.4},
#   'port': {'a': 0.2222222222222222,
#    'e': 0.2777777777777778,
#    'u': 0.1111111111111111,
#    's': 0.16666666666666666,
#    'i': 0.2222222222222222},
#   'orta': {'n': 0.5, 'b': 0.3333333333333333, 't': 0.16666666666666666},
#   'rtan': {'t': 0.6666666666666666, 'c': 0.3333333333333333},
#   'omeo': {'n': 1.0},
#   'meon': {'e': 1.0},
#   '%%tr': {'y': 0.03571428571428571,
#    'i': 0.16071428571428573,
#    'u': 0.10714285714285714,
#    'a': 0.48214285714285715,
#    'e': 0.17857142857142858,
#    'o': 0.03571428571428571},
#   '%try': {'i': 1.0},
#   'tryi': {'n': 1.0},
#   'ryin': {'g': 1.0},
#   '%get': {'t': 0.5, 's': 0.5},
#   'gett': {'i': 1.0},
#   'etti': {'n': 1.0},
#   'ttin': {'g': 1.0},
#   '%cha': {'n': 0.21875,
#    'r': 0.34375,
#    'l': 0.125,
#    'i': 0.125,
#    'p': 0.03125,
#    'm': 0.09375,
#    's': 0.03125,
#    'o': 0.03125},
#   'chan': {'g': 0.5555555555555556,
#    'c': 0.2222222222222222,
#    'n': 0.1111111111111111,
#    'i': 0.1111111111111111},
#   'hang': {'e': 0.6666666666666666, 'i': 0.3333333333333333},
#   '%wee': {'k': 1.0},
#   '%how': {'e': 0.5, 'a': 0.5},
#   'howe': {'v': 0.3333333333333333,
#    'd': 0.3333333333333333,
#    'r': 0.3333333333333333},
#   'owev': {'e': 1.0},
#   'weve': {'r': 1.0},
#   '%wat': {'e': 0.4, 'c': 0.6},
#   'wate': {'r': 1.0},
#   '%bus': {'i': 0.5, 'h': 0.25, 'y': 0.25},
#   'busi': {'n': 1.0},
#   'usin': {'e': 0.3333333333333333, 'g': 0.6666666666666666},
#   'sine': {'s': 1.0},
#   'ines': {'s': 0.75, 'e': 0.25},
#   'very': {'t': 0.2, 'o': 0.2, 'b': 0.2, 'w': 0.2, 'd': 0.2},
#   'eryt': {'h': 1.0},
#   'ryth': {'i': 1.0},
#   '%%sm': {'a': 0.25,
#    'i': 0.4166666666666667,
#    'o': 0.25,
#    'e': 0.08333333333333333},
#   '%sma': {'l': 0.6666666666666666, 'r': 0.3333333333333333},
#   'smal': {'l': 1.0},
#   '%%ro': {'o': 0.13513513513513514,
#    'l': 0.13513513513513514,
#    'a': 0.05405405405405406,
#    'm': 0.10810810810810811,
#    'b': 0.13513513513513514,
#    'c': 0.05405405405405406,
#    's': 0.05405405405405406,
#    'u': 0.13513513513513514,
#    'w': 0.02702702702702703,
#    'g': 0.02702702702702703,
#    'n': 0.05405405405405406,
#    'y': 0.05405405405405406,
#    'k': 0.02702702702702703},
#   '%roo': {'m': 0.4, 'f': 0.2, 't': 0.4},
#   'want': {'e': 0.3333333333333333,
#    's': 0.3333333333333333,
#    'i': 0.3333333333333333},
#   'ante': {'d': 0.6666666666666666, 'e': 0.3333333333333333},
#   '%lea': {'s': 0.058823529411764705,
#    'v': 0.17647058823529413,
#    'd': 0.35294117647058826,
#    'r': 0.17647058823529413,
#    'g': 0.058823529411764705,
#    't': 0.058823529411764705,
#    'n': 0.11764705882352941},
#   'leas': {'t': 0.14285714285714285,
#    'e': 0.5714285714285714,
#    'u': 0.14285714285714285,
#    'a': 0.14285714285714285},
#   '%%na': {'t': 0.47368421052631576,
#    'm': 0.15789473684210525,
#    'r': 0.15789473684210525,
#    'v': 0.05263157894736842,
#    'n': 0.05263157894736842,
#    'k': 0.05263157894736842,
#    's': 0.05263157894736842},
#   '%nat': {'i': 0.5555555555555556,
#    'u': 0.3333333333333333,
#    'o': 0.1111111111111111},
#   'nati': {'o': 0.7857142857142857,
#    'v': 0.14285714285714285,
#    'n': 0.07142857142857142},
#   'atio': {'n': 1.0},
#   'tion': {'a': 0.1896551724137931,
#    's': 0.7758620689655172,
#    'e': 0.017241379310344827,
#    'w': 0.017241379310344827},
#   'iona': {'l': 1.0},
#   'than': {'k': 1.0},
#   '%sto': {'r': 0.3333333333333333,
#    'p': 0.2222222222222222,
#    'o': 0.05555555555555555,
#    'c': 0.1111111111111111,
#    'n': 0.1111111111111111,
#    'm': 0.05555555555555555,
#    'l': 0.1111111111111111},
#   'stor': {'y': 0.18181818181818182,
#    'i': 0.36363636363636365,
#    'e': 0.18181818181818182,
#    'm': 0.09090909090909091,
#    's': 0.09090909090909091,
#    'a': 0.09090909090909091},
#   '%pow': {'e': 0.8, 'd': 0.2},
#   'powe': {'r': 0.75, 'l': 0.25},
# ...
#    'i': 0.38461538461538464},
#   'lita': {'r': 1.0},
#   'itar': {'y': 1.0},
#   '%rep': {'o': 0.23076923076923078,
#    'u': 0.15384615384615385,
#    'r': 0.2692307692307692,
#    'l': 0.19230769230769232,
#    'e': 0.11538461538461539,
#    'a': 0.038461538461538464},
#   'repo': {'r': 1.0},
#   'epor': {'t': 1.0},
#   '%hol': {'d': 0.375, 'e': 0.25, 'y': 0.125, 'l': 0.125, 'i': 0.125},
#   '%%sp': {'e': 0.4411764705882353,
#    'a': 0.14705882352941177,
#    'o': 0.20588235294117646,
#    'r': 0.08823529411764706,
#    'i': 0.08823529411764706,
#    'l': 0.029411764705882353},
#   '%spe': {'c': 0.3333333333333333,
#    'n': 0.2,
#    'a': 0.26666666666666666,
#    'e': 0.13333333333333333,
#    'l': 0.06666666666666667},
#   '%bab': {'y': 0.5, 'i': 0.5},
#   '%cau': {'s': 0.8, 'g': 0.2},
#   '%sou': {'t': 0.2, 'n': 0.3, 'r': 0.2, 'l': 0.1, 'g': 0.1, 'p': 0.1},
#   'sout': {'h': 1.0},
#   'ssue': {'s': 0.5, 'd': 0.5},
#   '%%ph': {'o': 0.42105263157894735,
#    'y': 0.2631578947368421,
#    'i': 0.15789473684210525,
#    'a': 0.05263157894736842,
#    'r': 0.05263157894736842,
#    'e': 0.05263157894736842},
#   '%pho': {'n': 0.25, 't': 0.75},
#   'phon': {'e': 1.0},
#   '%soo': {'n': 1.0},
#   '%nor': {'t': 0.5, 'm': 0.5},
#   'nort': {'h': 1.0},
#   '%%ec': {'o': 1.0},
#   '%eco': {'n': 1.0},
#   'cono': {'m': 1.0},
#   'onom': {'i': 0.6666666666666666, 'y': 0.3333333333333333},
#   'nomi': {'c': 0.6666666666666666, 'n': 0.3333333333333333},
#   'live': {'s': 0.2, 'd': 0.2, 'r': 0.6},
#   'coup': {'l': 1.0},
#   'oupl': {'e': 1.0},
#   '%chu': {'r': 0.5, 'c': 0.5},
#   'chur': {'c': 1.0},
#   'hurc': {'h': 1.0},
#   '%goe': {'s': 1.0},
#   '%cla': {'s': 0.45454545454545453,
#    'i': 0.36363636363636365,
#    'r': 0.09090909090909091,
#    'y': 0.09090909090909091},
#   'clas': {'s': 1.0},
#   '%dev': {'e': 0.6, 'i': 0.3, 'o': 0.1},
#   'deve': {'l': 1.0},
#   'evel': {'o': 0.75, 's': 0.125, 'a': 0.125},
#   'velo': {'p': 1.0},
#   'elop': {'m': 0.4, 'e': 0.4, 'i': 0.2},
#   'lopm': {'e': 1.0},
#   'opme': {'n': 1.0},
#   'pmen': {'t': 1.0},
#   'abov': {'e': 1.0},
#   '%fig': {'u': 0.6, 'h': 0.4},
#   'figu': {'r': 1.0},
#   'igur': {'e': 1.0},
#   'watc': {'h': 1.0},
#   '%mid': {'d': 0.5, 'n': 0.5},
#   'midd': {'l': 1.0},
#   'iddl': {'e': 1.0},
#   '%sim': {'p': 0.42857142857142855,
#    'i': 0.2857142857142857,
#    'o': 0.14285714285714285,
#    'u': 0.14285714285714285},
#   'simp': {'l': 0.6666666666666666, 's': 0.3333333333333333},
#   'impl': {'y': 0.16666666666666666,
#    'e': 0.6666666666666666,
#    'i': 0.16666666666666666},
#   'rson': {'a': 0.6, 's': 0.2, 'n': 0.2},
#   'sona': {'l': 0.75, 'b': 0.25},
#   '%run': {'n': 0.5, 's': 0.5},
#   'runn': {'i': 1.0},
#   'unni': {'n': 1.0},
#   'nnin': {'g': 1.0},
#   'eede': {'d': 1.0},
#   '%spa': {'c': 0.4, 'n': 0.2, 'i': 0.2, 'r': 0.2},
#   'spac': {'e': 1.0},
#   ...},
#  {'%%%t': 267,
#   '%%th': 56,
#   '%%%a': 359,
#   '%%an': 42,
#   '%%%o': 127,
#   '%%%i': 190,
#   '%tha': 6,
#   '%%%y': 21,
#   '%%yo': 8,
#   '%%%f': 240,
#   '%%fo': 48,
#   '%%%w': 174,
#   '%%wa': 42,
#   '%%%h': 168,
#   '%%wi': 35,
#   '%wit': 5,
#   '%thi': 10,
#   '%%%n': 96,
#   "%%n'": 1,
#   '%%%b': 247,
#   '%%ha': 38,
#   '%hav': 2,
#   '%%ar': 32,
#   '%%no': 26,
#   '%%bu': 31,
#   '%the': 16,
#   '%%%d': 283,
#   '%%wh': 22,
#   '%wha': 2,
#   '%%hi': 27,
#   '%%fr': 28,
#   '%fro': 3,
#   '%%%s': 541,
#   '%%sh': 48,
#   '%%%m': 247,
#   '%%al': 32,
#   'ther': 13,
#   '%%he': 38,
#   '%%ab': 14,
#   '%abo': 3,
#   'abou': 1,
#   '%%on': 7,
#   '%you': 6,
#   '%%%c': 506,
#   '%%ca': 72,
#   '%%ou': 9,
#   'thei': 1,
#   '%%we': 27,
#   '%wer': 1,
#   '%%%l': 194,
#   '%%li': 50,
#   '%lik': 4,
#   '%%%j': 75,
#   '%%ju': 17,
#   '%jus': 4,
#   '%%wo': 35,
#   '%wou': 3,
#   'woul': 1,
#   '%%%u': 59,
#   '%whe': 8,
#   '%%mo': 50,
#   '%mor': 7,
#   '%wil': 7,
#   '%%%k': 45,
#   '%%kn': 11,
#   '%kno': 7,
#   '%%sa': 39,
#   '%sai': 2,
#   '%%di': 70,
#   '%%be': 54,
#   '%bee': 3,
#   '%%%p': 387,
#   '%%pe': 42,
#   '%peo': 2,
#   'peop': 2,
#   'eopl': 2,
#   '%%%g': 150,
#   '%%ge': 24,
#   '%%ti': 18,
#   '%tim': 3,
#   '%%so': 46,
#   '%som': 8,
#   '%%ho': 42,
#   '%whi': 5,
#   'whic': 1,
#   '%%co': 230,
#   '%cou': 21,
#   'coul': 1,
#   'thin': 11,
#   '%%in': 117,
#   '%int': 30,
#   '%%ot': 3,
#   '%oth': 3,
#   'othe': 11,
#   '%%%r': 305,
#   '%%ri': 18,
#   '%rig': 2,
#   'righ': 6,
#   '%her': 6,
#   '%wel': 4,
#   '%%ne': 29,
#   '%bec': 5,
#   'beca': 2,
#   'ecau': 1,
#   'caus': 5,
#   '%%se': 81,
#   '%%ba': 45,
#   '%bac': 5,
#   '%onl': 2,
#   'thes': 1,
#   '%%ov': 7,
#   '%ove': 7,
#   '%%go': 27,
#   '%goi': 1,
#   'goin': 2,
#   '%als': 1,
#   '%%tw': 6,
#   '%%fi': 49,
#   '%fir': 7,
#   'firs': 1,
#   '%%it': 6,
#   '%%%e': 253,
#   '%%ev': 19,
#   '%eve': 12,
#   '%goo': 5,
#   'wher': 8,
#   '%%af': 13,
#   '%aft': 2,
#   'afte': 2,
#   '%wan': 4,
#   '%%%v': 72,
#   '%%ve': 11,
#   '%ver': 4,
#   '%%ye': 8,
#   '%yea': 3,
#   'year': 1,
#   '%%ma': 83,
#   '%mak': 4,
#   '%mos': 3,
#   '%%mu': 14,
#   '%muc': 1,
#   '%%do': 30,
#   '%doe': 1,
#   '%tho': 8,
#   'thos': 1,
#   '%dow': 2,
#   '%sho': 23,
#   'shou': 3,
#   'houl': 3,
#   '%com': 57,
#   '%man': 12,
#   '%%re': 198,
#   '%rea': 22,
#   'real': 5,
#   'eall': 1,
#   '%%ta': 29,
#   '%tak': 4,
#   '%thr': 13,
#   'thro': 7,
#   'hrou': 2,
#   'roug': 5,
#   '%say': 2,
#   '%bef': 1,
#   'befo': 1,
#   'efor': 5,
#   '%wor': 19,
#   '%%st': 107,
#   '%sti': 3,
#   'stil': 1,
#   '%%lo': 45,
#   '%loo': 5,
#   'some': 7,
#   'omet': 2,
#   'meth': 3,
#   'ethi': 3,
#   '%%to': 35,
#   '%nee': 3,
#   '%%le': 42,
#   '%lit': 5,
#   'litt': 1,
#   'ittl': 1,
#   '%bei': 2,
#   'bein': 2,
#   '%%of': 15,
#   '%%da': 30,
#   '%nev': 2,
#   'neve': 3,
#   '%%la': 47,
#   '%las': 1,
#   '%lif': 5,
#   '%%su': 66,
#   '%suc': 5,
#   'worl': 3,
#   '%mad': 1,
#   'whil': 2,
#   '%aro': 1,
#   'arou': 1,
#   'roun': 8,
#   'hing': 2,
#   '%%ow': 7,
#   '%sam': 3,
#   '%ano': 2,
#   'anot': 1,
#   'noth': 2,
#   '%lon': 5,
#   '%%bo': 37,
#   '%bot': 4,
#   '%%us': 10,
#   '%sta': 35,
#   'stat': 11,
#   'thre': 7,
#   '%bet': 2,
#   'betw': 1,
#   'etwe': 1,
#   'twee': 1,
#   'ever': 10,
#   '%%gr': 36,
#   '%gre': 8,
#   'grea': 4,
#   '%hom': 3,
#   '%%ea': 18,
#   '%eac': 1,
#   '%%ag': 17,
#   '%aga': 2,
#   'agai': 2,
#   '%%te': 51,
#   '%tel': 5,
#   '%hel': 9,
#   '%%pr': 127,
#   '%pre': 32,
#   'pres': 27,
#   'resi': 8,
#   'esid': 8,
#   'side': 14,
#   'iden': 17,
#   '%%sc': 28,
#   '%sch': 7,
#   'scho': 4,
#   'choo': 4,
#   '%%mi': 43,
#   '%mig': 1,
#   'migh': 1,
#   '%%me': 44,
#   '%mea': 12,
#   '%fin': 13,
#   '%hou': 7,
#   'hous': 7,
#   '%%pu': 24,
#   '%lov': 5,
#   'bett': 1,
#   'ette': 3,
#   '%%si': 47,
#   '%sin': 6,
#   'sinc': 1,
#   '%alw': 1,
#   'alwa': 1,
#   'lway': 1,
#   '%nex': 1,
#   '%use': 5,
#   '%%aw': 8,
#   '%awa': 6,
#   '%%pa': 71,
#   '%par': 23,
#   '%%pl': 30,
#   '%pla': 23,
#   'plac': 6,
#   '%%fe': 28,
#   'thou': 7,
#   'houg': 4,
#   'ough': 9,
#   '%%bi': 25,
#   'gain': 3,
#   'ains': 2,
#   '%%gi': 11,
#   '%giv': 4,
#   '%doi': 1,
#   'doin': 1,
#   '%sur': 15,
#   '%bes': 3,
#   'with': 2,
#   'itho': 1,
#   '%wom': 2,
#   'wome': 1,
#   '%%ch': 71,
#   '%chi': 10,
#   'chil': 3,
#   'hild': 2,
#   'ildr': 1,
#   'ldre': 1,
#   '%fou': 7,
#   'foun': 4,
#   '%%fa': 51,
#   '%fam': 5,
#   'fami': 3,
#   'amil': 3,
#   '%mon': 8,
#   'mone': 1,
#   '%tod': 2,
#   'toda': 1,
#   '%mus': 8,
#   '%tol': 1,
#   '%%ok': 2,
#   '%oka': 1,
#   '%%ol': 6,
#   '%%am': 12,
#   '%ame': 4,
#   'amer': 6,
#   'meri': 4,
#   'eric': 4,
#   'rica': 8,
#   '%%du': 8,
#   '%dur': 1,
#   'duri': 1,
#   'urin': 2,
#   '%%ni': 6,
#   '%nig': 2,
#   'nigh': 5,
#   '%%un': 30,
#   '%und': 6,
#   'unde': 11,
#   '%lef': 1,
#   '%%po': 51,
#   '%poi': 4,
#   'poin': 7,
#   '%%ki': 16,
#   '%kin': 4,
#   '%dif': 7,
#   'diff': 7,
#   'iffe': 4,
#   'ffer': 10,
#   'fere': 9,
#   'eren': 7,
#   '%%en': 43,
#   '%cam': 8,
#   '%fee': 9,
#   '%%ke': 12,
#   '%kee': 3,
#   '%hig': 5,
#   'tate': 4,
#   '%eno': 2,
#   'enou': 1,
#   'noug': 1,
#   '%gov': 3,
#   'gove': 3,
#   'over': 18,
#   'vern': 4,
#   'ernm': 2,
#   'rnme': 2,
#   'nmen': 5,
#   '%any': 6,
#   'anyt': 1,
#   'nyth': 1,
#   'ythi': 2,
#   '%not': 7,
#   'othi': 2,
#   '%stu': 10,
#   'stud': 7,
#   'tude': 3,
#   'uden': 2,
#   'dent': 10,
#   '%unt': 1,
#   'unti': 5,
#   'coun': 15,
#   'ount': 13,
#   'untr': 2,
#   '%wen': 1,
#   '%%ci': 14,
#   '%cit': 5,
#   '%bel': 9,
#   'beli': 5,
#   'elie': 6,
#   'liev': 3,
#   '%onc': 1,
#   '%may': 2,
#   'mayb': 1,
#   '%pub': 5,
#   'publ': 8,
#   'ubli': 8,
#   '%cal': 9,
#   'call': 15,
#   'alle': 16,
#   'whit': 2,
#   '%cas': 4,
#   '%tal': 8,
#   'cour': 9,
#   'ours': 5,
#   '%per': 26,
#   'perc': 5,
#   'erce': 5,
#   'rcen': 2,
#   '%don': 3,
#   'time': 2,
#   '%%ac': 41,
#   '%act': 14,
#   'actu': 4,
#   'ctua': 3,
#   'tual': 3,
#   'uall': 6,
#   '%day': 1,
#   '%fac': 13,
#   '%too': 3,
#   '%car': 19,
#   '%%nu': 8,
#   '%num': 3,
#   'numb': 2,
#   'umbe': 2,
#   '%hea': 18,
#   '%les': 3,
#   '%sec': 11,
#   'seco': 3,
#   'econ': 6,
#   '%%sy': 5,
#   '%sys': 2,
#   'syst': 2,
#   'yste': 3,
#   '%%im': 26,
#   '%imp': 17,
#   'impo': 4,
#   'mpor': 5,
#   'port': 18,
#   'orta': 6,
#   'rtan': 3,
#   'omeo': 1,
#   'meon': 1,
#   '%%tr': 56,
#   '%try': 1,
#   'tryi': 1,
#   'ryin': 3,
#   '%get': 2,
#   'gett': 1,
#   'etti': 4,
#   'ttin': 8,
#   '%cha': 32,
#   'chan': 9,
#   'hang': 6,
#   '%wee': 4,
#   '%how': 2,
#   'howe': 3,
#   'owev': 1,
#   'weve': 1,
#   '%wat': 5,
#   'wate': 2,
#   '%bus': 4,
#   'busi': 2,
#   'usin': 6,
#   'sine': 2,
#   'ines': 4,
#   'very': 5,
#   'eryt': 1,
#   'ryth': 1,
#   '%%sm': 12,
#   '%sma': 3,
#   'smal': 2,
#   '%%ro': 37,
#   '%roo': 5,
#   'want': 3,
#   'ante': 3,
#   '%lea': 17,
#   'leas': 7,
#   '%%na': 19,
#   '%nat': 9,
#   'nati': 14,
#   'atio': 90,
#   'tion': 58,
#   'iona': 17,
#   'than': 3,
#   '%sto': 18,
#   'stor': 11,
#   '%pow': 5,
#   'powe': 4,
#   '%gro': 10,
#   'grou': 6,
#   '%mot': 5,
#   'moth': 3,
#   'havi': 4,
#   'avin': 4,
#   '%nam': 3,
#   'woma': 1,
#   '%inf': 7,
#   'info': 2,
#   'nfor': 5,
#   'form': 16,
#   'orma': 10,
#   'rmat': 4,
#   'mati': 7,
#   '%pro': 65,
#   'prob': 3,
#   'robl': 2,
#   'oble': 2,
#   '%%jo': 26,
#   '%lat': 6,
#   'late': 7,
#   '%alr': 2,
#   'alre': 1,
#   'lrea': 1,
#   'read': 6,
#   '%%ga': 24,
#   '%gam': 2,
#   '%%bl': 13,
#   '%bla': 3,
#   'blac': 2,
#   '%har': 9,
#   'maki': 1,
#   'akin': 6,
#   'look': 3,
#   'ooki': 3,
#   'okin': 3,
#   '%%as': 27,
#   '%ask': 3,
#   'aske': 2,
#   '%mil': 7,
#   'mill': 3,
#   'illi': 12,
#   'llio': 5,
#   '%boo': 5,
#   '%tog': 1,
#   'toge': 1,
#   'oget': 1,
#   'geth': 1,
#   'ethe': 3,
#   'heal': 4,
#   'ealt': 5,
#   '%uni': 12,
#   'unit': 6,
#   'nite': 2,
#   '%%%q': 15,
#   '%%qu': 14,
#   '%que': 3,
#   'ques': 4,
#   'uest': 4,
#   'esti': 18,
#   'stio': 4,
#   '%han': 10,
#   '%fat': 3,
#   'fath': 3,
#   'athe': 10,
#   'pers': 7,
#   'erso': 8,
#   'youn': 2,
#   '%oft': 1,
#   'ofte': 1,
#   '%see': 11,
#   '%pas': 8,
#   '%soc': 4,
#   'soci': 6,
#   'ocia': 4,
#   '%new': 4,
#   'comi': 3,
#   'omin': 5,
#   'comp': 27,
#   'ompa': 5,
#   'mpan': 2,
#   '%sid': 3,
#   '%tea': 9,
#   'whet': 1,
#   'heth': 1,
#   '%abl': 1,
#   '%alm': 1,
#   'almo': 1,
#   'lmos': 1,
#   '%pol': 10,
#   'poli': 7,
#   'olit': 4,
#   'liti': 10,
#   'itic': 7,
#   'tica': 10,
#   '%liv': 4,
#   '%kne': 3,
#   'beco': 3,
#   'ecom': 6,
#   'star': 7,
#   'sayi': 1,
#   'ayin': 4,
#   '%%op': 20,
#   '%ope': 9,
#   'work': 6,
#   'orki': 1,
#   'rkin': 2,
#   '%who': 5,
#   'whol': 1,
#   '%sup': 13,
#   'supp': 9,
#   'uppo': 7,
#   'ppor': 7,
#   '%yor': 1,
#   '%fiv': 1,
#   'roba': 1,
#   'obab': 1,
#   'babl': 1,
#   '%amo': 3,
#   'amon': 1,
#   '%usi': 1,
#   '%res': 32,
#   'rese': 16,
#   'esea': 2,
#   'sear': 4,
#   'earc': 4,
#   '%%gu': 17,
#   '%%id': 8,
#   '%ide': 7,
#   '%%ru': 12,
#   'make': 2,
#   '%ear': 7,
#   'earl': 4,
#   '%%el': 16,
#   '%els': 2,
#   '%inc': 15,
#   'incl': 4,
#   'nclu': 7,
#   'clud': 5,
#   'ludi': 1,
#   'udin': 1,
#   '%joh': 3,
#   'nder': 9,
#   'ders': 5,
#   'erst': 3,
#   'rsta': 2,
#   'stan': 20,
#   '%%hu': 18,
#   '%hum': 4,
#   'huma': 3,
#   'univ': 4,
#   'nive': 5,
#   'iver': 11,
#   'vers': 16,
#   'ersi': 6,
#   'rsit': 3,
#   'talk': 3,
#   'alki': 2,
#   'lkin': 2,
#   '%fre': 8,
#   '%alo': 3,
#   'alon': 3,
#   'ithi': 1,
#   '%his': 5,
#   'hist': 5,
#   'isto': 5,
#   'morn': 1,
#   'orni': 2,
#   'rnin': 8,
#   '%%ey': 2,
#   '%eye': 1,
#   '%sev': 3,
#   'seve': 3,
#   'vera': 4,
#   '%lin': 7,
#   '%min': 11,
#   '%ple': 5,
#   'plea': 4,
#   'prog': 5,
#   'rogr': 5,
#   'ogra': 7,
#   '%acr': 2,
#   'acro': 1,
#   'cros': 5,
#   '%kid': 2,
#   '%beh': 5,
#   'behi': 1,
#   'ehin': 1,
#   'part': 15,
#   'eryo': 1,
#   'ryon': 1,
#   '%bod': 2,
#   '%rem': 14,
#   'reme': 7,
#   'emem': 2,
#   'memb': 5,
#   'embe': 8,
#   '%%ex': 71,
#   '%exa': 7,
#   'exam': 5,
#   'xamp': 2,
#   'ampl': 4,
#   '%sor': 3,
#   'sorr': 1,
#   '%con': 93,
#   'cont': 27,
#   'ontr': 13,
#   'ntro': 8,
#   'give': 2,
#   '%%ra': 37,
#   '%rat': 7,
#   'rath': 1,
#   'mean': 5,
#   '%dat': 5,
#   '%%ob': 12,
#   '%oba': 1,
#   'obam': 1,
#   'tart': 3,
#   'arte': 5,
#   '%off': 13,
#   'offi': 7,
#   'ffic': 13,
#   '%%%T': 1,
#   '%%Tr': 1,
#   '%Tru': 1,
#   'comm': 23,
#   'ommu': 6,
#   'mmun': 6,
#   'muni': 6,
#   '%%wr': 11,
#   '%wro': 2,
#   'wron': 1,
#   'mont': 3,
#   'onth': 2,
#   '%fri': 5,
#   'frie': 6,
#   'rien': 10,
#   'iend': 3,
#   '%gen': 16,
#   'gene': 9,
#   'ener': 8,
#   'nera': 8,
#   '%mat': 10,
#   'matt': 4,
#   'atte': 15,
#   '%mov': 8,
#   '%%ed': 11,
#   '%edu': 4,
#   'educ': 8,
#   'duca': 4,
#   'ucat': 4,
#   'cati': 12,
#   '%foo': 5,
#   'hear': 4,
#   'ooke': 1,
#   '%%ei': 2,
#   '%eit': 1,
#   'eith': 2,
#   'ithe': 2,
#   '%him': 1,
#   'hims': 1,
#   'imse': 1,
#   'msel': 2,
#   '%hap': 6,
#   'happ': 6,
#   'appe': 14,
#   'ppen': 3,
#   'pene': 2,
#   '%lar': 5,
#   'larg': 4,
#   '%guy': 1,
#   '%sen': 10,
#   'sens': 3,
#   '%%ce': 16,
#   '%cen': 6,
#   'cent': 9,
#   'ente': 12,
#   'leav': 3,
#   '%%or': 16,
#   '%ord': 4,
#   'orde': 7,
#   'musi': 2,
#   'pret': 3,
#   'rett': 2,
#   'taki': 1,
#   'olic': 3,
#   'proc': 5,
#   'roce': 6,
#   'oces': 3,
#   '%%tu': 9,
#   '%tur': 6,
#   'come': 4,
#   '%los': 5,
#   '%%fu': 20,
#   '%fut': 1,
#   'futu': 1,
#   'utur': 1,
#   '%tab': 2,
#   'tabl': 11,
#   '%hal': 2,
#   '%%cl': 42,
#   '%clo': 12,
#   'clos': 7,
#   '%hop': 5,
#   '%lig': 2,
#   'ligh': 5,
#   'minu': 2,
#   'inut': 2,
#   'nute': 1,
#   'seem': 3,
#   'pare': 6,
#   'aren': 6,
#   'rent': 4,
#   '%pos': 12,
#   'poss': 6,
#   'ossi': 6,
#   'ssib': 6,
#   'sibl': 7,
#   'reas': 10,
#   'easo': 5,
#   '%exp': 32,
#   'expe': 17,
#   'xper': 9,
#   'peri': 9,
#   'erie': 4,
#   'ienc': 7,
#   '%are': 3,
#   'word': 1,
#   '%alt': 2,
#   'alth': 4,
#   'ltho': 1,
#   '%wai': 3,
#   '%doo': 2,
#   '%fel': 3,
#   '%acc': 15,
#   'acco': 5,
#   'ccor': 1,
#   'cord': 4,
#   'ordi': 4,
#   'rdin': 5,
#   '%%ai': 7,
#   '%ful': 2,
#   '%%de': 105,
#   '%dea': 9,
#   'anyo': 1,
#   'nyon': 1,
#   'deat': 2,
#   '%loc': 6,
#   'loca': 4,
#   'hour': 1,
#   'hank': 2,
#   '%%is': 10,
#   '%iss': 3,
#   'issu': 4,
#   'fron': 1,
#   'meti': 1,
#   'etim': 2,
#   '%ins': 19,
#   'inst': 13,
#   'nste': 2,
#   'stea': 3,
#   '%mom': 3,
#   'mome': 2,
#   'omen': 3,
#   'livi': 1,
#   'ivin': 6,
#   '%col': 17,
#   'coll': 10,
#   'olle': 9,
#   'lleg': 5,
#   '%gir': 3,
#   'need': 2,
#   'turn': 7,
#   'urne': 5,
#   '%%br': 39,
#   '%bri': 11,
#   'brin': 3,
#   '%lev': 2,
#   'leve': 3,
#   '%maj': 2,
#   'majo': 2,
#   '%was': 3,
#   'wash': 1,
#   'ashi': 2,
#   'shin': 4,
#   'ingt': 1,
#   'ngto': 1,
#   '%cle': 6,
#   'clea': 6,
#   '%bil': 5,
#   '%out': 4,
#   'outs': 1,
#   'utsi': 1,
#   'tsid': 1,
#   '%ser': 10,
#   'serv': 17,
#   'ervi': 6,
#   'rvic': 2,
#   'take': 3,
#   'hand': 7,
#   'perh': 1,
#   'erha': 1,
#   'rhap': 1,
#   '%sea': 8,
#   'seas': 4,
#   '%mem': 6,
#   'mber': 4,
#   'know': 7,
#   'blem': 1,
#   '%%cu': 19,
#   'hink': 2,
#   'inki': 2,
#   'nkin': 3,
#   '%bas': 8,
#   'base': 3,
#   'like': 4,
#   'ikel': 2,
#   '%str': 28,
#   'stre': 7,
#   'tree': 3,
#   'secu': 4,
#   'ecur': 2,
#   'curi': 2,
#   'urit': 1,
#   '%gav': 1,
#   'them': 4,
#   'hems': 1,
#   'emse': 1,
#   'selv': 2,
#   'elve': 2,
#   'insi': 3,
#   'nsid': 6,
#   '%%es': 13,
#   '%esp': 1,
#   'espe': 4,
#   'spec': 14,
#   'peci': 5,
#   'ecia': 3,
#   'cial': 3,
#   'iall': 5,
#   '%for': 25,
#   'orme': 4,
#   '%fed': 1,
#   'fede': 1,
#   'eder': 1,
#   'dera': 4,
#   '%mar': 20,
#   'mark': 7,
#   'arke': 5,
#   '%beg': 5,
#   'bega': 1,
#   '%%my': 3,
#   '%mys': 2,
#   'myse': 1,
#   'ysel': 1,
#   '%nic': 2,
#   '%wif': 1,
#   '%qui': 6,
#   'quit': 1,
#   '%gon': 1,
#   'fina': 4,
#   'inal': 2,
#   'nall': 4,
#   '%tow': 5,
#   'towa': 2,
#   'owar': 3,
#   'mili': 4,
#   'ilit': 13,
#   'lita': 1,
#   'itar': 1,
#   '%rep': 26,
#   'repo': 6,
#   'epor': 6,
#   '%hol': 8,
#   '%%sp': 34,
#   '%spe': 15,
#   '%bab': 2,
#   '%cau': 5,
#   '%sou': 10,
#   'sout': 2,
#   'ssue': 2,
#   '%%ph': 19,
#   '%pho': 8,
#   'phon': 4,
#   '%soo': 2,
#   '%nor': 4,
#   'nort': 2,
#   '%%ec': 3,
#   '%eco': 3,
#   'cono': 3,
#   'onom': 3,
#   'nomi': 3,
#   'live': 5,
#   'coup': 2,
#   'oupl': 2,
#   '%chu': 4,
#   'chur': 2,
#   'hurc': 2,
#   '%goe': 1,
#   '%cla': 11,
#   'clas': 5,
#   '%dev': 10,
#   'deve': 6,
#   'evel': 8,
#   'velo': 6,
#   'elop': 5,
#   'lopm': 2,
#   'opme': 2,
#   'pmen': 3,
#   'abov': 1,
#   '%fig': 5,
#   'figu': 3,
#   'igur': 3,
#   'watc': 3,
#   '%mid': 2,
#   'midd': 1,
#   'iddl': 1,
#   '%sim': 7,
#   'simp': 3,
#   'impl': 6,
#   'rson': 5,
#   'sona': 4,
#   '%run': 2,
#   'runn': 1,
#   'unni': 1,
#   'nnin': 4,
#   'eede': 1,
#   '%spa': 5,
#   'spac': 2,
#   ...})

# %%
def get_top3_weights(txt, probs, n):    
    weights = probs.get(txt[len(txt)-n:], {})
    if not weights:
        return {}

    words = np.array(list(weights.keys()))
    freq = np.array(list(weights.values()))

    top = np.argpartition(freq, -3)[-3:] if len(freq) >= 3 else np.argpartition(freq, -len(freq))

    return dict(zip(words[top], freq[top]))

# %%
word_counts = {'apple': 10, 'banana': 5, 'orange': 8, 'grape': 3, 'kiwi': 12}
print(get_top3_weights('oi', {'oi': word_counts}, 2))
# Out:
# {'orange': 8, 'apple': 10, 'kiwi': 12}

# %%
def predicter(n, words):

    # initializes variables
    probs, prev_counts = generate_probs(n, words)

    txt = r'%%%'
    while (curr := input("Next Letter: ")) != '':
        if curr == ' ':
            txt = r'%%%'
            continue

        txt += curr
        top3 = get_top3_weights(txt, probs, n)
        print(f'\n{txt} \nBest 3 letters are: {list(reversed(top3.keys()))}')

# %%
predicter(N, words)
# Out:
# %%%a
# Best 3 letters are: ['n', 'c', 'l']
#
# %%%an
# Best 3 letters are: ['n', 'y', 'g']
#
# %%%ann
# Best 3 letters are: ['o', 'i', 'e']
#
# %%%anno
# Best 3 letters are: ['u']
#
# %%%annou
# Best 3 letters are: ['n']
#
# %%%announ
# Best 3 letters are: ['c']
#
# %%%announc
# Best 3 letters are: ['e', 'i']
#
# %%%announce
# Best 3 letters are: ['m', 'd']
#
# %%%announcem
# Best 3 letters are: ['e']
#
# %%%announceme
# Best 3 letters are: ['n']
#
# %%%announcemen
# Best 3 letters are: ['t', 'd']
#
# %%%announcement
# Best 3 letters are: ['s', 'a', 'i']
#
# %%%s
# Best 3 letters are: ['t', 'e', 'u']
#
# %%%st
# Best 3 letters are: ['r', 'a', 'o']
#
# %%%str
# Best 3 letters are: ['e', 'u', 'a']
#
# %%%stre
# Best 3 letters are: ['a', 'e', 't']

# %%
# Save the probs dict as a json
import json

with open('./data/probs.json', 'w') as f:
    json.dump(generate_probs(N, words)[0], f)
